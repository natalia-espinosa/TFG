# %%
import numpy as np
import ModeloBase
from ModeloBase import read_data_model, add_laplace_noise, rmse
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor  # Importación del modelo XGBoost
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

# Cargar los datos de California Housing
all_data = fetch_california_housing()
X_train_val, X_val, X_test, Y_train_val, Y_val, Y_test = read_data_model(all_data, 'MedInc')

# Entrenar el escalador con los datos train_val para evitar fuga de datos antes del entrenamiento
scaler = StandardScaler()
X_train_val_scaled = scaler.fit_transform(X_train_val)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Definir los parámetros para la búsqueda en cuadrícula
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Configurar el modelo y la búsqueda en cuadrícula
xgbr = XGBRegressor(objective='reg:squarederror', random_state=42)
grid_search = GridSearchCV(
    estimator=xgbr,
    param_grid=param_grid,
    cv=3,
    scoring='neg_mean_squared_error',
    n_jobs=-1
)

# Entrenar el modelo con la búsqueda de hiperparámetros
grid_search.fit(X_train_val_scaled, Y_train_val)
best_params = grid_search.best_params_

# Imprimir los mejores parámetros encontrados
print("Best parameters found:", best_params)

# Entrenamiento del modelo original sin ruido con los mejores parámetros
model_original = XGBRegressor(**best_params, objective='reg:squarederror', random_state=42)
model_original.fit(X_train_val_scaled, Y_train_val)
Y_predict = model_original.predict(X_test_scaled)

print(f"X_test : {X_test}")
print(f"Y_test : {Y_test}")
print(f"Y_predict : {Y_predict}")

# Introducción de ruido óptimo en los datos
epsilon_optimo = 1
np.random.seed(0)  # Semilla para reproducibilidad

X_train_val_noisy = add_laplace_noise(X_train_val, epsilon_optimo)
X_test_noisy = add_laplace_noise(X_test, epsilon_optimo)

scalerRuido = StandardScaler()
X_train_val_noisy_scaled = scalerRuido.fit_transform(X_train_val_noisy)
X_test_noisy_scaled = scalerRuido.transform(X_test_noisy)

# Entrenamiento del modelo con los datos ruidosos
model_noisy = XGBRegressor(**best_params, objective='reg:squarederror', random_state=42)
model_noisy.fit(X_train_val_noisy_scaled, Y_train_val)
Y_predict_optimo = model_noisy.predict(X_test_noisy_scaled)

# Definir 20 niveles de ruido adicionales que el atacante probará usando Laplace
additional_epsilons = np.logspace(np.log10(0.01), np.log10(1000), num=50)
additional_epsilons = np.insert(additional_epsilons, 0, 0)

print("\nResultados del ataque para los primeros 10 valores:")

numero_muestras = 50

X_test_reducido = X_test[0:numero_muestras, 0]
X_test_noisy_reducido = X_test_noisy[0:numero_muestras, 0]

MAE_delivery = mae(X_test_reducido, X_test_noisy_reducido)
RMSE_delivery = rmse(X_test_reducido, X_test_noisy_reducido)
R2_delivery = r2(X_test_reducido, X_test_noisy_reducido)

print("\nerror en la entrega:")
print(f"MAE: {MAE_delivery}")
print(f"RMSE: {RMSE_delivery}")
print(f"R2: {R2_delivery}")


# Inicializar listas para estadísticas detalladas
improvement = []
worsening = []

# Inicializar contadores para mejoras y empeoramientos
count_improvements = 0
count_worsenings = 0

X_test_attack = np.empty(numero_muestras)

# Simulación del ataque para los primeros 10 valores
for i in range(numero_muestras):
    original_noisy_value = X_test_noisy[i, 0]  # Valor con ruido
    original_value = X_test[i, 0]  # Valor original sin ruido
    print(f"\nValor original sin ruido (index {i}): {original_value}")
    print(f"Valor ruidoso original (index {i}): {original_noisy_value}")
    print(f"Y_test original (index {i}): {Y_test[i]}")
    print(f"Y Predict original (index {i}): {Y_predict[i]}")
    print(f"Y Predict optimo (index {i}): {Y_predict_optimo[i]}")
    print(f" Error prediccion (index {i}): {abs(Y_test[i] - Y_predict_optimo[i])}")

    best_error = float('inf')
    best_prediction = None
    best_epsilon = None

    for epsilon in additional_epsilons:
        # Generar ruido adicional usando Laplace
        if (epsilon != 0):
            additional_noise_test = add_laplace_noise(X_test_noisy, epsilon)
        else:
            additional_noise_test = X_test_noisy.copy()

        additional_noise_test_scaled = scaler.transform(additional_noise_test)

        # Ajustar el valor de entrada con el nuevo ruido
        noisy_X_test_scaled = [additional_noise_test_scaled[i, :]]  # Suponiendo que la columna de interés es la primera

        # Realizar la predicción para esta fila
        prediction = model_original.predict(noisy_X_test_scaled)

        # Calcular el error
        true_value = Y_test[i]
        error = abs(true_value - prediction)

        # Mostrar el valor con ruido añadido y la predicción correspondiente
        print(f"  - Valor ajustado: {additional_noise_test[i, 0]}, Predicción: {prediction}, Epsilon usado: {epsilon}, Error: {error}")

        # Evaluar si este error es el mejor (menor)
        if error < best_error:
            best_error = error
            best_prediction = prediction
            best_epsilon = epsilon

            X_test_attack[i] = additional_noise_test[i, 0]

    print(f"Mejor X: {X_test_attack[i]} Mejor Epsilon para index {i}: {best_epsilon}, Mejor Error: {best_error}, Mejor Predicción: {best_prediction}")
    error_x_noise = abs(X_test_noisy[i, 0] - X_test[i, 0])
    error_x_attack = abs(X_test_attack[i] - X_test[i, 0])

    improvement_value = error_x_noise - error_x_attack
    improvement.append(improvement_value)
    if improvement_value > 0:
        count_improvements += 1
    else:
        worsening_value = error_x_attack - error_x_noise
        worsening.append(worsening_value)
        if worsening_value > 0:
            count_worsenings += 1

    print(f"mejora {improvement_value}  R pre {error_x_noise} R pos {error_x_attack}")

MAE_attack = mae(X_test_reducido, X_test_attack)
RMSE_attack = rmse(X_test_reducido, X_test_attack)
R2_attack = r2(X_test_reducido, X_test_attack)

print("\nerror en la entrega:")
print(f"MAE: {MAE_delivery}")
print(f"RMSE: {RMSE_delivery}")
print(f"R2: {R2_delivery}")

print("\nerror attack:")
print(f"MAE: {MAE_attack}")
print(f"RMSE: {RMSE_attack}")
print(f"R2: {R2_attack}")


# Estadísticas detalladas
improvement = np.array(improvement)
worsening = np.array(worsening)


# Filtrar solo mejoras positivas
positive_improvements = improvement[improvement > 0]


print("\nEstadísticas detalladas de mejora:")
print(f"Mejora Media: {np.mean(positive_improvements)}")
print(f"Varianza de la Mejora: {np.var(positive_improvements)}")
print(f"Número de puntos que mejoran: {count_improvements}")
print(f"Mejora Máxima: {np.max(positive_improvements)}")
print(f"Mejora Mínima: {np.min(positive_improvements)}")

print("\nEstadísticas detalladas de empeoramiento:")
print(f"Empeoramiento Medio: {np.mean(worsening)}")
print(f"Varianza del Empeoramiento: {np.var(worsening)}")
print(f"Número de puntos que empeoran: {count_worsenings}")
print(f"Empeoramiento Máximo: {np.max(worsening)}")
print(f"Empeoramiento Mínimo: {np.min(worsening)}")
# Out:
# Y_data: 20640
# y_data: 19648
# y_data: 18665
# Best parameters found: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'subsample': 0.8}
# X_test : [[   3.463         8.            6.36363636 ...    2.89800443
#     39.08       -121.04      ]
#  [   3.2891       27.            5.24033149 ...    2.42541436
#     38.05       -122.14      ]
#  [   2.096        34.            2.46689304 ...    3.37351443
#     34.05       -118.3       ]
#  ...
#  [   6.4415       15.            7.07798165 ...    2.89449541
#     33.83       -117.76      ]
#  [   2.425        17.            3.16008772 ...    1.68640351
#     33.89       -117.87      ]
#  [   3.0938       32.            4.71764706 ...    2.23921569
#     38.25       -122.04      ]]
# Y_test : [2.017 1.506 1.875 ... 3.007 1.717 1.104]
# Y_predict : [1.5475898 1.401996  1.9830345 ... 2.8735013 1.3602865 1.6196193]
#
# Resultados del ataque para los primeros 10 valores:
#
# error en la entrega:
# MAE: 13.138027078018375
# RMSE: 17.759378930395194
# R2: -110.28166218236254
#
# Valor original sin ruido (index 0): 3.463
# Valor ruidoso original (index 0): -0.8372446417749249
# Y_test original (index 0): 2.017
# Y Predict original (index 0): 1.5475897789001465
# Y Predict optimo (index 0): 1.6081595420837402
#  Error prediccion (index 0): 0.40884045791625967
#   - Valor ajustado: -0.8372446417749249, Predicción: [1.1523403], Epsilon usado: 0.0, Error: [0.86465967]
#   - Valor ajustado: 982.9501234052991, Predicción: [3.2141988], Epsilon usado: 0.01, Error: [1.1971989]
#   - Valor ajustado: 7207.2947340145565, Predicción: [3.2141988], Epsilon usado: 0.012648552168552958, Error: [1.1971989]
#   - Valor ajustado: -1959.8308031835318, Predicción: [1.1523403], Epsilon usado: 0.015998587196060583, Error: [0.86465967]
#   - Valor ajustado: 12202.232260236575, Predicción: [3.2141988], Epsilon usado: 0.020235896477251575, Error: [1.1971989]
#   - Valor ajustado: -5124.854333672991, Predicción: [1.1523403], Epsilon usado: 0.025595479226995357, Error: [0.86465967]
#   - Valor ajustado: 1530.245520522361, Predicción: [3.2141988], Epsilon usado: 0.032374575428176434, Error: [1.1971989]
#   - Valor ajustado: -4701.197170041786, Predicción: [1.1523403], Epsilon usado: 0.040949150623804255, Error: [0.86465967]
#   - Valor ajustado: -649.2795606726413, Predicción: [1.1523403], Epsilon usado: 0.05179474679231213, Error: [0.86465967]
#   - Valor ajustado: 13.637575627974446, Predicción: [3.2141988], Epsilon usado: 0.0655128556859551, Error: [1.1971989]
#   - Valor ajustado: -1201.7937886734508, Predicción: [1.1523403], Epsilon usado: 0.08286427728546843, Error: [0.86465967]
#   - Valor ajustado: -1635.8930925248085, Predicción: [1.1523403], Epsilon usado: 0.10481131341546858, Error: [0.86465967]
#   - Valor ajustado: 371.8416172541719, Predicción: [3.2141988], Epsilon usado: 0.13257113655901095, Error: [1.1971989]
#   - Valor ajustado: 2271.9067944886797, Predicción: [3.2141988], Epsilon usado: 0.16768329368110083, Error: [1.1971989]
#   - Valor ajustado: 0.7179744735058631, Predicción: [1.1523403], Epsilon usado: 75.43120063354623, Error: [0.86465967]
#   - Valor ajustado: -0.3770740965789068, Predicción: [1.1523403], Epsilon usado: 95.40954763499944, Error: [0.86465967]
#   - Valor ajustado: -1.8997902285867871, Predicción: [1.1523403], Epsilon usado: 120.67926406393289, Error: [0.86465967]
#   - Valor ajustado: -5.3547747198938085, Predicción: [1.1523403], Epsilon usado: 152.64179671752333, Error: [0.86465967]
#   - Valor ajustado: -1.209023077994174, Predicción: [1.1523403], Epsilon usado: 193.06977288832496, Error: [0.86465967]
#   - Valor ajustado: 1.1787643822580942, Predicción: [1.1498232], Epsilon usado: 244.205309454865, Error: [0.8671768]
#   - Valor ajustado: -0.4770918818827611, Predicción: [1.1523403], Epsilon usado: 308.8843596477485, Error: [0.86465967]
#   - Valor ajustado: 0.3990485624974709, Predicción: [1.1523403], Epsilon usado: 390.6939937054621, Error: [0.86465967]
#   - Valor ajustado: -1.2086638783062171, Predicción: [1.1523403], Epsilon usado: 494.17133613238383, Error: [0.86465967]
#   - Valor ajustado: -0.7565499436455567, Predicción: [1.1523403], Epsilon usado: 625.0551925273976, Error: [0.86465967]
#   - Valor ajustado: -0.9236503134824657, Predicción: [1.1523403], Epsilon usado: 790.6043210907702, Error: [0.86465967]
#   - Valor ajustado: -0.8384516645453408, Predicción: [1.1523403], Epsilon usado: 1000.0, Error: [0.86465967]
# Mejor X: 4.284590728678094 Mejor Epsilon para index 0: 37.27593720314942, Mejor Error: [0.34544873], Mejor Predicción: [1.6715512]
# mejora 3.4786539130968306  R pre 4.300244641774925 R pos 0.8215907286780944
#
# Valor original sin ruido (index 1): 3.2891
# Valor ruidoso original (index 1): -38.74946179095862
# Y_test original (index 1): 1.506
# Y Predict original (index 1): 1.4019960165023804
# Y Predict optimo (index 1): 1.518595576286316
#  Error prediccion (index 1): 0.012595576286315913
#   - Valor ajustado: -38.74946179095862, Predicción: [1.33482], Epsilon usado: 0.0, Error: [0.17118001]
#   - Valor ajustado: 38940.92462608591, Predicción: [3.0499227], Epsilon usado: 0.01, Error: [1.5439227]
#   - Valor ajustado: 21674.87456940173, Predicción: [3.0499227], Epsilon usado: 0.012648552168552958, Error: [1.5439227]
#   - Valor ajustado: -1788.0829146215208, Predicción: [1.33482], Epsilon usado: 0.015998587196060583, Error: [0.17118001]
#   - Valor ajustado: 14323.914832039442, Predicción: [3.0499227], Epsilon usado: 0.020235896477251575, Error: [1.5439227]
#   - Valor ajustado: -4201.195463129717, Predicción: [1.33482], Epsilon usado: 0.025595479226995357, Error: [0.17118001]
#   - Valor ajustado: 11771.494772741722, Predicción: [3.0499227], Epsilon usado: 0.032374575428176434, Error: [1.5439227]
#   - Valor ajustado: 981.9645708951278, Predicción: [3.0499227], Epsilon usado: 0.040949150623804255, Error: [1.5439227]
#   - Valor ajustado: 5000.083903602765, Predicción: [3.0499227], Epsilon usado: 0.05179474679231213, Error: [1.5439227]
#   - Valor ajustado: 3871.2153995187145, Predicción: [3.0499227], Epsilon usado: 0.0655128556859551, Error: [1.5439227]
#   - Valor ajustado: -4645.454325771529, Predicción: [1.33482], Epsilon usado: 0.08286427728546843, Error: [0.17118001]
#   - Valor ajustado: 375.0799620517558, Predicción: [3.0499227], Epsilon usado: 0.10481131341546858, Error: [1.5439227]
#   - Valor ajustado: 2186.3252566615824, Predicción: [3.0499227], Epsilon usado: 0.13257113655901095, Error: [1.5439227]
#   - Valor ajustado: -4682.120817099898, Predicción: [1.33482], Epsilon usado: 0.16768329368110083, Error: [0.17118001]
#   - Valor ajustado: 652.1278618889689, Predicción: [3.0499227], Epsilon usado: 0.21209508879201905, Error: [1.5439227]
#   - Valor ajustado: -99.50311518319869, Predicción: [1.33482], Epsilon usado: 0.2682695795279726, Error: [0.17118001]
#   - Valor ajustado: -988.9706976740721, Predicción: [1.33482], Epsilon usado: 0.33932217718953295, Error: [0.17118001]
#   - Valor ajustado: -12.574363277395825, Predicción: [1.33482], Epsilon usado: 0.42919342601287785, Error: [0.17118001]
#   - Valor ajustado: -387.07282640746416, Predicción: [1.33482], Epsilon usado: 0.5428675439323859, Error: [0.17118001]
#   - Valor ajustado: -600.5796046909011, Predicción: [1.33482], Epsilon usado: 0.6866488450043002, Error: [0.17118001]
#   - Valor ajustado: -10.033586340012384, Predicción: [1.33482], Epsilon usado: 0.8685113737513529, Error: [0.17118001]
#   - Valor ajustado: 30.855034938700385, Predicción: [3.0499227], Epsilon usado: 1.0985411419875584, Error: [1.5439227]
#   - Valor ajustado: -64.98377866186355, Predicción: [1.33482], Epsilon usado: 1.3894954943731375, Error: [0.17118001]
#   - Valor ajustado: -158.5706565639982, Predicción: [1.33482], Epsilon usado: 1.757510624854793, Error: [0.17118001]
#   - Valor ajustado: -114.01652743097576, Predicción: [1.33482], Epsilon usado: 2.2229964825261956, Error: [0.17118001]
#   - Valor ajustado: -0.5665882454505748, Predicción: [1.33482], Epsilon usado: 2.8117686979742307, Error: [0.17118001]
#   - Valor ajustado: -31.195652209692764, Predicción: [1.33482], Epsilon usado: 3.5564803062231287, Error: [0.17118001]
#   - Valor ajustado: 1.9714864899659759, Predicción: [1.1907362], Epsilon usado: 4.498432668969444, Error: [0.31526387]
#   - Valor ajustado: -51.62147345002742, Predicción: [1.33482], Epsilon usado: 5.689866029018299, Error: [0.17118001]
#   - Valor ajustado: -9.06357209891161, Predicción: [1.33482], Epsilon usado: 7.196856730011521, Error: [0.17118001]
#   - Valor ajustado: -32.38972764532403, Predicción: [1.33482], Epsilon usado: 9.102981779915218, Error: [0.17118001]
#   - Valor ajustado: -46.737127414411816, Predicción: [1.33482], Epsilon usado: 11.513953993264481, Error: [0.17118001]
#   - Valor ajustado: -37.492261293981315, Predicción: [1.33482], Epsilon usado: 14.563484775012444, Error: [0.17118001]
#   - Valor ajustado: -72.57683546634976, Predicción: [1.33482], Epsilon usado: 18.420699693267164, Error: [0.17118001]
#   - Valor ajustado: -38.11870545340393, Predicción: [1.33482], Epsilon usado: 23.29951810515372, Error: [0.17118001]
#   - Valor ajustado: -36.59618105836933, Predicción: [1.33482], Epsilon usado: 29.4705170255181, Error: [0.17118001]
#   - Valor ajustado: -42.002635773916694, Predicción: [1.33482], Epsilon usado: 37.27593720314942, Error: [0.17118001]
#   - Valor ajustado: -36.59878083820684, Predicción: [1.33482], Epsilon usado: 47.14866363457394, Error: [0.17118001]
#   - Valor ajustado: -37.813456936045995, Predicción: [1.33482], Epsilon usado: 59.63623316594643, Error: [0.17118001]
#   - Valor ajustado: -36.55717571364665, Predicción: [1.33482], Epsilon usado: 75.43120063354623, Error: [0.17118001]
#   - Valor ajustado: -42.54333854317557, Predicción: [1.33482], Epsilon usado: 95.40954763499944, Error: [0.17118001]
#   - Valor ajustado: -36.27732761918875, Predicción: [1.33482], Epsilon usado: 120.67926406393289, Error: [0.17118001]
#   - Valor ajustado: -38.326122991273735, Predicción: [1.33482], Epsilon usado: 152.64179671752333, Error: [0.17118001]
#   - Valor ajustado: -39.52738941588392, Predicción: [1.33482], Epsilon usado: 193.06977288832496, Error: [0.17118001]
#   - Valor ajustado: -39.62947541634905, Predicción: [1.33482], Epsilon usado: 244.205309454865, Error: [0.17118001]
#   - Valor ajustado: -41.093242589882, Predicción: [1.33482], Epsilon usado: 308.8843596477485, Error: [0.17118001]
#   - Valor ajustado: -38.48790031026805, Predicción: [1.33482], Epsilon usado: 390.6939937054621, Error: [0.17118001]
#   - Valor ajustado: -38.731662604174, Predicción: [1.33482], Epsilon usado: 494.17133613238383, Error: [0.17118001]
#   - Valor ajustado: -38.69060761946829, Predicción: [1.33482], Epsilon usado: 625.0551925273976, Error: [0.17118001]
#   - Valor ajustado: -38.407202228979955, Predicción: [1.33482], Epsilon usado: 790.6043210907702, Error: [0.17118001]
#   - Valor ajustado: -38.7566141728201, Predicción: [1.33482], Epsilon usado: 1000.0, Error: [0.17118001]
# Mejor X: -38.74946179095862 Mejor Epsilon para index 1: 0.0, Mejor Error: [0.17118001], Mejor Predicción: [1.33482]
# mejora 0.0  R pre 42.03856179095862 R pos 42.03856179095862
#
# Valor original sin ruido (index 2): 2.096
# Valor ruidoso original (index 2): 43.2177595645841
# Y_test original (index 2): 1.875
# Y Predict original (index 2): 1.9830344915390015
# Y Predict optimo (index 2): 1.965895175933838
#  Error prediccion (index 2): 0.09089517593383789
#   - Valor ajustado: 43.2177595645841, Predicción: [3.9389727], Epsilon usado: 0.0, Error: [2.0639727]
#   - Valor ajustado: -1983.8327350471502, Predicción: [2.0676663], Epsilon usado: 0.01, Error: [0.19266629]
#   - Valor ajustado: 6460.627948896553, Predicción: [3.9389727], Epsilon usado: 0.012648552168552958, Error: [2.0639727]
#   - Valor ajustado: 785.5656886925523, Predicción: [3.9389727], Epsilon usado: 0.015998587196060583, Error: [2.0639727]
#   - Valor ajustado: 9877.874757530175, Predicción: [3.9389727], Epsilon usado: 0.020235896477251575, Error: [2.0639727]
#   - Valor ajustado: -14466.109535098745, Predicción: [2.0676663], Epsilon usado: 0.025595479226995357, Error: [0.19266629]
#   - Valor ajustado: 46.377826240981825, Predicción: [3.9389727], Epsilon usado: 0.032374575428176434, Error: [2.0639727]
#   - Valor ajustado: 42.6401832459465, Predicción: [3.9389727], Epsilon usado: 18.420699693267164, Error: [2.0639727]
#   - Valor ajustado: 42.40766503975754, Predicción: [3.9389727], Epsilon usado: 23.29951810515372, Error: [2.0639727]
#   - Valor ajustado: 41.156488963608396, Predicción: [3.9389727], Epsilon usado: 29.4705170255181, Error: [2.0639727]
#   - Valor ajustado: 42.230030797873354, Predicción: [3.9389727], Epsilon usado: 37.27593720314942, Error: [2.0639727]
#   - Valor ajustado: 47.43563770718637, Predicción: [3.9389727], Epsilon usado: 47.14866363457394, Error: [2.0639727]
#   - Valor ajustado: 36.4355284484793, Predicción: [3.9389727], Epsilon usado: 59.63623316594643, Error: [2.0639727]
#   - Valor ajustado: 40.96784279866895, Predicción: [3.9389727], Epsilon usado: 75.43120063354623, Error: [2.0639727]
#   - Valor ajustado: 41.79480577857917, Predicción: [3.9389727], Epsilon usado: 95.40954763499944, Error: [2.0639727]
#   - Valor ajustado: 42.29195138039084, Predicción: [3.9389727], Epsilon usado: 120.67926406393289, Error: [2.0639727]
#   - Valor ajustado: 45.640867865759404, Predicción: [3.9389727], Epsilon usado: 152.64179671752333, Error: [2.0639727]
#   - Valor ajustado: 45.39741138790025, Predicción: [3.9389727], Epsilon usado: 193.06977288832496, Error: [2.0639727]
#   - Valor ajustado: 41.33083416339958, Predicción: [3.9389727], Epsilon usado: 244.205309454865, Error: [2.0639727]
#   - Valor ajustado: 42.56449536939928, Predicción: [3.9389727], Epsilon usado: 308.8843596477485, Error: [2.0639727]
#   - Valor ajustado: 43.35437390982327, Predicción: [3.9389727], Epsilon usado: 390.6939937054621, Error: [2.0639727]
#   - Valor ajustado: 42.74461819238034, Predicción: [3.9389727], Epsilon usado: 494.17133613238383, Error: [2.0639727]
#   - Valor ajustado: 43.12496509862299, Predicción: [3.9389727], Epsilon usado: 625.0551925273976, Error: [2.0639727]
#   - Valor ajustado: 43.40325690630341, Predicción: [3.9389727], Epsilon usado: 790.6043210907702, Error: [2.0639727]
#   - Valor ajustado: 43.073116654365855, Predicción: [3.9389727], Epsilon usado: 1000.0, Error: [2.0639727]
# Mejor X: 4.52963565161258 Mejor Epsilon para index 2: 1.757510624854793, Mejor Error: [0.11402738], Mejor Predicción: [1.9890274]
# mejora 38.68812391297152  R pre 41.121759564584096 R pos 2.4336356516125797
#
# Valor original sin ruido (index 3): 4.875
# Valor ruidoso original (index 3): 2.7017448346013198
# Y_test original (index 3): 2.495
# Y Predict original (index 3): 2.7404825687408447
# Y Predict optimo (index 3): 2.5386879444122314
#  Error prediccion (index 3): 0.04368794441223134
#   - Valor ajustado: 2.7017448346013198, Predicción: [2.2045276], Epsilon usado: 0.0, Error: [0.29047227]
#   - Valor ajustado: -19628.691795309787, Predicción: [1.9007423], Epsilon usado: 0.01, Error: [0.5942576]
#   - Valor ajustado: 1605.165719841195, Predicción: [3.5589592], Epsilon usado: 0.012648552168552958, Error: [1.0639594]
#   - Valor ajustado: -1482.4649895459931, Predicción: [1.9007423], Epsilon usado: 0.015998587196060583, Error: [0.5942576]
#   - Valor ajustado: -69.41639981744851, Predicción: [1.9007423], Epsilon usado: 7.196856730011521, Error: [0.5942576]
#   - Valor ajustado: 8.243956413697077, Predicción: [3.5287988], Epsilon usado: 9.102981779915218, Error: [1.0337989]
#   - Valor ajustado: -24.662434542462503, Predicción: [1.9007423], Epsilon usado: 11.513953993264481, Error: [0.5942576]
#   - Valor ajustado: -13.133118368011726, Predicción: [1.9007423], Epsilon usado: 14.563484775012444, Error: [0.5942576]
#   - Valor ajustado: -16.88609078317045, Predicción: [1.9007423], Epsilon usado: 18.420699693267164, Error: [0.5942576]
#   - Valor ajustado: 0.5281717240944315, Predicción: [1.9007423], Epsilon usado: 23.29951810515372, Error: [0.5942576]
#   - Valor ajustado: -4.947478649572579, Predicción: [1.9007423], Epsilon usado: 29.4705170255181, Error: [0.5942576]
#   - Valor ajustado: -2.9680760541636046, Predicción: [1.9007423], Epsilon usado: 37.27593720314942, Error: [0.5942576]
#   - Valor ajustado: 2.470740316228655, Predicción: [2.1247146], Epsilon usado: 47.14866363457394, Error: [0.37028527]
#   - Valor ajustado: 3.6206947509672567, Predicción: [2.4326513], Epsilon usado: 59.63623316594643, Error: [0.0623486]
#   - Valor ajustado: 0.21415977067478487, Predicción: [1.9007423], Epsilon usado: 75.43120063354623, Error: [0.5942576]
#   - Valor ajustado: 0.20253113108890508, Predicción: [1.9007423], Epsilon usado: 95.40954763499944, Error: [0.5942576]
#   - Valor ajustado: 2.244187698252524, Predicción: [2.1051679], Epsilon usado: 120.67926406393289, Error: [0.38983202]
#   - Valor ajustado: 2.128223102604698, Predicción: [2.0022063], Epsilon usado: 152.64179671752333, Error: [0.49279356]
#   - Valor ajustado: 4.434421422951849, Predicción: [2.5880191], Epsilon usado: 193.06977288832496, Error: [0.09301925]
#   - Valor ajustado: 2.806542620013892, Predicción: [2.2016761], Epsilon usado: 244.205309454865, Error: [0.29332376]
#   - Valor ajustado: 2.7801227148118737, Predicción: [2.2016072], Epsilon usado: 308.8843596477485, Error: [0.29339266]
#   - Valor ajustado: 2.706965285265566, Predicción: [2.2045276], Epsilon usado: 390.6939937054621, Error: [0.29047227]
#   - Valor ajustado: 3.5379602496450344, Predicción: [2.3716497], Epsilon usado: 494.17133613238383, Error: [0.12335014]
#   - Valor ajustado: 2.239603606090327, Predicción: [2.1051679], Epsilon usado: 625.0551925273976, Error: [0.38983202]
#   - Valor ajustado: 2.8896924457694113, Predicción: [2.261821], Epsilon usado: 790.6043210907702, Error: [0.23317885]
#   - Valor ajustado: 2.9226201728854146, Predicción: [2.266254], Epsilon usado: 1000.0, Error: [0.22874594]
# Mejor X: 3.6206947509672567 Mejor Epsilon para index 3: 59.63623316594643, Mejor Error: [0.0623486], Mejor Predicción: [2.4326513]
# mejora 0.9189499163659369  R pre 2.1732551653986802 R pos 1.2543052490327433
#
# Valor original sin ruido (index 4): 4.4167
# Valor ruidoso original (index 4): -11.456992705886265
# Y_test original (index 4): 1.58
# Y Predict original (index 4): 1.6224033832550049
# Y Predict optimo (index 4): 1.4975916147232056
#  Error prediccion (index 4): 0.0824083852767945
#   - Valor ajustado: -17.23339591675574, Predicción: [1.0160035], Epsilon usado: 3.5564803062231287, Error: [0.56399655]
#   - Valor ajustado: -129.37682388465174, Predicción: [1.0160035], Epsilon usado: 4.498432668969444, Error: [0.56399655]
#   - Valor ajustado: -30.09197489620688, Predicción: [1.0160035], Epsilon usado: 5.689866029018299, Error: [0.56399655]
#   - Valor ajustado: -43.08412851258603, Predicción: [1.0160035], Epsilon usado: 7.196856730011521, Error: [0.56399655]
#   - Valor ajustado: -9.92912247428836, Predicción: [1.0160035], Epsilon usado: 9.102981779915218, Error: [0.56399655]
#   - Valor ajustado: -16.57543150896011, Predicción: [1.0160035], Epsilon usado: 11.513953993264481, Error: [0.56399655]
#   - Valor ajustado: -6.314422808253272, Predicción: [1.0160035], Epsilon usado: 14.563484775012444, Error: [0.56399655]
#   - Valor ajustado: -15.690816278398593, Predicción: [1.0160035], Epsilon usado: 18.420699693267164, Error: [0.56399655]
#   - Valor ajustado: -12.875533330745672, Predicción: [1.0160035], Epsilon usado: 23.29951810515372, Error: [0.56399655]
#   - Valor ajustado: -9.380437957224029, Predicción: [1.0160035], Epsilon usado: 29.4705170255181, Error: [0.56399655]
#   - Valor ajustado: -7.650299385197593, Predicción: [1.0160035], Epsilon usado: 37.27593720314942, Error: [0.56399655]
#   - Valor ajustado: -6.946835697805579, Predicción: [1.0160035], Epsilon usado: 47.14866363457394, Error: [0.56399655]
#   - Valor ajustado: -9.635130604121551, Predicción: [1.0160035], Epsilon usado: 59.63623316594643, Error: [0.56399655]
#   - Valor ajustado: -14.648702398436317, Predicción: [1.0160035], Epsilon usado: 75.43120063354623, Error: [0.56399655]
#   - Valor ajustado: -11.596178731657423, Predicción: [1.0160035], Epsilon usado: 95.40954763499944, Error: [0.56399655]
#   - Valor ajustado: -11.47852987053884, Predicción: [1.0160035], Epsilon usado: 120.67926406393289, Error: [0.56399655]
#   - Valor ajustado: -11.55907975417518, Predicción: [1.0160035], Epsilon usado: 152.64179671752333, Error: [0.56399655]
#   - Valor ajustado: -11.583696729744764, Predicción: [1.0160035], Epsilon usado: 193.06977288832496, Error: [0.56399655]
#   - Valor ajustado: -12.683598106902682, Predicción: [1.0160035], Epsilon usado: 244.205309454865, Error: [0.56399655]
#   - Valor ajustado: -11.889712929445972, Predicción: [1.0160035], Epsilon usado: 308.8843596477485, Error: [0.56399655]
#   - Valor ajustado: -12.572733455066732, Predicción: [1.0160035], Epsilon usado: 390.6939937054621, Error: [0.56399655]
#   - Valor ajustado: -11.00523562680582, Predicción: [1.0160035], Epsilon usado: 494.17133613238383, Error: [0.56399655]
#   - Valor ajustado: -10.82587886381142, Predicción: [1.0160035], Epsilon usado: 625.0551925273976, Error: [0.56399655]
#   - Valor ajustado: -11.4856356438405, Predicción: [1.0160035], Epsilon usado: 790.6043210907702, Error: [0.56399655]
#   - Valor ajustado: -11.524903862709836, Predicción: [1.0160035], Epsilon usado: 1000.0, Error: [0.56399655]
# Mejor X: -11.456992705886265 Mejor Epsilon para index 4: 0.0, Mejor Error: [0.56399655], Mejor Predicción: [1.0160035]
# mejora 0.0  R pre 15.873692705886263 R pos 15.873692705886263
#
# Valor original sin ruido (index 5): 3.9107
# Valor ruidoso original (index 5): 10.586220942263946
# Y_test original (index 5): 1.907
# Y Predict original (index 5): 1.8280681371688843
# Y Predict optimo (index 5): 1.8249675035476685
#  Error prediccion (index 5): 0.08203249645233157
#   - Valor ajustado: 10.586220942263946, Predicción: [3.7927885], Epsilon usado: 0.0, Error: [1.8857886]
#   - Valor ajustado: -25504.858157938233, Predicción: [1.3202507], Epsilon usado: 0.01, Error: [0.5867492]
#   - Valor ajustado: -8901.412377991637, Predicción: [1.3202507], Epsilon usado: 0.012648552168552958, Error: [0.5867492]
#   - Valor ajustado: 18096.099026621112, Predicción: [3.7927885], Epsilon usado: 0.015998587196060583, Error: [1.8857886]
#   - Valor ajustado: -7692.981263803776, Predicción: [1.3202507], Epsilon usado: 0.020235896477251575, Error: [0.5867492]
#   - Valor ajustado: 16850.00549629462, Predicción: [3.7927885], Epsilon usado: 0.025595479226995357, Error: [1.8857886]
#   - Valor ajustado: 95.60170179687324, Predicción: [3.7927885], Epsilon usado: 0.032374575428176434, Error: [1.8857886]
#   - Valor ajustado: -5618.792950601636, Predicción: [1.3202507], Epsilon usado: 0.040949150623804255, Error: [0.5867492]
#   - Valor ajustado: -2749.517494644451, Predicción: [1.3202507], Epsilon usado: 0.05179474679231213, Error: [0.5867492]
#   - Valor ajustado: 164.51611370176005, Predicción: [3.7927885], Epsilon usado: 0.0655128556859551, Error: [1.8857886]
#   - Valor ajustado: 5237.746859732913, Predicción: [3.7927885], Epsilon usado: 0.08286427728546843, Error: [1.8857886]
#   - Valor ajustado: 654.9327569061375, Predicción: [3.7927885], Epsilon usado: 0.10481131341546858, Error: [1.8857886]
#   - Valor ajustado: -433.2052336469655, Predicción: [1.3202507], Epsilon usado: 0.13257113655901095, Error: [0.5867492]
#   - Valor ajustado: 374.44762945192207, Predicción: [3.7927885], Epsilon usado: 0.16768329368110083, Error: [1.8857886]
#   - Valor ajustado: 95.42659898927107, Predicción: [3.7927885], Epsilon usado: 0.21209508879201905, Error: [1.8857886]
#   - Valor ajustado: -266.79443688544353, Predicción: [1.3202507], Epsilon usado: 0.2682695795279726, Error: [0.5867492]
#   - Valor ajustado: -204.75888102283525, Predicción: [1.3202507], Epsilon usado: 0.33932217718953295, Error: [0.5867492]
#   - Valor ajustado: 262.2630150221746, Predicción: [3.7927885], Epsilon usado: 0.42919342601287785, Error: [1.8857886]
#   - Valor ajustado: 347.58191060236845, Predicción: [3.7927885], Epsilon usado: 0.5428675439323859, Error: [1.8857886]
#   - Valor ajustado: 133.0144801149155, Predicción: [3.7927885], Epsilon usado: 0.6866488450043002, Error: [1.8857886]
#   - Valor ajustado: 26.09097155369534, Predicción: [3.7927885], Epsilon usado: 0.8685113737513529, Error: [1.8857886]
#   - Valor ajustado: 249.53946258626252, Predicción: [3.7927885], Epsilon usado: 1.0985411419875584, Error: [1.8857886]
#   - Valor ajustado: -105.90132054896785, Predicción: [1.3202507], Epsilon usado: 1.3894954943731375, Error: [0.5867492]
#   - Valor ajustado: 10.503534806137585, Predicción: [3.7927885], Epsilon usado: 625.0551925273976, Error: [1.8857886]
#   - Valor ajustado: 10.974222017680432, Predicción: [3.7927885], Epsilon usado: 790.6043210907702, Error: [1.8857886]
#   - Valor ajustado: 10.963578051733263, Predicción: [3.7927885], Epsilon usado: 1000.0, Error: [1.8857886]
# Mejor X: -25504.858157938233 Mejor Epsilon para index 5: 0.01, Mejor Error: [0.5867492], Mejor Predicción: [1.3202507]
# mejora -25502.09333699597  R pre 6.675520942263946 R pos 25508.768857938234
#
# Valor original sin ruido (index 6): 5.1769
# Valor ruidoso original (index 6): 0.6768299509244704
# Y_test original (index 6): 1.33
# Y Predict original (index 6): 1.5621365308761597
# Y Predict optimo (index 6): 1.3431425094604492
#  Error prediccion (index 6): 0.013142509460449148
#   - Valor ajustado: 0.6768299509244704, Predicción: [0.94660527], Epsilon usado: 0.0, Error: [0.38339478]
#   - Valor ajustado: -6004.795776669967, Predicción: [0.94660527], Epsilon usado: 0.01, Error: [0.38339478]
#   - Valor ajustado: -35470.266345155986, Predicción: [0.94660527], Epsilon usado: 0.012648552168552958, Error: [0.38339478]
#   - Valor ajustado: 3636.0398281318667, Predicción: [3.3002553], Epsilon usado: 0.015998587196060583, Error: [1.9702553]
#   - Valor ajustado: -19338.72462504241, Predicción: [0.94660527], Epsilon usado: 0.020235896477251575, Error: [0.38339478]
#   - Valor ajustado: -831.4245733577866, Predicción: [0.94660527], Epsilon usado: 0.025595479226995357, Error: [0.38339478]
#   - Valor ajustado: 15954.477392470004, Predicción: [3.3002553], Epsilon usado: 0.032374575428176434, Error: [1.9702553]
#   - Valor ajustado: -11586.45200605986, Predicción: [0.94660527], Epsilon usado: 0.040949150623804255, Error: [0.38339478]
#   - Valor ajustado: 10266.59557176013, Predicción: [3.3002553], Epsilon usado: 0.05179474679231213, Error: [1.9702553]
#   - Valor ajustado: -2595.016013688751, Predicción: [0.94660527], Epsilon usado: 0.0655128556859551, Error: [0.38339478]
#   - Valor ajustado: -260.40725942988354, Predicción: [0.94660527], Epsilon usado: 0.08286427728546843, Error: [0.38339478]
#   - Valor ajustado: 1946.519034614346, Predicción: [3.3002553], Epsilon usado: 0.10481131341546858, Error: [1.9702553]
#   - Valor ajustado: 431.2671084326148, Predicción: [3.3002553], Epsilon usado: 0.13257113655901095, Error: [1.9702553]
#   - Valor ajustado: -418.77536357322344, Predicción: [0.94660527], Epsilon usado: 0.16768329368110083, Error: [0.38339478]
#   - Valor ajustado: 754.3695411334052, Predicción: [3.3002553], Epsilon usado: 0.21209508879201905, Error: [1.9702553]
#   - Valor ajustado: -262.5888371454052, Predicción: [0.94660527], Epsilon usado: 0.2682695795279726, Error: [0.38339478]
#   - Valor ajustado: -7.995827054411703, Predicción: [0.94660527], Epsilon usado: 0.33932217718953295, Error: [0.38339478]
#   - Valor ajustado: 236.8875876751785, Predicción: [3.3002553], Epsilon usado: 0.42919342601287785, Error: [1.9702553]
#   - Valor ajustado: -183.8129398235658, Predicción: [0.94660527], Epsilon usado: 0.5428675439323859, Error: [0.38339478]
#   - Valor ajustado: 121.49028927948277, Predicción: [3.3002553], Epsilon usado: 0.6866488450043002, Error: [1.9702553]
#   - Valor ajustado: 2.41485411102491, Predicción: [1.1296355], Epsilon usado: 0.8685113737513529, Error: [0.20036459]
#   - Valor ajustado: 49.49580226504616, Predicción: [3.3002553], Epsilon usado: 1.0985411419875584, Error: [1.9702553]
#   - Valor ajustado: 1.4989389666485406, Predicción: [0.93835354], Epsilon usado: 1.3894954943731375, Error: [0.3916465]
#   - Valor ajustado: -33.71609177549872, Predicción: [0.94660527], Epsilon usado: 1.757510624854793, Error: [0.38339478]
#   - Valor ajustado: -5.947862305998208, Predicción: [0.94660527], Epsilon usado: 2.2229964825261956, Error: [0.38339478]
#   - Valor ajustado: -68.22343039890262, Predicción: [0.94660527], Epsilon usado: 2.8117686979742307, Error: [0.38339478]
#   - Valor ajustado: 117.989876545471, Predicción: [3.3002553], Epsilon usado: 3.5564803062231287, Error: [1.9702553]
#   - Valor ajustado: -101.45966891308262, Predicción: [0.94660527], Epsilon usado: 4.498432668969444, Error: [0.38339478]
#   - Valor ajustado: -11.849726335437197, Predicción: [0.94660527], Epsilon usado: 5.689866029018299, Error: [0.38339478]
#   - Valor ajustado: 7.6841704565694995, Predicción: [2.4384003], Epsilon usado: 7.196856730011521, Error: [1.1084002]
#   - Valor ajustado: 6.32337596893378, Predicción: [1.9238467], Epsilon usado: 9.102981779915218, Error: [0.5938467]
#   - Valor ajustado: 11.113568882381923, Predicción: [3.3002553], Epsilon usado: 11.513953993264481, Error: [1.9702553]
#   - Valor ajustado: 13.297372142985182, Predicción: [3.3002553], Epsilon usado: 14.563484775012444, Error: [1.9702553]
#   - Valor ajustado: 2.5833345834416717, Predicción: [1.1138524], Epsilon usado: 18.420699693267164, Error: [0.21614766]
#   - Valor ajustado: 3.904552166679505, Predicción: [1.3737139], Epsilon usado: 23.29951810515372, Error: [0.04371381]
#   - Valor ajustado: 14.225521970142573, Predicción: [3.3002553], Epsilon usado: 29.4705170255181, Error: [1.9702553]
#   - Valor ajustado: -0.985661069946755, Predicción: [0.94660527], Epsilon usado: 37.27593720314942, Error: [0.38339478]
#   - Valor ajustado: 0.49864841859412967, Predicción: [0.94660527], Epsilon usado: 47.14866363457394, Error: [0.38339478]
#   - Valor ajustado: 1.4969316217624975, Predicción: [0.93835354], Epsilon usado: 59.63623316594643, Error: [0.3916465]
#   - Valor ajustado: 0.1508825827818947, Predicción: [0.94660527], Epsilon usado: 75.43120063354623, Error: [0.38339478]
#   - Valor ajustado: 2.8266310385233564, Predicción: [1.1201307], Epsilon usado: 95.40954763499944, Error: [0.20986938]
#   - Valor ajustado: 0.4442259591113388, Predicción: [0.94660527], Epsilon usado: 120.67926406393289, Error: [0.38339478]
#   - Valor ajustado: 0.884200443174773, Predicción: [0.94660527], Epsilon usado: 152.64179671752333, Error: [0.38339478]
#   - Valor ajustado: 4.738277634637075, Predicción: [1.5261678], Epsilon usado: 193.06977288832496, Error: [0.1961677]
#   - Valor ajustado: 1.5687778515783735, Predicción: [0.93835354], Epsilon usado: 244.205309454865, Error: [0.3916465]
#   - Valor ajustado: 0.6837242555123212, Predicción: [0.94660527], Epsilon usado: 308.8843596477485, Error: [0.38339478]
#   - Valor ajustado: 0.8623855056976195, Predicción: [0.94660527], Epsilon usado: 390.6939937054621, Error: [0.38339478]
#   - Valor ajustado: 0.20934365320663423, Predicción: [0.94660527], Epsilon usado: 494.17133613238383, Error: [0.38339478]
#   - Valor ajustado: 1.0434728211021047, Predicción: [0.90672785], Epsilon usado: 625.0551925273976, Error: [0.4232722]
#   - Valor ajustado: 0.7176866765383638, Predicción: [0.94660527], Epsilon usado: 790.6043210907702, Error: [0.38339478]
#   - Valor ajustado: 0.9875713663612444, Predicción: [0.90672785], Epsilon usado: 1000.0, Error: [0.4232722]
# Mejor X: 3.904552166679505 Mejor Epsilon para index 6: 23.29951810515372, Mejor Error: [0.04371381], Mejor Predicción: [1.3737139]
# mejora 3.2277222157550347  R pre 4.500070049075529 R pos 1.2723478333204947
#
# Valor original sin ruido (index 7): 4.25
# Valor ruidoso original (index 7): -7.119621391313228
# Y_test original (index 7): 1.463
# Y Predict original (index 7): 1.5002524852752686
# Y Predict optimo (index 7): 1.5241799354553223
#  Error prediccion (index 7): 0.06117993545532219
#   - Valor ajustado: -7.119621391313228, Predicción: [1.0222075], Epsilon usado: 0.0, Error: [0.44079256]
#   - Valor ajustado: 3198.950737425993, Predicción: [3.1679285], Epsilon usado: 0.01, Error: [1.7049284]
#   - Valor ajustado: 19463.349871177663, Predicción: [3.1679285], Epsilon usado: 0.012648552168552958, Error: [1.7049284]
#   - Valor ajustado: -1130.1330057786497, Predicción: [1.0222075], Epsilon usado: 0.015998587196060583, Error: [0.44079256]
#   - Valor ajustado: 5301.306431763399, Predicción: [3.1679285], Epsilon usado: 0.020235896477251575, Error: [1.7049284]
#   - Valor ajustado: -911.3870603651213, Predicción: [1.0222075], Epsilon usado: 0.025595479226995357, Error: [0.44079256]
#   - Valor ajustado: 2289.06763241159, Predicción: [3.1679285], Epsilon usado: 0.032374575428176434, Error: [1.7049284]
#   - Valor ajustado: -1240.5340647179507, Predicción: [1.0222075], Epsilon usado: 0.040949150623804255, Error: [0.44079256]
#   - Valor ajustado: 1795.6594522174876, Predicción: [3.1679285], Epsilon usado: 0.05179474679231213, Error: [1.7049284]
# ...
#   - Valor ajustado: 11.410069080988782, Predicción: [3.673612], Epsilon usado: 18.420699693267164, Error: [2.154612]
#   - Valor ajustado: 1.0058419230500455, Predicción: [1.6691189], Epsilon usado: 23.29951810515372, Error: [0.15011883]
#   - Valor ajustado: -3.229672631802561, Predicción: [1.6394254], Epsilon usado: 29.4705170255181, Error: [0.12042534]
#   - Valor ajustado: 6.1813903514543505, Predicción: [3.0936396], Epsilon usado: 37.27593720314942, Error: [1.5746396]
#   - Valor ajustado: 5.075394483609164, Predicción: [2.6156473], Epsilon usado: 47.14866363457394, Error: [1.0966473]
#   - Valor ajustado: 7.36778765077082, Predicción: [3.488001], Epsilon usado: 59.63623316594643, Error: [1.969001]
#   - Valor ajustado: 3.209492781550227, Predicción: [1.8720301], Epsilon usado: 75.43120063354623, Error: [0.3530301]
#   - Valor ajustado: 3.3686537877871747, Predicción: [1.9739512], Epsilon usado: 95.40954763499944, Error: [0.45495117]
#   - Valor ajustado: 3.87978746616984, Predicción: [1.9962881], Epsilon usado: 120.67926406393289, Error: [0.477288]
#   - Valor ajustado: 1.8088076199881136, Predicción: [1.7910286], Epsilon usado: 152.64179671752333, Error: [0.27202857]
#   - Valor ajustado: 3.890485480981053, Predicción: [2.009396], Epsilon usado: 193.06977288832496, Error: [0.49039602]
#   - Valor ajustado: 4.371861170469447, Predicción: [2.2250535], Epsilon usado: 244.205309454865, Error: [0.7060535]
#   - Valor ajustado: 5.368701973240622, Predicción: [2.701209], Epsilon usado: 308.8843596477485, Error: [1.182209]
#   - Valor ajustado: 3.3767672592109976, Predicción: [1.9739512], Epsilon usado: 390.6939937054621, Error: [0.45495117]
#   - Valor ajustado: 3.9457776907562225, Predicción: [2.0606663], Epsilon usado: 494.17133613238383, Error: [0.54166627]
#   - Valor ajustado: 4.156866400519343, Predicción: [2.2239044], Epsilon usado: 625.0551925273976, Error: [0.7049043]
#   - Valor ajustado: 4.1015171525454335, Predicción: [2.1423514], Epsilon usado: 790.6043210907702, Error: [0.62335134]
#   - Valor ajustado: 3.6144876306819778, Predicción: [1.9509152], Epsilon usado: 1000.0, Error: [0.43191516]
# Mejor X: -1908.8084742625458 Mejor Epsilon para index 47: 0.012648552168552958, Mejor Error: [0.12042534], Mejor Predicción: [1.6394254]
# mejora -1909.3046973130502  R pre 1.7454769494956124 R pos 1911.0501742625459
#
# Valor original sin ruido (index 48): 2.0395
# Valor ruidoso original (index 48): 8.671908780056903
# Y_test original (index 48): 0.679
# Y Predict original (index 48): 0.6120328903198242
# Y Predict optimo (index 48): 0.5498548746109009
#  Error prediccion (index 48): 0.12914512538909917
#   - Valor ajustado: 8.671908780056903, Predicción: [2.6819189], Epsilon usado: 0.0, Error: [2.0029187]
#   - Valor ajustado: 4997.103308160216, Predicción: [2.5635943], Epsilon usado: 0.01, Error: [1.8845943]
#   - Valor ajustado: 10444.77835479286, Predicción: [2.5635943], Epsilon usado: 0.012648552168552958, Error: [1.8845943]
#   - Valor ajustado: -14357.627755723619, Predicción: [0.53752583], Epsilon usado: 0.015998587196060583, Error: [0.14147419]
#   - Valor ajustado: 4122.851488602969, Predicción: [2.5635943], Epsilon usado: 0.020235896477251575, Error: [1.8845943]
#   - Valor ajustado: 3804.3120421509434, Predicción: [2.5635943], Epsilon usado: 0.025595479226995357, Error: [1.8845943]
#   - Valor ajustado: 2129.26224760367, Predicción: [2.5635943], Epsilon usado: 0.032374575428176434, Error: [1.8845943]
#   - Valor ajustado: 5003.383653822258, Predicción: [2.5635943], Epsilon usado: 0.040949150623804255, Error: [1.8845943]
#   - Valor ajustado: -4483.316991287406, Predicción: [0.53752583], Epsilon usado: 0.05179474679231213, Error: [0.14147419]
#   - Valor ajustado: -3264.3301443785035, Predicción: [0.53752583], Epsilon usado: 0.0655128556859551, Error: [0.14147419]
#   - Valor ajustado: 5425.175081619134, Predicción: [2.5635943], Epsilon usado: 0.08286427728546843, Error: [1.8845943]
#   - Valor ajustado: -4460.483635172638, Predicción: [0.53752583], Epsilon usado: 0.10481131341546858, Error: [0.14147419]
#   - Valor ajustado: -1057.7086716047422, Predicción: [0.53752583], Epsilon usado: 0.13257113655901095, Error: [0.14147419]
#   - Valor ajustado: -477.10593194935126, Predicción: [0.53752583], Epsilon usado: 0.16768329368110083, Error: [0.14147419]
#   - Valor ajustado: 827.8195945843675, Predicción: [2.5635943], Epsilon usado: 0.21209508879201905, Error: [1.8845943]
#   - Valor ajustado: 547.5359546317226, Predicción: [2.5635943], Epsilon usado: 0.2682695795279726, Error: [1.8845943]
#   - Valor ajustado: -265.0274821258512, Predicción: [0.53752583], Epsilon usado: 0.33932217718953295, Error: [0.14147419]
#   - Valor ajustado: 475.7919347288574, Predicción: [2.5635943], Epsilon usado: 0.42919342601287785, Error: [1.8845943]
#   - Valor ajustado: 157.13995665894734, Predicción: [2.5635943], Epsilon usado: 0.5428675439323859, Error: [1.8845943]
#   - Valor ajustado: -58.97995363606464, Predicción: [0.53752583], Epsilon usado: 0.6866488450043002, Error: [0.14147419]
#   - Valor ajustado: 51.65700155288972, Predicción: [2.5635943], Epsilon usado: 0.8685113737513529, Error: [1.8845943]
#   - Valor ajustado: 77.48321333421828, Predicción: [2.5635943], Epsilon usado: 1.0985411419875584, Error: [1.8845943]
#   - Valor ajustado: -267.6288386801989, Predicción: [0.53752583], Epsilon usado: 1.3894954943731375, Error: [0.14147419]
#   - Valor ajustado: 4.648975983297674, Predicción: [1.2015018], Epsilon usado: 1.757510624854793, Error: [0.5225018]
#   - Valor ajustado: -10.56893262112914, Predicción: [0.53752583], Epsilon usado: 2.2229964825261956, Error: [0.14147419]
#   - Valor ajustado: 16.684664600878474, Predicción: [2.5635943], Epsilon usado: 2.8117686979742307, Error: [1.8845943]
#   - Valor ajustado: -76.08799987681795, Predicción: [0.53752583], Epsilon usado: 3.5564803062231287, Error: [0.14147419]
#   - Valor ajustado: -9.470805827494466, Predicción: [0.53752583], Epsilon usado: 4.498432668969444, Error: [0.14147419]
#   - Valor ajustado: -39.18985064971079, Predicción: [0.53752583], Epsilon usado: 5.689866029018299, Error: [0.14147419]
#   - Valor ajustado: -14.208149447046733, Predicción: [0.53752583], Epsilon usado: 7.196856730011521, Error: [0.14147419]
#   - Valor ajustado: 0.3539735746842201, Predicción: [0.53752583], Epsilon usado: 9.102981779915218, Error: [0.14147419]
#   - Valor ajustado: 5.653037960954677, Predicción: [1.7053955], Epsilon usado: 11.513953993264481, Error: [1.0263954]
#   - Valor ajustado: 11.109961649324582, Predicción: [2.5635943], Epsilon usado: 14.563484775012444, Error: [1.8845943]
#   - Valor ajustado: 12.973739427419154, Predicción: [2.5635943], Epsilon usado: 18.420699693267164, Error: [1.8845943]
#   - Valor ajustado: -6.477334269781114, Predicción: [0.53752583], Epsilon usado: 23.29951810515372, Error: [0.14147419]
#   - Valor ajustado: -10.639864070079827, Predicción: [0.53752583], Epsilon usado: 29.4705170255181, Error: [0.14147419]
#   - Valor ajustado: 11.905532259995889, Predicción: [2.5635943], Epsilon usado: 37.27593720314942, Error: [1.8845943]
#   - Valor ajustado: 9.65210438190998, Predicción: [2.5635943], Epsilon usado: 47.14866363457394, Error: [1.8845943]
#   - Valor ajustado: 5.907049228043176, Predicción: [1.7029803], Epsilon usado: 59.63623316594643, Error: [1.0239803]
#   - Valor ajustado: 12.71267308398258, Predicción: [2.5635943], Epsilon usado: 75.43120063354623, Error: [1.8845943]
#   - Valor ajustado: 9.308685771986811, Predicción: [2.5635943], Epsilon usado: 95.40954763499944, Error: [1.8845943]
#   - Valor ajustado: 7.61280700778928, Predicción: [2.6751428], Epsilon usado: 120.67926406393289, Error: [1.9961427]
#   - Valor ajustado: 8.683747625542548, Predicción: [2.6819189], Epsilon usado: 152.64179671752333, Error: [2.0029187]
#   - Valor ajustado: 8.984009685458306, Predicción: [2.5635943], Epsilon usado: 193.06977288832496, Error: [1.8845943]
#   - Valor ajustado: 5.927556461178238, Predicción: [1.7071533], Epsilon usado: 244.205309454865, Error: [1.0281533]
#   - Valor ajustado: 8.77180692191932, Predicción: [2.6819189], Epsilon usado: 308.8843596477485, Error: [2.0029187]
#   - Valor ajustado: 7.2086816247417556, Predicción: [2.5999258], Epsilon usado: 390.6939937054621, Error: [1.9209257]
#   - Valor ajustado: 8.937488416156349, Predicción: [2.5635943], Epsilon usado: 494.17133613238383, Error: [1.8845943]
#   - Valor ajustado: 8.549103006121802, Predicción: [2.6819189], Epsilon usado: 625.0551925273976, Error: [2.0029187]
#   - Valor ajustado: 8.722143223380554, Predicción: [2.6819189], Epsilon usado: 790.6043210907702, Error: [2.0029187]
#   - Valor ajustado: 8.911420035129288, Predicción: [2.5635943], Epsilon usado: 1000.0, Error: [1.8845943]
# Mejor X: -14357.627755723619 Mejor Epsilon para index 48: 0.015998587196060583, Mejor Error: [0.14147419], Mejor Predicción: [0.53752583]
# mejora -14353.034846943563  R pre 6.6324087800569025 R pos 14359.66725572362
#
# Valor original sin ruido (index 49): 4.7891
# Valor ruidoso original (index 49): 5.883355406711605
# Y_test original (index 49): 3.346
# Y Predict original (index 49): 2.3885061740875244
# Y Predict optimo (index 49): 2.140230894088745
#  Error prediccion (index 49): 1.205769105911255
#   - Valor ajustado: 5.883355406711605, Predicción: [2.8195803], Epsilon usado: 0.0, Error: [0.52641964]
#   - Valor ajustado: -3742.4160315290674, Predicción: [1.6344935], Epsilon usado: 0.01, Error: [1.7115065]
#   - Valor ajustado: -4634.582462910834, Predicción: [1.6344935], Epsilon usado: 0.012648552168552958, Error: [1.7115065]
#   - Valor ajustado: -210.45378387920698, Predicción: [1.6344935], Epsilon usado: 0.015998587196060583, Error: [1.7115065]
#   - Valor ajustado: -202.7590816855339, Predicción: [1.6344935], Epsilon usado: 0.020235896477251575, Error: [1.7115065]
#   - Valor ajustado: -12077.7420469011, Predicción: [1.6344935], Epsilon usado: 0.025595479226995357, Error: [1.7115065]
#   - Valor ajustado: 1972.663336207424, Predicción: [3.5329192], Epsilon usado: 0.032374575428176434, Error: [0.18691921]
#   - Valor ajustado: 0.23750488399861158, Predicción: [1.6344935], Epsilon usado: 14.563484775012444, Error: [1.7115065]
#   - Valor ajustado: 14.938839424478028, Predicción: [3.5329192], Epsilon usado: 18.420699693267164, Error: [0.18691921]
#   - Valor ajustado: 8.211569164301615, Predicción: [3.2956145], Epsilon usado: 23.29951810515372, Error: [0.05038548]
#   - Valor ajustado: 12.489684623296915, Predicción: [3.5329192], Epsilon usado: 29.4705170255181, Error: [0.18691921]
#   - Valor ajustado: 11.686927760369688, Predicción: [3.5329192], Epsilon usado: 37.27593720314942, Error: [0.18691921]
#   - Valor ajustado: 6.281808211323277, Predicción: [2.8548784], Epsilon usado: 47.14866363457394, Error: [0.49112153]
#   - Valor ajustado: 3.0441062498138134, Predicción: [2.161862], Epsilon usado: 59.63623316594643, Error: [1.1841381]
#   - Valor ajustado: 1.756577445192148, Predicción: [1.739212], Epsilon usado: 75.43120063354623, Error: [1.6067879]
#   - Valor ajustado: 6.401797263542155, Predicción: [2.9069533], Epsilon usado: 95.40954763499944, Error: [0.43904662]
#   - Valor ajustado: 6.299935792636419, Predicción: [2.9830985], Epsilon usado: 120.67926406393289, Error: [0.36290145]
#   - Valor ajustado: 4.30814794751579, Predicción: [2.3846767], Epsilon usado: 152.64179671752333, Error: [0.96132326]
#   - Valor ajustado: 5.371923741210893, Predicción: [2.5812535], Epsilon usado: 193.06977288832496, Error: [0.7647464]
#   - Valor ajustado: 5.963012978744187, Predicción: [2.9144824], Epsilon usado: 244.205309454865, Error: [0.4315176]
#   - Valor ajustado: 5.917173058355744, Predicción: [2.8195803], Epsilon usado: 308.8843596477485, Error: [0.52641964]
#   - Valor ajustado: 5.260089477371728, Predicción: [2.5270972], Epsilon usado: 390.6939937054621, Error: [0.81890273]
#   - Valor ajustado: 5.83105706483649, Predicción: [2.8023272], Epsilon usado: 494.17133613238383, Error: [0.5436728]
#   - Valor ajustado: 6.020138281022169, Predicción: [2.7917295], Epsilon usado: 625.0551925273976, Error: [0.5542705]
#   - Valor ajustado: 5.687722658352554, Predicción: [2.7588677], Epsilon usado: 790.6043210907702, Error: [0.5871322]
#   - Valor ajustado: 5.917145132069845, Predicción: [2.8195803], Epsilon usado: 1000.0, Error: [0.52641964]
# Mejor X: 8.211569164301615 Mejor Epsilon para index 49: 23.29951810515372, Mejor Error: [0.05038548], Mejor Predicción: [3.2956145]
# mejora -2.32821375759001  R pre 1.0942554067116044 R pos 3.4224691643016145
#
# error en la entrega:
# MAE: 13.138027078018375
# RMSE: 17.759378930395194
# R2: -110.28166218236254
#
# error attack:
# MAE: 3607.681298642661
# RMSE: 8658.262054950223
# R2: -26450232.405871928
#
# Estadísticas detalladas de mejora:
# Mejora Media: 8.269423998547643
# Varianza de la Mejora: 83.18833867592546
# Número de puntos que mejoran: 24
# Mejora Máxima: 38.68812391297152
# Mejora Mínima: 0.39706039504804913
#
# Estadísticas detalladas de empeoramiento:
# Empeoramiento Medio: 6920.216529007589
# Varianza del Empeoramiento: 96122562.97821254
# Número de puntos que empeoran: 15
# Empeoramiento Máximo: 32035.557989401434
# Empeoramiento Mínimo: 0.0
