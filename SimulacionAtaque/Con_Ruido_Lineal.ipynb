# %%
import numpy as np
import ModeloBase
from ModeloBase import read_data_model, add_laplace_noise, rmse
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 

# Cargar los datos de California Housing
all_data = fetch_california_housing()
X_train_val, X_val, X_test, Y_train_val, Y_val, Y_test = read_data_model(all_data, 'MedInc')

# Entrenar el escalador con los datos train_val para evitar fuga de datos antes del entrenamiento
scaler = StandardScaler()
X_train_val_scaled = scaler.fit_transform(X_train_val)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Entrenamiento del modelo original sin ruido
model_original = LinearRegression()
model_original.fit(X_train_val_scaled, Y_train_val)
Y_predict = model_original.predict(X_test_scaled)


print(f"X_test : {X_test}")
print(f"Y_test : {Y_test}")
print(f"Y_predict : {Y_predict}")

# Introducción de ruido óptimo en los datos
epsilon_optimo = 10
np.random.seed(0)  # Semilla para reproducibilidad

X_train_val_noisy = add_laplace_noise(X_train_val, epsilon_optimo)
# Añadir ruido al conjunto de prueba
X_test_noisy = add_laplace_noise(X_test, epsilon_optimo)

scalerRuido = StandardScaler()
X_train_val_noisy_scaled = scalerRuido.fit_transform(X_train_val_noisy)
X_test_noisy_scaled = scalerRuido.transform(X_test_noisy)


# Entrenamiento del modelo con los datos ruidosos
model_noisy = LinearRegression()
model_noisy.fit(X_train_val_noisy_scaled, Y_train_val)
Y_predict_optimo = model_noisy.predict(X_test_noisy_scaled)


# Definir 20 niveles de ruido adicionales que el atacante probará usando Laplace
#np.random.seed(0)  # Semilla para reproducibilidad
additional_epsilons = np.logspace( np.log10(0.01),  np.log10(1000), num=50)

additional_epsilons = np.insert(additional_epsilons, 0, 0)

print("\nResultados del ataque para los primeros 10 valores:")

numero_muestras = 50


X_test_reducido = X_test[0:numero_muestras, 0]
X_test_noisy_reducido = X_test_noisy[0:numero_muestras, 0]

MAE_delivery = mae(X_test_reducido, X_test_noisy_reducido)
RMSE_delivery = rmse(X_test_reducido, X_test_noisy_reducido)
R2_delivery = r2(X_test_reducido, X_test_noisy_reducido)

print("\nerror en la entrega:")
print(f"MAE: {MAE_delivery}")
print(f"RMSE: {RMSE_delivery}")
print(f"R2: {R2_delivery}")


X_test_attack = np.empty(numero_muestras)

# Inicializar listas para estadísticas detalladas
improvement = []
worsening = []

# Inicializar contadores para mejoras y empeoramientos
count_improvements = 0
count_worsenings = 0


# Simulación del ataque para los primeros 10 valores
for i in range(numero_muestras):
    original_noisy_value = X_test_noisy[i,0]  # Valor con ruido
    original_value = X_test[i,0]  # Valor original sin ruido
    print(f"\nValor original sin ruido (index {i}): {original_value}")
    print(f"Valor ruidoso original (index {i}): {original_noisy_value}")
    print(f"Y_test original (index {i}): {Y_test[i]}")
    print(f"Y Predict original (index {i}): {Y_predict[i]}")
    print(f"Y Predict optimo (index {i}): {Y_predict_optimo[i]}")
    print(f" Error prediccion (index {i}): {abs(Y_test[i] - Y_predict_optimo[i])}")


    best_error = float('inf')
    best_prediction = None
    best_epsilon = None
    
    for epsilon in additional_epsilons:
        
        # Generar ruido adicional usando Laplace
        if(epsilon != 0):
            additional_noise_test = add_laplace_noise(X_test_noisy, epsilon)
        else :
            additional_noise_test = X_test_noisy.copy()

        additional_noise_test_scaled = scaler.transform(additional_noise_test)
        
        # Ajustar el valor de entrada con el nuevo ruido
        noisy_X_test_scaled =  [additional_noise_test_scaled[i,:]]  # Suponiendo que la columna de interés es la primera
        
        # Realizar la predicción para esta fila
        prediction = model_noisy.predict(noisy_X_test_scaled)
        
        # Calcular el error
        true_value = Y_test[i]
        error = abs(true_value - prediction)
        
        # Mostrar el valor con ruido añadido y la predicción correspondiente
        print(f"  - Valor ajustado: {additional_noise_test[i,0]}, Predicción: {prediction}, Epsilon usado: {epsilon}, Error: {error}")
        
        # Evaluar si este error es el mejor (menor)
        if error < best_error:
            best_error = error
            best_prediction = prediction
            best_epsilon = epsilon

            X_test_attack[i] = additional_noise_test[i,0]
    
    print(f"Mejor X: {X_test_attack[i]} Mejor Epsilon para index {i}: {best_epsilon}, Mejor Error: {best_error}, Mejor Predicción: {best_prediction}")
    error_x_noise = abs(X_test_noisy[i,0] - X_test[i,0])
    error_x_attack = abs(X_test_attack[i] - X_test[i,0])

    improvement_value = error_x_noise - error_x_attack
    improvement.append(improvement_value)
    if improvement_value > 0:
        count_improvements += 1
    else:
        worsening_value = error_x_attack - error_x_noise
        worsening.append(worsening_value)
        if worsening_value > 0:
            count_worsenings += 1

    print(f"mejora {improvement_value}  R pre {error_x_noise} R pos {error_x_attack}")


MAE_attack = mae(X_test_reducido, X_test_attack)
RMSE_attack = rmse(X_test_reducido, X_test_attack)
R2_attack = r2(X_test_reducido, X_test_attack)

print("\nerror en la entrega:")
print(f"MAE: {MAE_delivery}")
print(f"RMSE: {RMSE_delivery}")
print(f"R2: {R2_delivery}")

print("\nerror attack:")
print(f"MAE: {MAE_attack}")
print(f"RMSE: {RMSE_attack}")
print(f"R2: {R2_attack}")


# Estadísticas detalladas
improvement = np.array(improvement)
worsening = np.array(worsening)

# Filtrar solo mejoras positivas
positive_improvements = improvement[improvement > 0]

print("\nEstadísticas detalladas de mejora:")
print(f"Mejora Media: {np.mean(positive_improvements)}")
print(f"Varianza de la Mejora: {np.var(positive_improvements)}")
print(f"Número de puntos que mejoran: {count_improvements}")
print(f"Mejora Máxima: {np.max(positive_improvements)}")
print(f"Mejora Mínima: {np.min(positive_improvements)}")


print("\nEstadísticas detalladas de empeoramiento:")
print(f"Empeoramiento Medio: {np.mean(worsening)}")
print(f"Varianza del Empeoramiento: {np.var(worsening)}")
print(f"Número de puntos que empeoran: {count_worsenings}")
print(f"Empeoramiento Máximo: {np.max(worsening)}")
print(f"Empeoramiento Mínimo: {np.min(worsening)}")
# Out:
# Y_data: 20640
# y_data: 19648
# y_data: 18665
# X_test : [[   3.463         8.            6.36363636 ...    2.89800443
#     39.08       -121.04      ]
#  [   3.2891       27.            5.24033149 ...    2.42541436
#     38.05       -122.14      ]
#  [   2.096        34.            2.46689304 ...    3.37351443
#     34.05       -118.3       ]
#  ...
#  [   6.4415       15.            7.07798165 ...    2.89449541
#     33.83       -117.76      ]
#  [   2.425        17.            3.16008772 ...    1.68640351
#     33.89       -117.87      ]
#  [   3.0938       32.            4.71764706 ...    2.23921569
#     38.25       -122.04      ]]
# Y_test : [2.017 1.506 1.875 ... 3.007 1.717 1.104]
# Y_predict : [0.73379863 1.95995262 1.5841695  ... 2.77662554 1.97735153 1.9205352 ]
#
# Resultados del ataque para los primeros 10 valores:
#
# error en la entrega:
# MAE: 1.3138027078018373
# RMSE: 1.775937893039519
# R2: -0.11281662182362528
#
# Valor original sin ruido (index 0): 3.463
# Valor ruidoso original (index 0): 3.0329755358225077
# Y_test original (index 0): 2.017
# Y Predict original (index 0): 0.7337986283619296
# Y Predict optimo (index 0): 0.5787997359380683
#  Error prediccion (index 0): 1.4382002640619316
#   - Valor ajustado: 3.0329755358225077, Predicción: [0.54627064], Epsilon usado: 0.0, Error: [1.47072936]
#   - Valor ajustado: 112.35432203719704, Predicción: [14.46386726], Epsilon usado: 0.01, Error: [12.44686726]
#   - Valor ajustado: 804.0218063139603, Predicción: [102.51939669], Epsilon usado: 0.012648552168552958, Error: [100.50239669]
#   - Valor ajustado: -214.65615177268813, Predicción: [-27.16752507], Epsilon usado: 0.015998587196060583, Error: [29.18452507]
#   - Valor ajustado: 1359.0739586309915, Predicción: [173.18255817], Epsilon usado: 0.020235896477251575, Error: [171.16555817]
#   - Valor ajustado: -566.3628775344745, Predicción: [-71.94297374], Epsilon usado: 0.025595479226995357, Error: [73.95997374]
#   - Valor ajustado: 173.17139663087977, Predicción: [22.20643117], Epsilon usado: 0.032374575428176434, Error: [20.18943117]
#   - Valor ajustado: -519.2848471720231, Predicción: [-65.94951448], Epsilon usado: 0.040949150623804255, Error: [67.96651448]
#   - Valor ajustado: -69.02384224756274, Predicción: [-8.62721429], Epsilon usado: 0.05179474679231213, Error: [10.64421429]
#   - Valor ajustado: 4.6414601470811805, Predicción: [0.75104528], Epsilon usado: 0.0655128556859551, Error: [1.26595472]
#   - Valor ajustado: -130.42084868211344, Predicción: [-16.44360877], Epsilon usado: 0.08286427728546843, Error: [18.46060877]
#   - Valor ajustado: -178.65924038513535, Predicción: [-22.58479253], Epsilon usado: 0.10481131341546858, Error: [24.60179253]
#   - Valor ajustado: 44.44614703846293, Predicción: [5.8185421], Epsilon usado: 0.13257113655901095, Error: [3.8015421]
#   - Valor ajustado: 255.58697925710754, Predicción: [32.69868059], Epsilon usado: 0.16768329368110083, Error: [30.68168059]
#   - Valor ajustado: -33.95652966029721, Predicción: [-4.16282808], Epsilon usado: 0.21209508879201905, Error: [6.17982808]
#   - Valor ajustado: 52.869523418372886, Predicción: [6.89091414], Epsilon usado: 0.2682695795279726, Error: [4.87391414]
#   - Valor ajustado: 76.15426846123418, Predicción: [9.85527288], Epsilon usado: 0.33932217718953295, Error: [7.83827288]
#   - Valor ajustado: -16.776578096781737, Predicción: [-1.97566479], Epsilon usado: 0.42919342601287785, Error: [3.99266479]
#   - Valor ajustado: -15.99027538455491, Predicción: [-1.87556134], Epsilon usado: 0.5428675439323859, Error: [3.89256134]
#   - Valor ajustado: 75.95809908694481, Predicción: [9.83029874], Epsilon usado: 0.6866488450043002, Error: [7.81329874]
#   - Valor ajustado: 51.72222219158662, Predicción: [6.74485231], Epsilon usado: 0.8685113737513529, Error: [4.72785231]
#   - Valor ajustado: -1.586067041381825, Predicción: [-0.04177528], Epsilon usado: 1.0985411419875584, Error: [2.05877528]
#   - Valor ajustado: 20.402312132480336, Predicción: [2.75754435], Epsilon usado: 1.3894954943731375, Error: [0.74054435]
#   - Valor ajustado: -20.337602939507008, Predicción: [-2.42901548], Epsilon usado: 1.757510624854793, Error: [4.44601548]
#   - Valor ajustado: 4.6918467382653875, Predicción: [0.75745995], Epsilon usado: 2.2229964825261956, Error: [1.25954005]
#   - Valor ajustado: 1.9294986630226145, Predicción: [0.40578805], Epsilon usado: 2.8117686979742307, Error: [1.61121195]
#   - Valor ajustado: 4.197477932101371, Predicción: [0.69452233], Epsilon usado: 3.5564803062231287, Error: [1.32247767]
#   - Valor ajustado: 3.867187427603705, Predicción: [0.65247336], Epsilon usado: 4.498432668969444, Error: [1.36452664]
#   - Valor ajustado: -8.479977374778926, Predicción: [-0.91943245], Epsilon usado: 5.689866029018299, Error: [2.93643245]
#   - Valor ajustado: 1.0405325529753624, Predicción: [0.29261462], Epsilon usado: 7.196856730011521, Error: [1.72438538]
#   - Valor ajustado: 5.545600838639762, Predicción: [0.86615057], Epsilon usado: 9.102981779915218, Error: [1.15084943]
#   - Valor ajustado: 2.8896840060338453, Predicción: [0.52802833], Epsilon usado: 11.513953993264481, Error: [1.48897167]
#   - Valor ajustado: 3.3375180041850974, Predicción: [0.58504165], Epsilon usado: 14.563484775012444, Error: [1.43195835]
#   - Valor ajustado: 2.7485340051400744, Predicción: [0.51005866], Epsilon usado: 18.420699693267164, Error: [1.50694134]
#   - Valor ajustado: 3.490132497917693, Predicción: [0.60447085], Epsilon usado: 23.29951810515372, Error: [1.41252915]
#   - Valor ajustado: 3.491478963439925, Predicción: [0.60464227], Epsilon usado: 29.4705170255181, Error: [1.41235773]
#   - Valor ajustado: 3.6021289499060867, Predicción: [0.61872902], Epsilon usado: 37.27593720314942, Error: [1.39827098]
#   - Valor ajustado: 3.0254934289094404, Predicción: [0.5453181], Epsilon usado: 47.14866363457394, Error: [1.4716819]
#   - Valor ajustado: 3.281108683597998, Predicción: [0.57786023], Epsilon usado: 59.63623316594643, Error: [1.43913977]
#   - Valor ajustado: 3.2057960591482724, Predicción: [0.56827225], Epsilon usado: 75.43120063354623, Error: [1.44872775]
#   - Valor ajustado: 3.084111040561671, Predicción: [0.55278065], Epsilon usado: 95.40954763499944, Error: [1.46421935]
#   - Valor ajustado: 2.914902344356394, Predicción: [0.53123885], Epsilon usado: 120.67926406393289, Error: [1.48576115]
#   - Valor ajustado: 2.5309743036042214, Predicción: [0.48236134], Epsilon usado: 152.64179671752333, Error: [1.53463866]
#   - Valor ajustado: 2.9916624222699877, Predicción: [0.5410111], Epsilon usado: 193.06977288832496, Error: [1.4759889]
#   - Valor ajustado: 3.257000389387883, Predicción: [0.57479103], Epsilon usado: 244.205309454865, Error: [1.44220897]
#   - Valor ajustado: 3.0729967700204583, Predicción: [0.5513657], Epsilon usado: 308.8843596477485, Error: [1.4656343]
#   - Valor ajustado: 3.170356073681874, Predicción: [0.56376042], Epsilon usado: 390.6939937054621, Error: [1.45323958]
#   - Valor ajustado: 2.991702337596028, Predicción: [0.54101618], Epsilon usado: 494.17133613238383, Error: [1.47598382]
#   - Valor ajustado: 3.0419425680710885, Predicción: [0.54741222], Epsilon usado: 625.0551925273976, Error: [1.46958778]
#   - Valor ajustado: 3.02337388338904, Predicción: [0.54504826], Epsilon usado: 790.6043210907702, Error: [1.47195174]
#   - Valor ajustado: 3.032841407901368, Predicción: [0.54625356], Epsilon usado: 1000.0, Error: [1.47074644]
# Mejor X: 20.402312132480336 Mejor Epsilon para index 0: 1.3894954943731375, Mejor Error: [0.74054435], Mejor Predicción: [2.75754435]
# mejora -16.509287668302843  R pre 0.4300244641774924 R pos 16.939312132480335
#
# Valor original sin ruido (index 1): 3.2891
# Valor ruidoso original (index 1): -0.9147561790958618
# Y_test original (index 1): 1.506
# Y Predict original (index 1): 1.9599526228200643
# Y Predict optimo (index 1): 1.8020863764146535
#  Error prediccion (index 1): 0.2960863764146535
#   - Valor ajustado: -0.9147561790958618, Predicción: [1.5940951], Epsilon usado: 0.0, Error: [0.0880951]
#   - Valor ajustado: 4330.6213011811515, Predicción: [553.03782989], Epsilon usado: 0.01, Error: [551.53182989]
#   - Valor ajustado: 2411.967024593073, Predicción: [308.77577919], Epsilon usado: 0.012648552168552958, Error: [307.26977919]
#   - Valor ajustado: -195.30583575045407, Predicción: [-23.15364832], Epsilon usado: 0.015998587196060583, Error: [24.65964832]
#   - Valor ajustado: 1595.1067530883638, Predicción: [204.78207512], Epsilon usado: 0.020235896477251575, Error: [203.27607512]
#   - Valor ajustado: -463.45800117819357, Predicción: [-57.2918454], Epsilon usado: 0.025595479226995357, Error: [58.7978454]
#   - Valor ajustado: 1311.474327238601, Predicción: [168.67310081], Epsilon usado: 0.032374575428176434, Error: [167.16710081]
#   - Valor ajustado: 112.50998993001626, Predicción: [16.03409162], Epsilon usado: 0.040949150623804255, Error: [14.52809162]
#   - Valor ajustado: 559.0152309220764, Predicción: [72.87824908], Epsilon usado: 0.05179474679231213, Error: [71.37224908]
#   - Valor ajustado: 433.57204177598885, Predicción: [56.90819601], Epsilon usado: 0.0655128556859551, Error: [55.40219601]
#   - Valor ajustado: -512.825352942003, Predicción: [-63.57675599], Epsilon usado: 0.08286427728546843, Error: [65.08275599]
#   - Valor ajustado: 45.071186826231305, Predicción: [7.44852175], Epsilon usado: 0.10481131341546858, Error: [5.94252175]
#   - Valor ajustado: 246.34209239202673, Predicción: [33.07212927], Epsilon usado: 0.13257113655901095, Error: [31.56612927]
#   - Valor ajustado: -516.8998413260686, Predicción: [-64.09547523], Epsilon usado: 0.16768329368110083, Error: [65.60147523]
#   - Valor ajustado: 75.85756449207348, Predicción: [11.36790621], Epsilon usado: 0.21209508879201905, Error: [9.86190621]
#   - Valor ajustado: -7.665880872739704, Predicción: [0.73461583], Epsilon usado: 0.2682695795279726, Error: [0.77138417]
#   - Valor ajustado: -106.5061353275742, Predicción: [-11.84864293], Epsilon usado: 0.33932217718953295, Error: [13.35464293]
#   - Valor ajustado: 1.9938977711873154, Predicción: [1.96439306], Epsilon usado: 0.42919342601287785, Error: [0.45839306]
#   - Valor ajustado: -39.62147317359944, Predicción: [-3.33362022], Epsilon usado: 0.5428675439323859, Error: [4.83962022]
#   - Valor ajustado: -63.34697448334882, Predicción: [-6.35409122], Epsilon usado: 0.6866488450043002, Error: [7.86009122]
#   - Valor ajustado: 2.2762363790775377, Predicción: [2.00033732], Epsilon usado: 0.8685113737513529, Error: [0.49433732]
#   - Valor ajustado: 6.81990026413745, Predicción: [2.57878685], Epsilon usado: 1.0985411419875584, Error: [1.07278685]
#   - Valor ajustado: -3.8299906474589713, Predicción: [1.22295937], Epsilon usado: 1.3894954943731375, Error: [0.28304063]
#   - Valor ajustado: -14.229639839368032, Predicción: [-0.10101008], Epsilon usado: 1.757510624854793, Error: [1.60701008]
#   - Valor ajustado: -9.278653938128985, Predicción: [0.52929523], Epsilon usado: 2.2229964825261956, Error: [0.97670477]
#   - Valor ajustado: 3.3282370579213034, Predicción: [2.13426653], Epsilon usado: 2.8117686979742307, Error: [0.62826653]
#   - Valor ajustado: -0.07535463618089566, Predicción: [1.70095851], Epsilon usado: 3.5564803062231287, Error: [0.19495851]
#   - Valor ajustado: 3.6102753891794674, Predicción: [2.17017256], Epsilon usado: 4.498432668969444, Error: [0.66417256]
#   - Valor ajustado: -2.345131982298348, Predicción: [1.41199531], Epsilon usado: 5.689866029018299, Error: [0.09400469]
#   - Valor ajustado: 2.384027215194038, Predicción: [2.01406007], Epsilon usado: 7.196856730011521, Error: [0.50806007]
#   - Valor ajustado: -0.2080438113901255, Predicción: [1.68406598], Epsilon usado: 9.102981779915218, Error: [0.17806598]
#   - Valor ajustado: -1.802369081762103, Predicción: [1.48109394], Epsilon usado: 11.513953993264481, Error: [0.02490606]
#   - Valor ajustado: -0.7750523613648134, Predicción: [1.61188066], Epsilon usado: 14.563484775012444, Error: [0.10588066]
#   - Valor ajustado: -4.673753457277989, Predicción: [1.11554073], Epsilon usado: 18.420699693267164, Error: [0.39045927]
#   - Valor ajustado: -0.8446646792704094, Predicción: [1.60301838], Epsilon usado: 23.29951810515372, Error: [0.09701838]
#   - Valor ajustado: -0.6754772894416663, Predicción: [1.62455746], Epsilon usado: 29.4705170255181, Error: [0.11855746]
#   - Valor ajustado: -1.2762584424621863, Predicción: [1.54807259], Epsilon usado: 37.27593720314942, Error: [0.04207259]
#   - Valor ajustado: -0.6757661846253971, Predicción: [1.62452069], Epsilon usado: 47.14866363457394, Error: [0.11852069]
#   - Valor ajustado: -0.8107445660234164, Predicción: [1.60733672], Epsilon usado: 59.63623316594643, Error: [0.10133672]
#   - Valor ajustado: -0.6711429007878476, Predicción: [1.62510927], Epsilon usado: 75.43120063354623, Error: [0.11910927]
#   - Valor ajustado: -1.3363429248536842, Predicción: [1.54042329], Epsilon usado: 95.40954763499944, Error: [0.03442329]
#   - Valor ajustado: -0.6400453572579765, Predicción: [1.62906827], Epsilon usado: 120.67926406393289, Error: [0.12306827]
#   - Valor ajustado: -0.8677135262717075, Predicción: [1.60008405], Epsilon usado: 152.64179671752333, Error: [0.09408405]
#   - Valor ajustado: -1.0012017853311517, Predicción: [1.58308979], Epsilon usado: 193.06977288832496, Error: [0.07708979]
#   - Valor ajustado: -1.012545882025484, Predicción: [1.58164558], Epsilon usado: 244.205309454865, Error: [0.07564558]
#   - Valor ajustado: -1.1752039965454872, Predicción: [1.56093773], Epsilon usado: 308.8843596477485, Error: [0.05493773]
#   - Valor ajustado: -0.8856906978844608, Predicción: [1.5977954], Epsilon usado: 390.6939937054621, Error: [0.0917954]
#   - Valor ajustado: -0.9127782810976522, Predicción: [1.5943469], Epsilon usado: 494.17133613238383, Error: [0.0883469]
#   - Valor ajustado: -0.9082161304191668, Predicción: [1.5949277], Epsilon usado: 625.0551925273976, Error: [0.0889277]
#   - Valor ajustado: -0.8767232896893292, Predicción: [1.59893703], Epsilon usado: 790.6043210907702, Error: [0.09293703]
#   - Valor ajustado: -0.9155509728096106, Predicción: [1.59399391], Epsilon usado: 1000.0, Error: [0.08799391]
# Mejor X: -1.802369081762103 Mejor Epsilon para index 1: 11.513953993264481, Mejor Error: [0.02490606], Mejor Predicción: [1.48109394]
# mejora -0.8876129026662412  R pre 4.203856179095862 R pos 5.091469081762103
#
# Valor original sin ruido (index 2): 2.096
# Valor ruidoso original (index 2): 6.20817595645841
# Y_test original (index 2): 1.875
# Y Predict original (index 2): 1.5841694985320065
# Y Predict optimo (index 2): 1.648045726823452
#  Error prediccion (index 2): 0.22695427317654793
#   - Valor ajustado: 6.20817595645841, Predicción: [1.75664263], Epsilon usado: 0.0, Error: [0.11835737]
#   - Valor ajustado: -219.04363830207612, Predicción: [-26.91995156], Epsilon usado: 0.01, Error: [28.79495156]
#   - Valor ajustado: 719.3296753126508, Predicción: [92.5434623], Epsilon usado: 0.012648552168552958, Error: [90.6684623]
#   - Valor ajustado: 88.70006172429153, Predicción: [12.25860613], Epsilon usado: 0.015998587196060583, Error: [10.38360613]
#   - Valor ajustado: 1099.0641937472044, Predicción: [140.8871026], Epsilon usado: 0.020235896477251575, Error: [139.0121026]
#   - Valor ajustado: -1606.1109574254642, Predicción: [-203.50617241], Epsilon usado: 0.025595479226995357, Error: [205.38117241]
#   - Valor ajustado: 6.559331862011156, Predicción: [1.80134795], Epsilon usado: 0.032374575428176434, Error: [0.07365205]
#   - Valor ajustado: -1562.6028279148168, Predicción: [-197.96719384], Epsilon usado: 0.040949150623804255, Error: [199.84219384]
#   - Valor ajustado: 123.46705723648131, Predicción: [16.68475925], Epsilon usado: 0.05179474679231213, Error: [14.80975925]
#   - Valor ajustado: -151.12279779468327, Predicción: [-18.27301397], Epsilon usado: 0.0655128556859551, Error: [20.14801397]
#   - Valor ajustado: 27.52662123979559, Predicción: [4.47067362], Epsilon usado: 0.08286427728546843, Error: [2.59567362]
#   - Valor ajustado: -425.4803647894748, Predicción: [-53.20121482], Epsilon usado: 0.10481131341546858, Error: [55.07621482]
#   - Valor ajustado: 58.3032505552666, Predicción: [8.38881702], Epsilon usado: 0.13257113655901095, Error: [6.51381702]
#   - Valor ajustado: 96.85940522222839, Predicción: [13.29736439], Epsilon usado: 0.16768329368110083, Error: [11.42236439]
#   - Valor ajustado: -111.95877135809701, Predicción: [-13.28707902], Epsilon usado: 0.21209508879201905, Error: [15.16207902]
#   - Valor ajustado: -3.24413988687839, Predicción: [0.55327729], Epsilon usado: 0.2682695795279726, Error: [1.32172271]
#   - Valor ajustado: -29.426135202373857, Predicción: [-2.77992763], Epsilon usado: 0.33932217718953295, Error: [4.65492763]
#   - Valor ajustado: 50.852524819337475, Predicción: [7.44027221], Epsilon usado: 0.42919342601287785, Error: [5.56527221]
#   - Valor ajustado: 30.829434886371125, Predicción: [4.89115168], Epsilon usado: 0.5428675439323859, Error: [3.01615168]
#   - Valor ajustado: 17.010017345802446, Predicción: [3.13181478], Epsilon usado: 0.6866488450043002, Error: [1.25681478]
#   - Valor ajustado: -15.00375848012874, Predicción: [-0.94382857], Epsilon usado: 0.8685113737513529, Error: [2.81882857]
#   - Valor ajustado: 11.68296952527952, Predicción: [2.45363339], Epsilon usado: 1.0985411419875584, Error: [0.57863339]
#   - Valor ajustado: -12.227256418537417, Predicción: [-0.59035473], Epsilon usado: 1.3894954943731375, Error: [2.46535473]
#   - Valor ajustado: 1.9090378122332279, Predicción: [1.20932344], Epsilon usado: 1.757510624854793, Error: [0.66567656]
#   - Valor ajustado: -2.9553014150721015, Predicción: [0.59004904], Epsilon usado: 2.2229964825261956, Error: [1.28495096]
#   - Valor ajustado: 5.29869254201323, Predicción: [1.64085716], Epsilon usado: 2.8117686979742307, Error: [0.23414284]
#   - Valor ajustado: 9.882887671402331, Predicción: [2.22446668], Epsilon usado: 3.5564803062231287, Error: [0.34946668]
#   - Valor ajustado: 2.318804633803711, Predicción: [1.26149046], Epsilon usado: 4.498432668969444, Error: [0.61350954]
#   - Valor ajustado: 20.038308069167464, Predicción: [3.51734359], Epsilon usado: 5.689866029018299, Error: [1.64234359]
#   - Valor ajustado: 2.88294565937396, Predicción: [1.33331072], Epsilon usado: 7.196856730011521, Error: [0.54168928]
#   - Valor ajustado: 6.231531716741095, Predicción: [1.75961603], Epsilon usado: 9.102981779915218, Error: [0.11538397]
#   - Valor ajustado: 1.3890332575272097, Predicción: [1.14312216], Epsilon usado: 11.513953993264481, Error: [0.73187784]
#   - Valor ajustado: 7.78020235621428, Predicción: [1.95677581], Epsilon usado: 14.563484775012444, Error: [0.08177581]
#   - Valor ajustado: 6.143993976783156, Predicción: [1.74847168], Epsilon usado: 18.420699693267164, Error: [0.12652832]
#   - Valor ajustado: 6.1181558696756, Predicción: [1.74518226], Epsilon usado: 23.29951810515372, Error: [0.12981774]
#   - Valor ajustado: 5.979121503309974, Predicción: [1.72748192], Epsilon usado: 29.4705170255181, Error: [0.14751808]
#   - Valor ajustado: 6.098416630142488, Predicción: [1.74266927], Epsilon usado: 37.27593720314942, Error: [0.13233073]
#   - Valor ajustado: 6.676878984068268, Predicción: [1.81631276], Epsilon usado: 47.14866363457394, Error: [0.05868724]
#   - Valor ajustado: 5.454514482467397, Predicción: [1.6606947], Epsilon usado: 59.63623316594643, Error: [0.2143053]
#   - Valor ajustado: 5.958158586491434, Predicción: [1.72481315], Epsilon usado: 75.43120063354623, Error: [0.15018685]
#   - Valor ajustado: 6.050053145627762, Predicción: [1.73651216], Epsilon usado: 95.40954763499944, Error: [0.13848784]
#   - Valor ajustado: 6.10529742743347, Predicción: [1.74354526], Epsilon usado: 120.67926406393289, Error: [0.13145474]
#   - Valor ajustado: 6.4774388793286155, Predicción: [1.79092223], Epsilon usado: 152.64179671752333, Error: [0.08407777]
#   - Valor ajustado: 6.450385279294212, Predicción: [1.78747807], Epsilon usado: 193.06977288832496, Error: [0.08752193]
#   - Valor ajustado: 5.998495254809812, Predicción: [1.72994838], Epsilon usado: 244.205309454865, Error: [0.14505162]
#   - Valor ajustado: 6.135583317278147, Predicción: [1.74740093], Epsilon usado: 308.8843596477485, Error: [0.12759907]
#   - Valor ajustado: 6.223356944401564, Predicción: [1.7585753], Epsilon usado: 390.6939937054621, Error: [0.1164247]
#   - Valor ajustado: 6.155599095263798, Predicción: [1.74994912], Epsilon usado: 494.17133613238383, Error: [0.12505088]
#   - Valor ajustado: 6.197864362412552, Predicción: [1.75532987], Epsilon usado: 625.0551925273976, Error: [0.11967013]
#   - Valor ajustado: 6.2287889667773335, Predicción: [1.75926685], Epsilon usado: 790.6043210907702, Error: [0.11573315]
#   - Valor ajustado: 6.192102810755873, Predicción: [1.75459637], Epsilon usado: 1000.0, Error: [0.12040363]
# Mejor X: 6.676878984068268 Mejor Epsilon para index 2: 47.14866363457394, Mejor Error: [0.05868724], Mejor Predicción: [1.81631276]
# mejora -0.46870302760985805  R pre 4.11217595645841 R pos 4.580878984068268
#
# Valor original sin ruido (index 3): 4.875
# Valor ruidoso original (index 3): 4.657674483460132
# Y_test original (index 3): 2.495
# Y Predict original (index 3): 2.78859376285354
# Y Predict optimo (index 3): 2.4896313775602277
#  Error prediccion (index 3): 0.00536862243977243
#   - Valor ajustado: 4.657674483460132, Predicción: [2.52931418], Epsilon usado: 0.0, Error: [0.03431418]
#   - Valor ajustado: -2176.840528494359, Predicción: [-275.19514674], Epsilon usado: 0.01, Error: [277.69014674]
#   - Valor ajustado: 182.72818560968483, Predicción: [25.19930155], Epsilon usado: 0.012648552168552958, Error: [22.70430155]
#   - Valor ajustado: -160.3784221924294, Predicción: [-18.48127429], Epsilon usado: 0.015998587196060583, Error: [20.97627429]
#   - Valor ajustado: 4025.6602226622995, Predicción: [514.43932333], Epsilon usado: 0.020235896477251575, Error: [511.94432333]
#   - Valor ajustado: -364.5269285733034, Predicción: [-44.47122642], Epsilon usado: 0.025595479226995357, Error: [46.96622642]
#   - Valor ajustado: 294.945794328584, Predicción: [39.48561856], Epsilon usado: 0.032374575428176434, Error: [36.99061856]
#   - Valor ajustado: 142.13952150855593, Predicción: [20.03199734], Epsilon usado: 0.040949150623804255, Error: [17.53699734]
#   - Valor ajustado: 157.3987932446546, Predicción: [21.9746407], Epsilon usado: 0.05179474679231213, Error: [19.4796407]
#   - Valor ajustado: 1353.637593514767, Predicción: [174.26666436], Epsilon usado: 0.0655128556859551, Error: [171.77166436]
#   - Valor ajustado: -241.38614144521387, Predicción: [-28.79428996], Epsilon usado: 0.08286427728546843, Error: [31.28928996]
#   - Valor ajustado: 274.3416117836529, Predicción: [36.86251968], Epsilon usado: 0.10481131341546858, Error: [34.36751968]
#   - Valor ajustado: 57.21997785643873, Predicción: [9.22097102], Epsilon usado: 0.13257113655901095, Error: [6.72597102]
#   - Valor ajustado: 115.81748499883979, Predicción: [16.68096391], Epsilon usado: 0.16768329368110083, Error: [14.18596391]
#   - Valor ajustado: 148.29575790031168, Predicción: [20.81574193], Epsilon usado: 0.21209508879201905, Error: [18.32074193]
#   - Valor ajustado: -156.9314553996628, Predicción: [-18.04244422], Epsilon usado: 0.2682695795279726, Error: [20.53744422]
#   - Valor ajustado: 103.54798015594008, Predicción: [15.11894492], Epsilon usado: 0.33932217718953295, Error: [12.62394492]
#   - Valor ajustado: 44.54000645775695, Predicción: [7.60669592], Epsilon usado: 0.42919342601287785, Error: [5.11169592]
#   - Valor ajustado: 1.7782988589426245, Predicción: [2.16274361], Epsilon usado: 0.5428675439323859, Error: [0.33225639]
#   - Valor ajustado: 14.09438908323424, Predicción: [3.73069334], Epsilon usado: 0.6866488450043002, Error: [1.23569334]
#   - Valor ajustado: -12.448526601633507, Predicción: [0.35153999], Epsilon usado: 0.8685113737513529, Error: [2.14346001]
#   - Valor ajustado: -26.23776091876164, Predicción: [-1.40395431], Epsilon usado: 1.0985411419875584, Error: [3.89895431]
#   - Valor ajustado: 13.504345627246202, Predicción: [3.65557547], Epsilon usado: 1.3894954943731375, Error: [1.16057547]
#   - Valor ajustado: -13.503614727003395, Predicción: [0.21721773], Epsilon usado: 1.757510624854793, Error: [2.27778227]
#   - Valor ajustado: 5.973285380959118, Predicción: [2.69680335], Epsilon usado: 2.2229964825261956, Error: [0.20180335]
#   - Valor ajustado: 9.411218925204384, Predicción: [3.1344834], Epsilon usado: 2.8117686979742307, Error: [0.6394834]
#   - Valor ajustado: 1.9614137147078088, Predicción: [2.18605579], Epsilon usado: 3.5564803062231287, Error: [0.30894421]
#   - Valor ajustado: 3.3034273907927023, Predicción: [2.35690627], Epsilon usado: 4.498432668969444, Error: [0.13809373]
#   - Valor ajustado: 7.1665149068497955, Predicción: [2.84871227], Epsilon usado: 5.689866029018299, Error: [0.35371227]
#   - Valor ajustado: -3.356305911707678, Predicción: [1.50906196], Epsilon usado: 7.196856730011521, Error: [0.98593804]
#   - Valor ajustado: 5.273541338535736, Predicción: [2.6077196], Epsilon usado: 9.102981779915218, Error: [0.1127196]
#   - Valor ajustado: 1.6168863695161644, Predicción: [2.14219434], Epsilon usado: 11.513953993264481, Error: [0.35280566]
#   - Valor ajustado: 2.8980579004467444, Predicción: [2.30529907], Epsilon usado: 14.563484775012444, Error: [0.18970093]
#   - Valor ajustado: 2.4810165649576352, Predicción: [2.25220593], Epsilon usado: 18.420699693267164, Error: [0.24279407]
#   - Valor ajustado: 4.416140645074412, Predicción: [2.49856474], Epsilon usado: 23.29951810515372, Error: [0.00356474]
#   - Valor ajustado: 3.8076702669597493, Predicción: [2.42110095], Epsilon usado: 29.4705170255181, Error: [0.07389905]
#   - Valor ajustado: 4.02762730648546, Predicción: [2.44910347], Epsilon usado: 37.27593720314942, Error: [0.04589653]
#   - Valor ajustado: 4.632004581795778, Predicción: [2.52604617], Epsilon usado: 47.14866363457394, Error: [0.03104617]
#   - Valor ajustado: 4.75979090158804, Predicción: [2.54231452], Epsilon usado: 59.63623316594643, Error: [0.04731452]
#   - Valor ajustado: 4.381246713031446, Predicción: [2.49412242], Epsilon usado: 75.43120063354623, Error: [0.00087758]
#   - Valor ajustado: 4.3799545043908426, Predicción: [2.49395791], Epsilon usado: 95.40954763499944, Error: [0.00104209]
#   - Valor ajustado: 4.606829388400352, Predicción: [2.52284114], Epsilon usado: 120.67926406393289, Error: [0.02784114]
#   - Valor ajustado: 4.593943061380446, Predicción: [2.52120059], Epsilon usado: 152.64179671752333, Error: [0.02620059]
#   - Valor ajustado: 4.850214603248317, Predicción: [2.55382628], Epsilon usado: 193.06977288832496, Error: [0.05882628]
#   - Valor ajustado: 4.669319921675513, Predicción: [2.53079675], Epsilon usado: 244.205309454865, Error: [0.03579675]
#   - Valor ajustado: 4.666384064085822, Predicción: [2.53042299], Epsilon usado: 308.8843596477485, Error: [0.03542299]
#   - Valor ajustado: 4.658254595295774, Predicción: [2.52938803], Epsilon usado: 390.6939937054621, Error: [0.03438803]
#   - Valor ajustado: 4.750597200407856, Predicción: [2.54114408], Epsilon usado: 494.17133613238383, Error: [0.04614408]
#   - Valor ajustado: 4.606319990593535, Predicción: [2.52277629], Epsilon usado: 625.0551925273976, Error: [0.02777629]
#   - Valor ajustado: 4.6785597749285515, Predicción: [2.53197307], Epsilon usado: 790.6043210907702, Error: [0.03697307]
#   - Valor ajustado: 4.682218800834421, Predicción: [2.53243889], Epsilon usado: 1000.0, Error: [0.03743889]
# Mejor X: 4.381246713031446 Mejor Epsilon para index 3: 75.43120063354623, Mejor Error: [0.00087758], Mejor Predicción: [2.49412242]
# mejora -0.27642777042868527  R pre 0.21732551653986842 R pos 0.4937532869685537
#
# Valor original sin ruido (index 4): 4.4167
# Valor ruidoso original (index 4): 2.8293307294113728
# Y_test original (index 4): 1.58
# Y Predict original (index 4): 2.2321085699258942
# Y Predict optimo (index 4): 1.6686510910702481
#  Error prediccion (index 4): 0.08865109107024804
#   - Valor ajustado: 2.8293307294113728, Predicción: [1.62707073], Epsilon usado: 0.0, Error: [0.04707073]
#   - Valor ajustado: -5680.7154490579505, Predicción: [-721.93960832], Epsilon usado: 0.01, Error: [723.51960832]
#   - Valor ajustado: 473.05229972850015, Predicción: [61.49070958], Epsilon usado: 0.012648552168552958, Error: [59.91070958]
#   - Valor ajustado: 748.2754481664908, Predicción: [96.52910678], Epsilon usado: 0.015998587196060583, Error: [94.94910678]
#   - Valor ajustado: 1148.3251564902978, Predicción: [147.45905457], Epsilon usado: 0.020235896477251575, Error: [145.87905457]
#   - Valor ajustado: 393.00457007463825, Predicción: [51.29990927], Epsilon usado: 0.025595479226995357, Error: [49.71990927]
#   - Valor ajustado: 184.5595009773721, Predicción: [24.76296582], Epsilon usado: 0.032374575428176434, Error: [23.18296582]
#   - Valor ajustado: 283.1541455523366, Predicción: [37.31495622], Epsilon usado: 0.040949150623804255, Error: [35.73495622]
#   - Valor ajustado: -10.901879267703103, Predicción: [-0.12103655], Epsilon usado: 0.05179474679231213, Error: [1.70103655]
#   - Valor ajustado: 125.23388679839653, Predicción: [17.21027831], Epsilon usado: 0.0655128556859551, Error: [15.63027831]
#   - Valor ajustado: -108.04451932476205, Predicción: [-12.48817365], Epsilon usado: 0.08286427728546843, Error: [14.06817365]
#   - Valor ajustado: -20.205046564736065, Predicción: [-1.30541393], Epsilon usado: 0.10481131341546858, Error: [2.88541393]
#   - Valor ajustado: -6.551788178168971, Predicción: [0.4327694], Epsilon usado: 0.13257113655901095, Error: [1.1472306]
#   - Valor ajustado: 46.10184083834096, Predicción: [7.13605282], Epsilon usado: 0.16768329368110083, Error: [5.55605282]
#   - Valor ajustado: 48.166655580864074, Predicción: [7.39892242], Epsilon usado: 0.21209508879201905, Error: [5.81892242]
#   - Valor ajustado: -119.53086641191953, Predicción: [-13.95048957], Epsilon usado: 0.2682695795279726, Error: [15.53048957]
#   - Valor ajustado: 13.82965543433434, Predicción: [3.0275116], Epsilon usado: 0.33932217718953295, Error: [1.4475116]
#   - Valor ajustado: -52.32892111243442, Predicción: [-5.39507384], Epsilon usado: 0.42919342601287785, Error: [6.97507384]
#   - Valor ajustado: 38.81665516701484, Predicción: [6.20858277], Epsilon usado: 0.5428675439323859, Error: [4.62858277]
#   - Valor ajustado: 24.04192420157937, Predicción: [4.32762582], Epsilon usado: 0.6866488450043002, Error: [2.74762582]
#   - Valor ajustado: -3.9113218773127825, Predicción: [0.76892466], Epsilon usado: 0.8685113737513529, Error: [0.81107534]
#   - Valor ajustado: 16.419794528417547, Predicción: [3.35725974], Epsilon usado: 1.0985411419875584, Error: [1.77725974]
#   - Valor ajustado: 1.8831394073733179, Predicción: [1.50661201], Epsilon usado: 1.3894954943731375, Error: [0.07338799]
#   - Valor ajustado: 2.2488239844934945, Predicción: [1.55316697], Epsilon usado: 1.757510624854793, Error: [0.02683303]
#   - Valor ajustado: 1.2067621407880316, Predicción: [1.42050306], Epsilon usado: 2.2229964825261956, Error: [0.15949694]
#   - Valor ajustado: 12.98322084717091, Predicción: [2.91975282], Epsilon usado: 2.8117686979742307, Error: [1.33975282]
#   - Valor ajustado: 2.1874398112542517, Predicción: [1.54535221], Epsilon usado: 3.5564803062231287, Error: [0.03464779]
#   - Valor ajustado: -10.274267814720949, Predicción: [-0.04113594], Epsilon usado: 4.498432668969444, Error: [1.62113594]
#   - Valor ajustado: 0.7585566869279323, Predicción: [1.36344245], Epsilon usado: 5.689866029018299, Error: [0.21655755]
#   - Valor ajustado: -0.6851696440116091, Predicción: [1.17964303], Epsilon usado: 7.196856730011521, Error: [0.40035697]
#   - Valor ajustado: 2.999112164325729, Predicción: [1.64868544], Epsilon usado: 9.102981779915218, Error: [0.06868544]
#   - Valor ajustado: 2.2605547518871907, Predicción: [1.5546604], Epsilon usado: 11.513953993264481, Error: [0.0253396]
#   - Valor ajustado: 3.400788225153251, Predicción: [1.69982244], Epsilon usado: 14.563484775012444, Error: [0.11982244]
#   - Valor ajustado: 2.3588557987206986, Predicción: [1.56717501], Epsilon usado: 18.420699693267164, Error: [0.01282499]
#   - Valor ajustado: 2.671698322030115, Predicción: [1.6070027], Epsilon usado: 23.29951810515372, Error: [0.0270027]
#   - Valor ajustado: 3.0600836020145477, Predicción: [1.65644766], Epsilon usado: 29.4705170255181, Error: [0.07644766]
#   - Valor ajustado: 3.252341689962313, Predicción: [1.68092385], Epsilon usado: 37.27593720314942, Error: [0.10092385]
#   - Valor ajustado: 3.3305126443964803, Predicción: [1.69087572], Epsilon usado: 47.14866363457394, Error: [0.11087572]
#   - Valor ajustado: 3.0317814058213717, Predicción: [1.65284453], Epsilon usado: 59.63623316594643, Error: [0.07284453]
#   - Valor ajustado: 2.47465855881448, Predicción: [1.58191775], Epsilon usado: 75.43120063354623, Error: [0.00191775]
#   - Valor ajustado: 2.813863968761982, Predicción: [1.62510167], Epsilon usado: 95.40954763499944, Error: [0.04510167]
#   - Valor ajustado: 2.8269374563158713, Predicción: [1.62676604], Epsilon usado: 120.67926406393289, Error: [0.04676604]
#   - Valor ajustado: 2.8179865162797797, Predicción: [1.62562651], Epsilon usado: 152.64179671752333, Error: [0.04562651]
#   - Valor ajustado: 2.81525100553481, Predicción: [1.62527825], Epsilon usado: 193.06977288832496, Error: [0.04527825]
#   - Valor ajustado: 2.693026728749965, Predicción: [1.60971799], Epsilon usado: 244.205309454865, Error: [0.02971799]
#   - Valor ajustado: 2.781245585167419, Predicción: [1.62094905], Epsilon usado: 308.8843596477485, Error: [0.04094905]
#   - Valor ajustado: 2.7053463350101787, Predicción: [1.61128639], Epsilon usado: 390.6939937054621, Error: [0.03128639]
#   - Valor ajustado: 2.8795313050445404, Predicción: [1.63346171], Epsilon usado: 494.17133613238383, Error: [0.05346171]
#   - Valor ajustado: 2.8994619561908332, Predicción: [1.63599907], Epsilon usado: 625.0551925273976, Error: [0.05599907]
#   - Valor ajustado: 2.8261478418824058, Predicción: [1.62666552], Epsilon usado: 790.6043210907702, Error: [0.04666552]
#   - Valor ajustado: 2.8217842418800716, Predicción: [1.62610999], Epsilon usado: 1000.0, Error: [0.04610999]
# Mejor X: 2.47465855881448 Mejor Epsilon para index 4: 75.43120063354623, Mejor Error: [0.00191775], Mejor Predicción: [1.58191775]
# mejora -0.35467217059689293  R pre 1.5873692705886269 R pos 1.9420414411855198
#
# Valor original sin ruido (index 5): 3.9107
# Valor ruidoso original (index 5): 4.578252094226395
# Y_test original (index 5): 1.907
# Y Predict original (index 5): 1.8972884509020083
# Y Predict optimo (index 5): 1.817581866751376
#  Error prediccion (index 5): 0.08941813324862413
#   - Valor ajustado: 4.578252094226395, Predicción: [1.85373464], Epsilon usado: 0.0, Error: [0.05326536]
#   - Valor ajustado: -2830.772990133426, Predicción: [-359.11213469], Epsilon usado: 0.01, Error: [361.01913469]
#   - Valor ajustado: -985.7492500649586, Predicción: [-124.22391755], Epsilon usado: 0.012648552168552958, Error: [126.13091755]
#   - Valor ajustado: 2014.293640094673, Predicción: [257.7086888], Epsilon usado: 0.015998587196060583, Error: [255.8016888]
#   - Valor ajustado: -851.4648296221336, Predicción: [-107.12829573], Epsilon usado: 0.020235896477251575, Error: [109.03529573]
#   - Valor ajustado: 1875.8240611729962, Predicción: [240.08025844], Epsilon usado: 0.025595479226995357, Error: [238.17325844]
#   - Valor ajustado: 14.025422430370616, Predicción: [3.0564449], Epsilon usado: 0.032374575428176434, Error: [1.1494449]
#   - Valor ajustado: -620.9749222890049, Predicción: [-77.78484489], Epsilon usado: 0.040949150623804255, Error: [79.69184489]
#   - Valor ajustado: -302.132592618458, Predicción: [-37.19333122], Epsilon usado: 0.05179474679231213, Error: [39.10033122]
#   - Valor ajustado: 21.683394617742806, Predicción: [4.03137406], Epsilon usado: 0.0655128556859551, Error: [2.12437406]
#   - Valor ajustado: 585.4357198475992, Predicción: [75.80214628], Epsilon usado: 0.08286427728546843, Error: [73.89514628]
#   - Valor ajustado: 76.17993474735884, Predicción: [10.96927674], Epsilon usado: 0.10481131341546858, Error: [9.06227674]
#   - Valor ajustado: -44.737159911731275, Predicción: [-4.42456355], Epsilon usado: 0.13257113655901095, Error: [6.33156355]
#   - Valor ajustado: 45.011602236875476, Predicción: [7.00126598], Epsilon usado: 0.16768329368110083, Error: [5.09426598]
#   - Valor ajustado: 14.005964491262047, Predicción: [3.05396773], Epsilon usado: 0.21209508879201905, Error: [1.14696773]
#   - Valor ajustado: -26.245102618446673, Predicción: [-2.07035733], Epsilon usado: 0.2682695795279726, Error: [3.97735733]
#   - Valor ajustado: -19.35152915111886, Predicción: [-1.19274305], Epsilon usado: 0.33932217718953295, Error: [3.09974305]
#   - Valor ajustado: 32.54531785009456, Predicción: [5.41419517], Epsilon usado: 0.42919342601287785, Error: [3.50719517]
#   - Valor ajustado: 42.02620452314917, Predicción: [6.62119784], Epsilon usado: 0.5428675439323859, Error: [4.71419784]
#   - Valor ajustado: 18.18284042020001, Predicción: [3.58572183], Epsilon usado: 0.6866488450043002, Error: [1.67872183]
#   - Valor ajustado: 6.301185594962892, Predicción: [2.07307966], Epsilon usado: 0.8685113737513529, Error: [0.16607966]
#   - Valor ajustado: 31.131439272515394, Predicción: [5.23419564], Epsilon usado: 1.0985411419875584, Error: [3.32719564]
#   - Valor ajustado: -8.366186206232499, Predicción: [0.20579051], Epsilon usado: 1.3894954943731375, Error: [1.70120949]
#   - Valor ajustado: 2.748741154531654, Predicción: [1.62082134], Epsilon usado: 1.757510624854793, Error: [0.28617866]
#   - Valor ajustado: 10.725857975140363, Predicción: [2.63638049], Epsilon usado: 2.2229964825261956, Error: [0.72938049]
#   - Valor ajustado: 4.270990633347233, Predicción: [1.81461747], Epsilon usado: 2.8117686979742307, Error: [0.09238253]
#   - Valor ajustado: -0.14538895004026564, Predicción: [1.25237239], Epsilon usado: 3.5564803062231287, Error: [0.65462761]
#   - Valor ajustado: 1.5549968639704042, Predicción: [1.46884689], Epsilon usado: 4.498432668969444, Error: [0.43815311]
#   - Valor ajustado: 4.671746725504128, Predicción: [1.86563735], Epsilon usado: 5.689866029018299, Error: [0.04136265]
#   - Valor ajustado: 6.674720907098397, Predicción: [2.12063409], Epsilon usado: 7.196856730011521, Error: [0.21363409]
#   - Valor ajustado: 7.151135649456528, Predicción: [2.18128599], Epsilon usado: 9.102981779915218, Error: [0.27428599]
#   - Valor ajustado: 4.146029873986859, Predicción: [1.79870884], Epsilon usado: 11.513953993264481, Error: [0.10829116]
#   - Valor ajustado: 4.589962485032116, Predicción: [1.85522548], Epsilon usado: 14.563484775012444, Error: [0.05177452]
#   - Valor ajustado: 4.613144855512136, Predicción: [1.8581768], Epsilon usado: 18.420699693267164, Error: [0.0488232]
#   - Valor ajustado: 5.1801570865749635, Predicción: [1.93036259], Epsilon usado: 23.29951810515372, Error: [0.02336259]
#   - Valor ajustado: 4.976393482653715, Predicción: [1.90442164], Epsilon usado: 29.4705170255181, Error: [0.00257836]
#   - Valor ajustado: 4.703996740679726, Predicción: [1.86974307], Epsilon usado: 37.27593720314942, Error: [0.03725693]
#   - Valor ajustado: 3.329716391525305, Predicción: [1.69478474], Epsilon usado: 47.14866363457394, Error: [0.21221526]
#   - Valor ajustado: 4.67484269680185, Predicción: [1.86603149], Epsilon usado: 59.63623316594643, Error: [0.04096851]
#   - Valor ajustado: 4.8596872845664345, Predicción: [1.88956388], Epsilon usado: 75.43120063354623, Error: [0.01743612]
#   - Valor ajustado: 4.7854568161201545, Predicción: [1.88011367], Epsilon usado: 95.40954763499944, Error: [0.02688633]
#   - Valor ajustado: 4.74092180673469, Predicción: [1.87444396], Epsilon usado: 120.67926406393289, Error: [0.03255604]
#   - Valor ajustado: 4.784162097232413, Predicción: [1.87994884], Epsilon usado: 152.64179671752333, Error: [0.02705116]
#   - Valor ajustado: 4.627239338093788, Predicción: [1.85997116], Epsilon usado: 193.06977288832496, Error: [0.04702884]
#   - Valor ajustado: 4.589776445407901, Predicción: [1.85520179], Epsilon usado: 244.205309454865, Error: [0.05179821]
#   - Valor ajustado: 4.503410485926247, Predicción: [1.84420662], Epsilon usado: 308.8843596477485, Error: [0.06279338]
#   - Valor ajustado: 4.669247982036419, Predicción: [1.86531924], Epsilon usado: 390.6939937054621, Error: [0.04168076]
#   - Valor ajustado: 4.586909129574692, Predicción: [1.85483676], Epsilon usado: 494.17133613238383, Error: [0.05216324]
#   - Valor ajustado: 4.569063767529058, Predicción: [1.85256488], Epsilon usado: 625.0551925273976, Error: [0.05443512]
#   - Valor ajustado: 4.621367915171233, Predicción: [1.85922367], Epsilon usado: 790.6043210907702, Error: [0.04777633]
#   - Valor ajustado: 4.620185126362134, Predicción: [1.85907309], Epsilon usado: 1000.0, Error: [0.04792691]
# Mejor X: 4.976393482653715 Mejor Epsilon para index 5: 29.4705170255181, Mejor Error: [0.00257836], Mejor Predicción: [1.90442164]
# mejora -0.3981413884273204  R pre 0.6675520942263948 R pos 1.0656934826537152
#
# Valor original sin ruido (index 6): 5.1769
# Valor ruidoso original (index 6): 4.726892995092447
# Y_test original (index 6): 1.33
# Y Predict original (index 6): 2.145171810293133
# Y Predict optimo (index 6): 2.0149325675136085
#  Error prediccion (index 6): 0.6849325675136084
#   - Valor ajustado: 4.726892995092447, Predicción: [2.05769188], Epsilon usado: 0.0, Error: [0.72769188]
#   - Valor ajustado: -662.6188903078507, Predicción: [-82.90146493], Epsilon usado: 0.01, Error: [84.23146493]
#   - Valor ajustado: -3936.908663145613, Predicción: [-499.74818102], Epsilon usado: 0.012648552168552958, Error: [501.07818102]
#   - Valor ajustado: 408.6991240792773, Predicción: [53.48701231], Epsilon usado: 0.015998587196060583, Error: [52.15701231]
#   - Valor ajustado: -2144.3242904811204, Predicción: [-271.53596986], Epsilon usado: 0.020235896477251575, Error: [272.86596986]
#   - Valor ajustado: -87.73866286579444, Predicción: [-9.71401007], Epsilon usado: 0.025595479226995357, Error: [11.04401007]
#   - Valor ajustado: 1777.5601453382124, Predicción: [227.7554067], Epsilon usado: 0.032374575428176434, Error: [226.4254067]
#   - Valor ajustado: -1282.8689509647493, Predicción: [-161.8649101], Epsilon usado: 0.040949150623804255, Error: [163.1949101]
#   - Valor ajustado: 1145.505984473098, Predicción: [147.28919277], Epsilon usado: 0.05179474679231213, Error: [145.95919277]
#   - Valor ajustado: -283.71413195318996, Predicción: [-34.66346061], Epsilon usado: 0.0655128556859551, Error: [35.99346061]
#   - Valor ajustado: -24.285539089550277, Predicción: [-1.63585325], Epsilon usado: 0.08286427728546843, Error: [2.96585325]
#   - Valor ajustado: 220.95460317121024, Predicción: [29.58543596], Epsilon usado: 0.10481131341546858, Error: [28.25543596]
#   - Valor ajustado: 52.57535147597813, Predicción: [8.14923361], Epsilon usado: 0.13257113655901095, Error: [6.81923361]
#   - Valor ajustado: -41.88386871863269, Predicción: [-3.87627985], Epsilon usado: 0.16768329368110083, Error: [5.20627985]
#   - Valor ajustado: 88.47944431957521, Predicción: [12.72014951], Epsilon usado: 0.21209508879201905, Error: [11.39014951]
#   - Valor ajustado: -24.527962423193657, Predicción: [-1.66671593], Epsilon usado: 0.2682695795279726, Error: [2.99671593]
#   - Valor ajustado: 3.7631618349231264, Predicción: [1.93500018], Epsilon usado: 0.33932217718953295, Error: [0.60500018]
#   - Valor ajustado: 30.975327292217706, Predicción: [5.39935508], Epsilon usado: 0.42919342601287785, Error: [4.06935508]
#   - Valor ajustado: -15.774152965187456, Predicción: [-0.55227678], Epsilon usado: 0.5428675439323859, Error: [1.88227678]
#   - Valor ajustado: 18.15204001187653, Predicción: [3.76683457], Epsilon usado: 0.6866488450043002, Error: [2.43683457]
#   - Valor ajustado: 4.9200273527852865, Predicción: [2.08227963], Epsilon usado: 0.8685113737513529, Error: [0.75227963]
#   - Valor ajustado: 10.15180081718367, Predicción: [2.74833173], Epsilon usado: 1.0985411419875584, Error: [1.41833173]
#   - Valor ajustado: 4.818248167448731, Predicción: [2.06932222], Epsilon usado: 1.3894954943731375, Error: [0.73932222]
#   - Valor ajustado: 0.9050503537168639, Predicción: [1.57113673], Epsilon usado: 1.757510624854793, Error: [0.24113673]
#   - Valor ajustado: 3.990737702590904, Predicción: [1.96397265], Epsilon usado: 2.2229964825261956, Error: [0.63397265]
#   - Valor ajustado: -2.929506629849624, Predicción: [1.08296293], Epsilon usado: 2.8117686979742307, Error: [0.24703707]
#   - Valor ajustado: 17.763063851151507, Predicción: [3.71731439], Epsilon usado: 3.5564803062231287, Error: [2.38731439]
#   - Valor ajustado: -6.622815229881519, Predicción: [0.61277132], Epsilon usado: 4.498432668969444, Error: [0.71722868]
#   - Valor ajustado: 3.3349052091862665, Predicción: [1.88047924], Epsilon usado: 5.689866029018299, Error: [0.55047924]
#   - Valor ajustado: 5.505569286689314, Predicción: [2.15682442], Epsilon usado: 7.196856730011521, Error: [0.82682442]
#   - Valor ajustado: 5.3543537999573605, Predicción: [2.13757332], Epsilon usado: 9.102981779915218, Error: [0.80757332]
#   - Valor ajustado: 5.886654128573123, Predicción: [2.20533997], Epsilon usado: 11.513953993264481, Error: [0.87533997]
#   - Valor ajustado: 6.129324771333213, Predicción: [2.23623413], Epsilon usado: 14.563484775012444, Error: [0.90623413]
#   - Valor ajustado: 4.938749398526076, Predicción: [2.08466312], Epsilon usado: 18.420699693267164, Error: [0.75466312]
#   - Valor ajustado: 5.085566983211653, Predicción: [2.10335432], Epsilon usado: 23.29951810515372, Error: [0.77335432]
#   - Valor ajustado: 6.232463510613111, Predicción: [2.24936463], Epsilon usado: 29.4705170255181, Error: [0.91936463]
#   - Valor ajustado: 4.5421521020386235, Predicción: [2.03417269], Epsilon usado: 37.27593720314942, Error: [0.70417269]
#   - Valor ajustado: 4.707092939034908, Predicción: [2.05517115], Epsilon usado: 47.14866363457394, Error: [0.72517115]
#   - Valor ajustado: 4.818025105379667, Predicción: [2.06929382], Epsilon usado: 59.63623316594643, Error: [0.73929382]
#   - Valor ajustado: 4.668448176281306, Predicción: [2.05025133], Epsilon usado: 75.43120063354623, Error: [0.72025133]
#   - Valor ajustado: 4.965785216358683, Predicción: [2.08810502], Epsilon usado: 95.40954763499944, Error: [0.75810502]
#   - Valor ajustado: 4.701045355233964, Predicción: [2.05440124], Epsilon usado: 120.67926406393289, Error: [0.72440124]
#   - Valor ajustado: 4.749936614246105, Predicción: [2.06062554], Epsilon usado: 152.64179671752333, Error: [0.73062554]
#   - Valor ajustado: 5.17821300991409, Predicción: [2.115149], Epsilon usado: 193.06977288832496, Error: [0.785149]
#   - Valor ajustado: 4.826008869798304, Predicción: [2.07031023], Epsilon usado: 244.205309454865, Error: [0.74031023]
#   - Valor ajustado: 4.727659110500323, Predicción: [2.05778941], Epsilon usado: 308.8843596477485, Error: [0.72778941]
#   - Valor ajustado: 4.747512474217167, Predicción: [2.06031693], Epsilon usado: 390.6939937054621, Error: [0.73031693]
#   - Valor ajustado: 4.674944542411144, Predicción: [2.05107837], Epsilon usado: 494.17133613238383, Error: [0.72107837]
#   - Valor ajustado: 4.76763542943831, Predicción: [2.06287876], Epsilon usado: 625.0551925273976, Error: [0.73287876]
#   - Valor ajustado: 4.7314331146374, Predicción: [2.05826988], Epsilon usado: 790.6043210907702, Error: [0.72826988]
#   - Valor ajustado: 4.761423495333293, Predicción: [2.06208792], Epsilon usado: 1000.0, Error: [0.73208792]
# Mejor X: 0.9050503537168639 Mejor Epsilon para index 6: 1.757510624854793, Mejor Error: [0.24113673], Mejor Predicción: [1.57113673]
# mejora -3.821842641375583  R pre 0.45000700490755285 R pos 4.271849646283136
#
# Valor original sin ruido (index 7): 4.25
# Valor ruidoso original (index 7): 3.113037860868677
# Y_test original (index 7): 1.463
# Y Predict original (index 7): 1.6251492267597905
# Y Predict optimo (index 7): 1.6624367776443305
#  Error prediccion (index 7): 0.19943677764433043
#   - Valor ajustado: 3.113037860868677, Predicción: [1.63346615], Epsilon usado: 0.0, Error: [0.17046615]
#   - Valor ajustado: 359.3810079404377, Predicción: [46.9896025], Epsilon usado: 0.01, Error: [45.5266025]
#   - Valor ajustado: 2166.728887256208, Predicción: [277.08134165], Epsilon usado: 0.012648552168552958, Error: [275.61834165]
# ...
#   - Valor ajustado: 2.6600751432422425, Predicción: [1.90533963], Epsilon usado: 37.27593720314942, Error: [0.38633963]
#   - Valor ajustado: 2.537173628723094, Predicción: [1.88969315], Epsilon usado: 47.14866363457394, Error: [0.37069315]
#   - Valor ajustado: 2.791911101356176, Predicción: [1.92212354], Epsilon usado: 59.63623316594643, Error: [0.40312354]
#   - Valor ajustado: 2.3298291423700954, Predicción: [1.86329632], Epsilon usado: 75.43120063354623, Error: [0.34429632]
#   - Valor ajustado: 2.347515581612426, Predicción: [1.86554797], Epsilon usado: 95.40954763499944, Error: [0.34654797]
#   - Valor ajustado: 2.4043142596376548, Predicción: [1.87277895], Epsilon usado: 120.67926406393289, Error: [0.35377895]
#   - Valor ajustado: 2.174180886598693, Predicción: [1.84348089], Epsilon usado: 152.64179671752333, Error: [0.32448089]
#   - Valor ajustado: 2.405503054515531, Predicción: [1.8729303], Epsilon usado: 193.06977288832496, Error: [0.3539303]
#   - Valor ajustado: 2.4589949372710134, Predicción: [1.8797403], Epsilon usado: 244.205309454865, Error: [0.3607403]
#   - Valor ajustado: 2.569766819840298, Predicción: [1.89384256], Epsilon usado: 308.8843596477485, Error: [0.37484256]
#   - Valor ajustado: 2.348417174425732, Predicción: [1.86566275], Epsilon usado: 390.6939937054621, Error: [0.34666275]
#   - Valor ajustado: 2.4116472875276473, Predicción: [1.87371251], Epsilon usado: 494.17133613238383, Error: [0.35471251]
#   - Valor ajustado: 2.435104085949802, Predicción: [1.87669877], Epsilon usado: 625.0551925273976, Error: [0.35769877]
#   - Valor ajustado: 2.4289535146852432, Predicción: [1.87591575], Epsilon usado: 790.6043210907702, Error: [0.35691575]
#   - Valor ajustado: 2.3748333614434647, Predicción: [1.86902577], Epsilon usado: 1000.0, Error: [0.35002577]
# Mejor X: -0.13049904743622642 Mejor Epsilon para index 47: 7.196856730011521, Mejor Error: [0.03107428], Mejor Predicción: [1.55007428]
# mejora -2.1976513524866648  R pre 0.17454769494956146 R pos 2.3721990474362262
#
# Valor original sin ruido (index 48): 2.0395
# Valor ruidoso original (index 48): 2.7027408780056903
# Y_test original (index 48): 0.679
# Y Predict original (index 48): 0.2320293317048534
# Y Predict optimo (index 48): 0.2016536746730606
#  Error prediccion (index 48): 0.47734632532693944
#   - Valor ajustado: 2.7027408780056903, Predicción: [0.15444686], Epsilon usado: 0.0, Error: [0.52455314]
#   - Valor ajustado: 557.03191324026, Predicción: [70.72556645], Epsilon usado: 0.01, Error: [70.04656645]
#   - Valor ajustado: 1162.393590715389, Predicción: [147.79358571], Epsilon usado: 0.012648552168552958, Error: [147.11458571]
#   - Valor ajustado: -1593.7227414734175, Predicción: [-203.08496259], Epsilon usado: 0.015998587196060583, Error: [203.76396259]
#   - Valor ajustado: 459.88247912524326, Predicción: [58.35756441], Epsilon usado: 0.020235896477251575, Error: [57.67856441]
#   - Valor ajustado: 424.4854387372723, Predicción: [53.85120087], Epsilon usado: 0.025595479226995357, Error: [53.17220087]
#   - Valor ajustado: 238.3489778064215, Predicción: [30.15434511], Epsilon usado: 0.032374575428176434, Error: [29.47534511]
#   - Valor ajustado: 557.7298037261193, Predicción: [70.81441422], Epsilon usado: 0.040949150623804255, Error: [70.13541422]
#   - Valor ajustado: -496.4602804966557, Predicción: [-63.39352253], Epsilon usado: 0.05179474679231213, Error: [64.07252253]
#   - Valor ajustado: -361.00287598038864, Predicción: [-46.14856923], Epsilon usado: 0.0655128556859551, Error: [46.82756923]
#   - Valor ajustado: 604.6005080339279, Predicción: [76.781479], Epsilon usado: 0.08286427728546843, Error: [76.102479]
#   - Valor ajustado: -493.9229707926623, Predicción: [-63.07050005], Epsilon usado: 0.10481131341546858, Error: [63.74950005]
#   - Valor ajustado: -115.79660635594381, Predicción: [-14.93159231], Epsilon usado: 0.13257113655901095, Error: [15.61059231]
#   - Valor ajustado: -51.27832187388773, Predicción: [-6.71783089], Epsilon usado: 0.16768329368110083, Error: [7.39683089]
#   - Valor ajustado: 93.72884154178972, Predicción: [11.74289314], Epsilon usado: 0.21209508879201905, Error: [11.06389314]
#   - Valor ajustado: 62.582898915228746, Predicción: [7.77773281], Epsilon usado: 0.2682695795279726, Error: [7.09873281]
#   - Valor ajustado: -27.711540624547833, Predicción: [-3.71756639], Epsilon usado: 0.33932217718953295, Error: [4.39656639]
#   - Valor ajustado: 54.6104923628127, Predicción: [6.76277332], Epsilon usado: 0.42919342601287785, Error: [6.08377332]
#   - Valor ajustado: 19.200947130410235, Predicción: [2.2548178], Epsilon usado: 0.5428675439323859, Error: [1.5758178]
#   - Valor ajustado: -4.814933095931993, Predicción: [-0.80262107], Epsilon usado: 0.6866488450043002, Error: [1.48162107]
#   - Valor ajustado: 7.479370843016312, Predicción: [0.76255507], Epsilon usado: 0.8685113737513529, Error: [0.08355507]
#   - Valor ajustado: 10.349255473237955, Predicción: [1.12791736], Epsilon usado: 1.0985411419875584, Error: [0.44891736]
#   - Valor ajustado: -28.00061101769183, Predicción: [-3.75436766], Epsilon usado: 1.3894954943731375, Error: [4.43336766]
#   - Valor ajustado: 2.255700750727683, Predicción: [0.0975346], Epsilon usado: 1.757510624854793, Error: [0.5814654]
#   - Valor ajustado: 0.5646419776583507, Predicción: [-0.11775248], Epsilon usado: 2.2229964825261956, Error: [0.79675248]
#   - Valor ajustado: 3.5931418772153343, Predicción: [0.26780296], Epsilon usado: 2.8117686979742307, Error: [0.41119704]
#   - Valor ajustado: -6.716029523668844, Predicción: [-1.04464784], Epsilon usado: 3.5564803062231287, Error: [1.72364784]
#   - Valor ajustado: 0.686669057501518, Predicción: [-0.10221733], Epsilon usado: 4.498432668969444, Error: [0.78121733]
#   - Valor ajustado: -2.6157986323905233, Predicción: [-0.52265135], Epsilon usado: 5.689866029018299, Error: [1.20165135]
#   - Valor ajustado: 0.16024149789865083, Predicción: [-0.16923632], Epsilon usado: 7.196856730011521, Error: [0.84823632]
#   - Valor ajustado: 1.7784274477899267, Predicción: [0.03677339], Epsilon usado: 9.102981779915218, Error: [0.64222661]
#   - Valor ajustado: 2.367275071493961, Predicción: [0.11173902], Epsilon usado: 11.513953993264481, Error: [0.56726098]
#   - Valor ajustado: 2.9736644852471374, Predicción: [0.18893788], Epsilon usado: 14.563484775012444, Error: [0.49006212]
#   - Valor ajustado: 3.180772954920931, Predicción: [0.21530467], Epsilon usado: 18.420699693267164, Error: [0.46369533]
#   - Valor ajustado: 1.0193124233666628, Predicción: [-0.05986882], Epsilon usado: 23.29951810515372, Error: [0.73886882]
#   - Valor ajustado: 0.5567598663806099, Predicción: [-0.11875594], Epsilon usado: 29.4705170255181, Error: [0.79775594]
#   - Valor ajustado: 3.062070631961705, Predicción: [0.20019279], Epsilon usado: 37.27593720314942, Error: [0.47880721]
#   - Valor ajustado: 2.811663096881117, Predicción: [0.16831364], Epsilon usado: 47.14866363457394, Error: [0.51068636]
#   - Valor ajustado: 2.395501550758235, Predicción: [0.11533251], Epsilon usado: 59.63623316594643, Error: [0.56366749]
#   - Valor ajustado: 3.1517624948178176, Predicción: [0.21161137], Epsilon usado: 75.43120063354623, Error: [0.46738863]
#   - Valor ajustado: 2.7735014106572353, Predicción: [0.16345531], Epsilon usado: 95.40954763499944, Error: [0.51554469]
#   - Valor ajustado: 2.5850503733429506, Predicción: [0.13946379], Epsilon usado: 120.67926406393289, Error: [0.53953621]
#   - Valor ajustado: 2.7040564453442726, Predicción: [0.15461434], Epsilon usado: 152.64179671752333, Error: [0.52438566]
#   - Valor ajustado: 2.7374224487708343, Predicción: [0.15886213], Epsilon usado: 193.06977288832496, Error: [0.52013787]
#   - Valor ajustado: 2.3977803748335966, Predicción: [0.11562263], Epsilon usado: 244.205309454865, Error: [0.56337737]
#   - Valor ajustado: 2.7138418534157163, Predicción: [0.15586011], Epsilon usado: 308.8843596477485, Error: [0.52313989]
#   - Valor ajustado: 2.540142771898707, Predicción: [0.13374665], Epsilon usado: 390.6939937054621, Error: [0.54525335]
#   - Valor ajustado: 2.732252868466974, Predicción: [0.158204], Epsilon usado: 494.17133613238383, Error: [0.520796]
#   - Valor ajustado: 2.6890943391287183, Predicción: [0.15270953], Epsilon usado: 625.0551925273976, Error: [0.52629047]
#   - Valor ajustado: 2.7083230771304767, Predicción: [0.15515752], Epsilon usado: 790.6043210907702, Error: [0.52384248]
#   - Valor ajustado: 2.7293560732777387, Predicción: [0.15783521], Epsilon usado: 1000.0, Error: [0.52116479]
# Mejor X: 7.479370843016312 Mejor Epsilon para index 48: 0.8685113737513529, Mejor Error: [0.08355507], Mejor Predicción: [0.76255507]
# mejora -4.776629965010621  R pre 0.6632408780056904 R pos 5.439870843016312
#
# Valor original sin ruido (index 49): 4.7891
# Valor ruidoso original (index 49): 4.8985255406711605
# Y_test original (index 49): 3.346
# Y Predict original (index 49): 3.2407508148708315
# Y Predict optimo (index 49): 2.3819257668319294
#  Error prediccion (index 49): 0.9640742331680707
#   - Valor ajustado: 4.8985255406711605, Predicción: [2.43231352], Epsilon usado: 0.0, Error: [0.91368648]
#   - Valor ajustado: -411.6235293049127, Predicción: [-50.59471304], Epsilon usado: 0.01, Error: [53.94071304]
#   - Valor ajustado: -510.7636877881369, Predicción: [-63.2161523], Epsilon usado: 0.012648552168552958, Error: [66.5621523]
#   - Valor ajustado: -19.141493810197723, Predicción: [-0.62819848], Epsilon usado: 0.015998587196060583, Error: [3.97419848]
#   - Valor ajustado: -18.286435865705833, Predicción: [-0.51934187], Epsilon usado: 0.020235896477251575, Error: [3.86534187]
#   - Valor ajustado: -1337.8694774891196, Predicción: [-168.51420355], Epsilon usado: 0.025595479226995357, Error: [171.86020355]
#   - Valor ajustado: 223.45290299715543, Predicción: [30.25626339], Epsilon usado: 0.032374575428176434, Error: [26.91026339]
#   - Valor ajustado: 165.53389915760675, Predicción: [22.88265011], Epsilon usado: 0.040949150623804255, Error: [19.53665011]
#   - Valor ajustado: 381.47826497588716, Predicción: [50.3743219], Epsilon usado: 0.05179474679231213, Error: [47.0283219]
#   - Valor ajustado: -122.7837062539942, Predicción: [-13.82278995], Epsilon usado: 0.0655128556859551, Error: [17.16878995]
#   - Valor ajustado: 14.936844971780218, Predicción: [3.71028241], Epsilon usado: 0.08286427728546843, Error: [0.36428241]
#   - Valor ajustado: -294.05673421461137, Predicción: [-35.6273962], Epsilon usado: 0.10481131341546858, Error: [38.9733962]
#   - Valor ajustado: 32.75840189229172, Predicción: [5.97912787], Epsilon usado: 0.13257113655901095, Error: [2.63312787]
#   - Valor ajustado: -4.690213267723408, Predicción: [1.2115803], Epsilon usado: 0.16768329368110083, Error: [2.1344197]
#   - Valor ajustado: -8.121582034042152, Predicción: [0.77473601], Epsilon usado: 0.21209508879201905, Error: [2.57126399]
#   - Valor ajustado: 284.8627214146553, Predicción: [38.07428896], Epsilon usado: 0.2682695795279726, Error: [34.72828896]
#   - Valor ajustado: 48.631591696913766, Predicción: [7.99992856], Epsilon usado: 0.33932217718953295, Error: [4.65392856]
#   - Valor ajustado: -108.29740112034628, Predicción: [-11.97855222], Epsilon usado: 0.42919342601287785, Error: [15.32455222]
#   - Valor ajustado: -13.637655821616546, Predicción: [0.0724899], Epsilon usado: 0.5428675439323859, Error: [3.2735101]
#   - Valor ajustado: -23.787357480614794, Predicción: [-1.21965896], Epsilon usado: 0.6866488450043002, Error: [4.56565896]
#   - Valor ajustado: -47.04998034092051, Predicción: [-4.18120135], Epsilon usado: 0.8685113737513529, Error: [7.52720135]
#   - Valor ajustado: 4.679671350125551, Predicción: [2.4044514], Epsilon usado: 1.0985411419875584, Error: [0.9415486]
#   - Valor ajustado: 25.19501916266539, Predicción: [5.01624081], Epsilon usado: 1.3894954943731375, Error: [1.67024081]
#   - Valor ajustado: 12.669510512201164, Predicción: [3.42163022], Epsilon usado: 1.757510624854793, Error: [0.07563022]
#   - Valor ajustado: 17.718123299118478, Predicción: [4.06436431], Epsilon usado: 2.2229964825261956, Error: [0.71836431]
#   - Valor ajustado: 6.897531519693269, Predicción: [2.68680506], Epsilon usado: 2.8117686979742307, Error: [0.65919494]
#   - Valor ajustado: 4.343216176656822, Predicción: [2.36161761], Epsilon usado: 3.5564803062231287, Error: [0.98438239]
#   - Valor ajustado: 4.199065718293517, Predicción: [2.34326595], Epsilon usado: 4.498432668969444, Error: [1.00273405]
#   - Valor ajustado: 3.380538613600913, Predicción: [2.23906004], Epsilon usado: 5.689866029018299, Error: [1.10693996]
#   - Valor ajustado: 15.930689564354314, Predicción: [3.83680782], Epsilon usado: 7.196856730011521, Error: [0.49080782]
#   - Valor ajustado: 4.539973436831895, Predicción: [2.38666659], Epsilon usado: 9.102981779915218, Error: [0.95933341]
#   - Valor ajustado: 0.19907348322184681, Predicción: [1.83403074], Epsilon usado: 11.513953993264481, Error: [1.51196926]
#   - Valor ajustado: 4.271142021289623, Predicción: [2.35244192], Epsilon usado: 14.563484775012444, Error: [0.99355808]
#   - Valor ajustado: 5.904797564684924, Predicción: [2.56042105], Epsilon usado: 18.420699693267164, Error: [0.78557895]
#   - Valor ajustado: 5.1572435026917764, Predicción: [2.46525065], Epsilon usado: 23.29951810515372, Error: [0.88074935]
#   - Valor ajustado: 5.632640278108935, Predicción: [2.52577296], Epsilon usado: 29.4705170255181, Error: [0.82022704]
#   - Valor ajustado: 5.543435573902746, Predicción: [2.5144164], Epsilon usado: 37.27593720314942, Error: [0.8315836]
#   - Valor ajustado: 4.942802788511685, Predicción: [2.43795041], Epsilon usado: 47.14866363457394, Error: [0.90804959]
#   - Valor ajustado: 4.583019821685239, Predicción: [2.39214678], Epsilon usado: 59.63623316594643, Error: [0.95385322]
#   - Valor ajustado: 4.439945833187137, Predicción: [2.37393217], Epsilon usado: 75.43120063354623, Error: [0.97206783]
#   - Valor ajustado: 4.9561363249851516, Predicción: [2.43964789], Epsilon usado: 95.40954763499944, Error: [0.90635211]
#   - Valor ajustado: 4.944817178675994, Predicción: [2.43820686], Epsilon usado: 120.67926406393289, Error: [0.90779314]
#   - Valor ajustado: 4.7234838537666635, Predicción: [2.41002912], Epsilon usado: 152.64179671752333, Error: [0.93597088]
#   - Valor ajustado: 4.841693749440738, Predicción: [2.42507831], Epsilon usado: 193.06977288832496, Error: [0.92092169]
#   - Valor ajustado: 4.907377324416787, Predicción: [2.43344043], Epsilon usado: 244.205309454865, Error: [0.91255957]
#   - Valor ajustado: 4.902283457608629, Predicción: [2.43279193], Epsilon usado: 308.8843596477485, Error: [0.91320807]
#   - Valor ajustado: 4.8292663970422645, Predicción: [2.4234962], Epsilon usado: 390.6939937054621, Error: [0.9225038]
#   - Valor ajustado: 4.892713995067636, Predicción: [2.43157365], Epsilon usado: 494.17133613238383, Error: [0.91442635]
#   - Valor ajustado: 4.913725256060516, Predicción: [2.43424858], Epsilon usado: 625.0551925273976, Error: [0.91175142]
#   - Valor ajustado: 4.876786254149489, Predicción: [2.42954591], Epsilon usado: 790.6043210907702, Error: [0.91645409]
#   - Valor ajustado: 4.902280354357585, Predicción: [2.43279154], Epsilon usado: 1000.0, Error: [0.91320846]
# Mejor X: 12.669510512201164 Mejor Epsilon para index 49: 1.757510624854793, Mejor Error: [0.07563022], Mejor Predicción: [3.42163022]
# mejora -7.7709849715300034  R pre 0.10942554067116017 R pos 7.880410512201164
#
# error en la entrega:
# MAE: 1.3138027078018373
# RMSE: 1.775937893039519
# R2: -0.11281662182362528
#
# error attack:
# MAE: 4.271175639399148
# RMSE: 5.602329674432224
# R2: -10.07402194261839
#
# Estadísticas detalladas de mejora:
# Mejora Media: 0.9903078893487586
# Varianza de la Mejora: 0.6297835342513255
# Número de puntos que mejoran: 6
# Mejora Máxima: 2.318562504817006
# Mejora Mínima: 0.08500163524372972
#
# Estadísticas detalladas de empeoramiento:
# Empeoramiento Medio: 3.4956930435445015
# Varianza del Empeoramiento: 13.563040836316924
# Número de puntos que empeoran: 44
# Empeoramiento Máximo: 16.509287668302843
# Empeoramiento Mínimo: 0.21288210758188963
