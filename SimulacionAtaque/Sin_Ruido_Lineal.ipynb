# %%
import numpy as np
import ModeloBase
from ModeloBase import read_data_model, add_laplace_noise, rmse
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, r2_score as r2
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 

# Cargar los datos de California Housing
all_data = fetch_california_housing()
X_train_val, X_val, X_test, Y_train_val, Y_val, Y_test = read_data_model(all_data, 'MedInc')

# Entrenar el escalador con los datos train_val para evitar fuga de datos antes del entrenamiento
scaler = StandardScaler()
X_train_val_scaled = scaler.fit_transform(X_train_val)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# Entrenamiento del modelo original sin ruido
model_original = LinearRegression()
model_original.fit(X_train_val_scaled, Y_train_val)
Y_predict = model_original.predict(X_test_scaled)


print(f"X_test : {X_test}")
print(f"Y_test : {Y_test}")
print(f"Y_predict : {Y_predict}")

# Introducción de ruido óptimo en los datos
epsilon_optimo = 10
np.random.seed(0)  # Semilla para reproducibilidad

X_train_val_noisy = add_laplace_noise(X_train_val, epsilon_optimo)
# Añadir ruido al conjunto de prueba
X_test_noisy = add_laplace_noise(X_test, epsilon_optimo)

scalerRuido = StandardScaler()
X_train_val_noisy_scaled = scalerRuido.fit_transform(X_train_val_noisy)
X_test_noisy_scaled = scalerRuido.transform(X_test_noisy)


# Entrenamiento del modelo con los datos ruidosos
model_noisy = LinearRegression()
model_noisy.fit(X_train_val_noisy_scaled, Y_train_val)
Y_predict_optimo = model_noisy.predict(X_test_noisy_scaled)


# Definir 20 niveles de ruido adicionales que el atacante probará usando Laplace
#np.random.seed(0)  # Semilla para reproducibilidad
additional_epsilons = np.logspace( np.log10(0.01),  np.log10(1000), num=50)

additional_epsilons = np.insert(additional_epsilons, 0, 0)

print("\nResultados del ataque para los primeros 10 valores:")

numero_muestras = 50


X_test_reducido = X_test[0:numero_muestras, 0]
X_test_noisy_reducido = X_test_noisy[0:numero_muestras, 0]

MAE_delivery = mae(X_test_reducido, X_test_noisy_reducido)
RMSE_delivery = rmse(X_test_reducido, X_test_noisy_reducido)
R2_delivery = r2(X_test_reducido, X_test_noisy_reducido)

print("\nerror en la entrega:")
print(f"MAE: {MAE_delivery}")
print(f"RMSE: {RMSE_delivery}")
print(f"R2: {R2_delivery}")


X_test_attack = np.empty(numero_muestras)

# Inicializar listas para estadísticas detalladas
improvement = []
worsening = []

# Inicializar contadores para mejoras y empeoramientos
count_improvements = 0
count_worsenings = 0


# Simulación del ataque para los primeros 10 valores
for i in range(numero_muestras):
    original_noisy_value = X_test_noisy[i,0]  # Valor con ruido
    original_value = X_test[i,0]  # Valor original sin ruido
    print(f"\nValor original sin ruido (index {i}): {original_value}")
    print(f"Valor ruidoso original (index {i}): {original_noisy_value}")
    print(f"Y_test original (index {i}): {Y_test[i]}")
    print(f"Y Predict original (index {i}): {Y_predict[i]}")
    print(f"Y Predict optimo (index {i}): {Y_predict_optimo[i]}")
    print(f" Error prediccion (index {i}): {abs(Y_test[i] - Y_predict_optimo[i])}")


    best_error = float('inf')
    best_prediction = None
    best_epsilon = None
    
    for epsilon in additional_epsilons:
        
        # Generar ruido adicional usando Laplace
        if(epsilon != 0):
            additional_noise_test = add_laplace_noise(X_test_noisy, epsilon)
        else :
            additional_noise_test = X_test_noisy.copy()

        additional_noise_test_scaled = scaler.transform(additional_noise_test)
        
        # Ajustar el valor de entrada con el nuevo ruido
        noisy_X_test_scaled =  [additional_noise_test_scaled[i,:]]  # Suponiendo que la columna de interés es la primera
        
        # Realizar la predicción para esta fila
        prediction = model_original.predict(noisy_X_test_scaled)
        
        # Calcular el error
        true_value = Y_test[i]
        error = abs(true_value - prediction)
        
        # Mostrar el valor con ruido añadido y la predicción correspondiente
        print(f"  - Valor ajustado: {additional_noise_test[i,0]}, Predicción: {prediction}, Epsilon usado: {epsilon}, Error: {error}")
        
        # Evaluar si este error es el mejor (menor)
        if error < best_error:
            best_error = error
            best_prediction = prediction
            best_epsilon = epsilon

            X_test_attack[i] = additional_noise_test[i,0]
    
    print(f"Mejor X: {X_test_attack[i]} Mejor Epsilon para index {i}: {best_epsilon}, Mejor Error: {best_error}, Mejor Predicción: {best_prediction}")
    error_x_noise = abs(X_test_noisy[i,0] - X_test[i,0])
    error_x_attack = abs(X_test_attack[i] - X_test[i,0])

    improvement_value = error_x_noise - error_x_attack
    improvement.append(improvement_value)
    if improvement_value > 0:
        count_improvements += 1
    else:
        worsening_value = error_x_attack - error_x_noise
        worsening.append(worsening_value)
        if worsening_value > 0:
            count_worsenings += 1

    print(f"mejora {improvement_value}  R pre {error_x_noise} R pos {error_x_attack}")


MAE_attack = mae(X_test_reducido, X_test_attack)
RMSE_attack = rmse(X_test_reducido, X_test_attack)
R2_attack = r2(X_test_reducido, X_test_attack)

print("\nerror en la entrega:")
print(f"MAE: {MAE_delivery}")
print(f"RMSE: {RMSE_delivery}")
print(f"R2: {R2_delivery}")

print("\nerror attack:")
print(f"MAE: {MAE_attack}")
print(f"RMSE: {RMSE_attack}")
print(f"R2: {R2_attack}")


# Estadísticas detalladas
improvement = np.array(improvement)
worsening = np.array(worsening)

# Filtrar solo mejoras positivas
positive_improvements = improvement[improvement > 0]

print("\nEstadísticas detalladas de mejora:")
print(f"Mejora Media: {np.mean(positive_improvements)}")
print(f"Varianza de la Mejora: {np.var(positive_improvements)}")
print(f"Número de puntos que mejoran: {count_improvements}")
print(f"Mejora Máxima: {np.max(positive_improvements)}")
print(f"Mejora Mínima: {np.min(positive_improvements)}")

print("\nEstadísticas detalladas de empeoramiento:")
print(f"Empeoramiento Medio: {np.mean(worsening)}")
print(f"Varianza del Empeoramiento: {np.var(worsening)}")
print(f"Número de puntos que empeoran: {count_worsenings}")
print(f"Empeoramiento Máximo: {np.max(worsening)}")
print(f"Empeoramiento Mínimo: {np.min(worsening)}")
# Out:
# Y_data: 20640
# y_data: 19648
# y_data: 18665
# X_test : [[   3.463         8.            6.36363636 ...    2.89800443
#     39.08       -121.04      ]
#  [   3.2891       27.            5.24033149 ...    2.42541436
#     38.05       -122.14      ]
#  [   2.096        34.            2.46689304 ...    3.37351443
#     34.05       -118.3       ]
#  ...
#  [   6.4415       15.            7.07798165 ...    2.89449541
#     33.83       -117.76      ]
#  [   2.425        17.            3.16008772 ...    1.68640351
#     33.89       -117.87      ]
#  [   3.0938       32.            4.71764706 ...    2.23921569
#     38.25       -122.04      ]]
# Y_test : [2.017 1.506 1.875 ... 3.007 1.717 1.104]
# Y_predict : [0.73379863 1.95995262 1.5841695  ... 2.77662554 1.97735153 1.9205352 ]
#
# Resultados del ataque para los primeros 10 valores:
#
# error en la entrega:
# MAE: 1.3138027078018373
# RMSE: 1.775937893039519
# R2: -0.11281662182362528
#
# Valor original sin ruido (index 0): 3.463
# Valor ruidoso original (index 0): 3.0329755358225077
# Y_test original (index 0): 2.017
# Y Predict original (index 0): 0.7337986283619296
# Y Predict optimo (index 0): 0.5787997359380683
#  Error prediccion (index 0): 1.4382002640619316
#   - Valor ajustado: 3.0329755358225077, Predicción: [0.54157821], Epsilon usado: 0.0, Error: [1.47542179]
#   - Valor ajustado: 112.35432203719704, Predicción: [49.40808795], Epsilon usado: 0.01, Error: [47.39108795]
#   - Valor ajustado: 804.0218063139603, Predicción: [358.58261734], Epsilon usado: 0.012648552168552958, Error: [356.56561734]
#   - Valor ajustado: -214.65615177268813, Predicción: [-96.76519855], Epsilon usado: 0.015998587196060583, Error: [98.78219855]
#   - Valor ajustado: 1359.0739586309915, Predicción: [606.69025848], Epsilon usado: 0.020235896477251575, Error: [604.67325848]
#   - Valor ajustado: -566.3628775344745, Predicción: [-253.97767982], Epsilon usado: 0.025595479226995357, Error: [255.99467982]
#   - Valor ajustado: 173.17139663087977, Predicción: [76.59324678], Epsilon usado: 0.032374575428176434, Error: [74.57624678]
#   - Valor ajustado: -519.2848471720231, Predicción: [-232.93385716], Epsilon usado: 0.040949150623804255, Error: [234.95085716]
#   - Valor ajustado: -69.02384224756274, Predicción: [-31.66773223], Epsilon usado: 0.05179474679231213, Error: [33.68473223]
#   - Valor ajustado: 4.6414601470811805, Predicción: [1.26056889], Epsilon usado: 0.0655128556859551, Error: [0.75643111]
#   - Valor ajustado: -130.42084868211344, Predicción: [-59.11211989], Epsilon usado: 0.08286427728546843, Error: [61.12911989]
#   - Valor ajustado: -178.65924038513535, Predicción: [-80.67462267], Epsilon usado: 0.10481131341546858, Error: [82.69162267]
#   - Valor ajustado: 44.44614703846293, Predicción: [19.05321581], Epsilon usado: 0.13257113655901095, Error: [17.03621581]
#   - Valor ajustado: 255.58697925710754, Predicción: [113.43291259], Epsilon usado: 0.16768329368110083, Error: [111.41591259]
#   - Valor ajustado: -33.95652966029721, Predicción: [-15.9926859], Epsilon usado: 0.21209508879201905, Error: [18.0096859]
#   - Valor ajustado: 52.869523418372886, Predicción: [22.81845487], Epsilon usado: 0.2682695795279726, Error: [20.80145487]
#   - Valor ajustado: 76.15426846123418, Predicción: [33.22670776], Epsilon usado: 0.33932217718953295, Error: [31.20970776]
#   - Valor ajustado: -16.776578096781737, Predicción: [-8.31326832], Epsilon usado: 0.42919342601287785, Error: [10.33026832]
#   - Valor ajustado: -15.99027538455491, Predicción: [-7.96179195], Epsilon usado: 0.5428675439323859, Error: [9.97879195]
#   - Valor ajustado: 75.95809908694481, Predicción: [33.13902029], Epsilon usado: 0.6866488450043002, Error: [31.12202029]
#   - Valor ajustado: 51.72222219158662, Predicción: [22.30561261], Epsilon usado: 0.8685113737513529, Error: [20.28861261]
#   - Valor ajustado: -1.586067041381825, Predicción: [-1.52312824], Epsilon usado: 1.0985411419875584, Error: [3.54012824]
#   - Valor ajustado: 20.402312132480336, Predicción: [8.30565068], Epsilon usado: 1.3894954943731375, Error: [6.28865068]
#   - Valor ajustado: -20.337602939507008, Predicción: [-9.90504212], Epsilon usado: 1.757510624854793, Error: [11.92204212]
#   - Valor ajustado: 4.6918467382653875, Predicción: [1.28309163], Epsilon usado: 2.2229964825261956, Error: [0.73390837]
#   - Valor ajustado: 1.9294986630226145, Predicción: [0.04832538], Epsilon usado: 2.8117686979742307, Error: [1.96867462]
#   - Valor ajustado: 4.197477932101371, Predicción: [1.06210938], Epsilon usado: 3.5564803062231287, Error: [0.95489062]
#   - Valor ajustado: 3.867187427603705, Predicción: [0.91446992], Epsilon usado: 4.498432668969444, Error: [1.10253008]
#   - Valor ajustado: -8.479977374778926, Predicción: [-4.60469782], Epsilon usado: 5.689866029018299, Error: [6.62169782]
#   - Valor ajustado: 1.0405325529753624, Predicción: [-0.34904139], Epsilon usado: 7.196856730011521, Error: [2.36604139]
#   - Valor ajustado: 5.545600838639762, Predicción: [1.66471869], Epsilon usado: 9.102981779915218, Error: [0.35228131]
#   - Valor ajustado: 2.8896840060338453, Predicción: [0.47752707], Epsilon usado: 11.513953993264481, Error: [1.53947293]
#   - Valor ajustado: 3.3375180041850974, Predicción: [0.67770833], Epsilon usado: 14.563484775012444, Error: [1.33929167]
#   - Valor ajustado: 2.7485340051400744, Predicción: [0.41443319], Epsilon usado: 18.420699693267164, Error: [1.60256681]
#   - Valor ajustado: 3.490132497917693, Predicción: [0.74592682], Epsilon usado: 23.29951810515372, Error: [1.27107318]
#   - Valor ajustado: 3.491478963439925, Predicción: [0.74652869], Epsilon usado: 29.4705170255181, Error: [1.27047131]
#   - Valor ajustado: 3.6021289499060867, Predicción: [0.7959891], Epsilon usado: 37.27593720314942, Error: [1.2210109]
#   - Valor ajustado: 3.0254934289094404, Predicción: [0.53823372], Epsilon usado: 47.14866363457394, Error: [1.47876628]
#   - Valor ajustado: 3.281108683597998, Predicción: [0.65249343], Epsilon usado: 59.63623316594643, Error: [1.36450657]
#   - Valor ajustado: 3.2057960591482724, Predicción: [0.61882878], Epsilon usado: 75.43120063354623, Error: [1.39817122]
#   - Valor ajustado: 3.084111040561671, Predicción: [0.56443572], Epsilon usado: 95.40954763499944, Error: [1.45256428]
#   - Valor ajustado: 2.914902344356394, Predicción: [0.48879964], Epsilon usado: 120.67926406393289, Error: [1.52820036]
#   - Valor ajustado: 2.5309743036042214, Predicción: [0.31718427], Epsilon usado: 152.64179671752333, Error: [1.69981573]
#   - Valor ajustado: 2.9916624222699877, Predicción: [0.5231113], Epsilon usado: 193.06977288832496, Error: [1.4938887]
#   - Valor ajustado: 3.257000389387883, Predicción: [0.64171705], Epsilon usado: 244.205309454865, Error: [1.37528295]
#   - Valor ajustado: 3.0729967700204583, Predicción: [0.55946766], Epsilon usado: 308.8843596477485, Error: [1.45753234]
#   - Valor ajustado: 3.170356073681874, Predicción: [0.60298715], Epsilon usado: 390.6939937054621, Error: [1.41401285]
#   - Valor ajustado: 2.991702337596028, Predicción: [0.52312914], Epsilon usado: 494.17133613238383, Error: [1.49387086]
#   - Valor ajustado: 3.0419425680710885, Predicción: [0.54558647], Epsilon usado: 625.0551925273976, Error: [1.47141353]
#   - Valor ajustado: 3.02337388338904, Predicción: [0.53728629], Epsilon usado: 790.6043210907702, Error: [1.47971371]
#   - Valor ajustado: 3.032841407901368, Predicción: [0.54151826], Epsilon usado: 1000.0, Error: [1.47548174]
# Mejor X: 5.545600838639762 Mejor Epsilon para index 0: 9.102981779915218, Mejor Error: [0.35228131], Mejor Predicción: [1.66471869]
# mejora -1.65257637446227  R pre 0.4300244641774924 R pos 2.0826008386397623
#
# Valor original sin ruido (index 1): 3.2891
# Valor ruidoso original (index 1): -0.9147561790958618
# Y_test original (index 1): 1.506
# Y Predict original (index 1): 1.9599526228200643
# Y Predict optimo (index 1): 1.8020863764146535
#  Error prediccion (index 1): 0.2960863764146535
#   - Valor ajustado: -0.9147561790958618, Predicción: [0.08083399], Epsilon usado: 0.0, Error: [1.42516601]
#   - Valor ajustado: 4330.6213011811515, Predicción: [1936.27221568], Epsilon usado: 0.01, Error: [1934.76621568]
#   - Valor ajustado: 2411.967024593073, Predicción: [1078.63607331], Epsilon usado: 0.012648552168552958, Error: [1077.13007331]
#   - Valor ajustado: -195.30583575045407, Predicción: [-86.8117436], Epsilon usado: 0.015998587196060583, Error: [88.3177436]
#   - Valor ajustado: 1595.1067530883638, Predicción: [713.50051937], Epsilon usado: 0.020235896477251575, Error: [711.99451937]
#   - Valor ajustado: -463.45800117819357, Predicción: [-206.6754374], Epsilon usado: 0.025595479226995357, Error: [208.1814374]
#   - Valor ajustado: 1311.474327238601, Predicción: [586.71716787], Epsilon usado: 0.032374575428176434, Error: [585.21116787]
#   - Valor ajustado: 112.50998993001626, Predicción: [50.7815584], Epsilon usado: 0.040949150623804255, Error: [49.2755584]
#   - Valor ajustado: 559.0152309220764, Predicción: [250.36886138], Epsilon usado: 0.05179474679231213, Error: [248.86286138]
#   - Valor ajustado: 433.57204177598885, Predicción: [194.29590747], Epsilon usado: 0.0655128556859551, Error: [192.78990747]
#   - Valor ajustado: -512.825352942003, Predicción: [-228.74258396], Epsilon usado: 0.08286427728546843, Error: [230.24858396]
#   - Valor ajustado: 45.071186826231305, Predicción: [20.63649493], Epsilon usado: 0.10481131341546858, Error: [19.13049493]
#   - Valor ajustado: 246.34209239202673, Predicción: [110.60434642], Epsilon usado: 0.13257113655901095, Error: [109.09834642]
#   - Valor ajustado: -516.8998413260686, Predicción: [-230.56387535], Epsilon usado: 0.16768329368110083, Error: [232.06987535]
#   - Valor ajustado: 75.85756449207348, Predicción: [34.39796853], Epsilon usado: 0.21209508879201905, Error: [32.89196853]
#   - Valor ajustado: -7.665880872739704, Predicción: [-2.93691058], Epsilon usado: 0.2682695795279726, Error: [4.44291058]
#   - Valor ajustado: -106.5061353275742, Predicción: [-47.11838485], Epsilon usado: 0.33932217718953295, Error: [48.62438485]
#   - Valor ajustado: 1.9938977711873154, Predicción: [1.38099879], Epsilon usado: 0.42919342601287785, Error: [0.12500121]
#   - Valor ajustado: -39.62147317359944, Predicción: [-17.22102172], Epsilon usado: 0.5428675439323859, Error: [18.72702172]
#   - Valor ajustado: -63.34697448334882, Predicción: [-27.82629212], Epsilon usado: 0.6866488450043002, Error: [29.33229212]
#   - Valor ajustado: 2.2762363790775377, Predicción: [1.50720381], Epsilon usado: 0.8685113737513529, Error: [0.00120381]
#   - Valor ajustado: 6.81990026413745, Predicción: [3.53821607], Epsilon usado: 1.0985411419875584, Error: [2.03221607]
#   - Valor ajustado: -3.8299906474589713, Predicción: [-1.22227229], Epsilon usado: 1.3894954943731375, Error: [2.72827229]
#   - Valor ajustado: -14.229639839368032, Predicción: [-5.87090291], Epsilon usado: 1.757510624854793, Error: [7.37690291]
#   - Valor ajustado: -9.278653938128985, Predicción: [-3.6578182], Epsilon usado: 2.2229964825261956, Error: [5.1638182]
#   - Valor ajustado: 3.3282370579213034, Predicción: [1.97744684], Epsilon usado: 2.8117686979742307, Error: [0.47144684]
#   - Valor ajustado: -0.07535463618089566, Predicción: [0.45604547], Epsilon usado: 3.5564803062231287, Error: [1.04995453]
#   - Valor ajustado: 3.6102753891794674, Predicción: [2.10351763], Epsilon usado: 4.498432668969444, Error: [0.59751763]
#   - Valor ajustado: -2.345131982298348, Predicción: [-0.55854226], Epsilon usado: 5.689866029018299, Error: [2.06454226]
#   - Valor ajustado: 2.384027215194038, Predicción: [1.55538618], Epsilon usado: 7.196856730011521, Error: [0.04938618]
#   - Valor ajustado: -0.2080438113901255, Predicción: [0.39673357], Epsilon usado: 9.102981779915218, Error: [1.10926643]
#   - Valor ajustado: -1.802369081762103, Predicción: [-0.3159279], Epsilon usado: 11.513953993264481, Error: [1.8219279]
#   - Valor ajustado: -0.7750523613648134, Predicción: [0.14328143], Epsilon usado: 14.563484775012444, Error: [1.36271857]
#   - Valor ajustado: -4.673753457277989, Predicción: [-1.59943325], Epsilon usado: 18.420699693267164, Error: [3.10543325]
#   - Valor ajustado: -0.8446646792704094, Predicción: [0.11216481], Epsilon usado: 23.29951810515372, Error: [1.39383519]
#   - Valor ajustado: -0.6754772894416663, Predicción: [0.18779137], Epsilon usado: 29.4705170255181, Error: [1.31820863]
#   - Valor ajustado: -1.2762584424621863, Predicción: [-0.08075708], Epsilon usado: 37.27593720314942, Error: [1.58675708]
#   - Valor ajustado: -0.6757661846253971, Predicción: [0.18766223], Epsilon usado: 47.14866363457394, Error: [1.31833777]
#   - Valor ajustado: -0.8107445660234164, Predicción: [0.12732706], Epsilon usado: 59.63623316594643, Error: [1.37867294]
#   - Valor ajustado: -0.6711429007878476, Predicción: [0.18972883], Epsilon usado: 75.43120063354623, Error: [1.31627117]
#   - Valor ajustado: -1.3363429248536842, Predicción: [-0.10761477], Epsilon usado: 95.40954763499944, Error: [1.61361477]
#   - Valor ajustado: -0.6400453572579765, Predicción: [0.2036294], Epsilon usado: 120.67926406393289, Error: [1.3023706]
#   - Valor ajustado: -0.8677135262717075, Predicción: [0.101862], Epsilon usado: 152.64179671752333, Error: [1.404138]
#   - Valor ajustado: -1.0012017853311517, Predicción: [0.04219291], Epsilon usado: 193.06977288832496, Error: [1.46380709]
#   - Valor ajustado: -1.012545882025484, Predicción: [0.03712211], Epsilon usado: 244.205309454865, Error: [1.46887789]
#   - Valor ajustado: -1.1752039965454872, Predicción: [-0.03558587], Epsilon usado: 308.8843596477485, Error: [1.54158587]
#   - Valor ajustado: -0.8856906978844608, Predicción: [0.09382623], Epsilon usado: 390.6939937054621, Error: [1.41217377]
#   - Valor ajustado: -0.9127782810976522, Predicción: [0.08171811], Epsilon usado: 494.17133613238383, Error: [1.42428189]
#   - Valor ajustado: -0.9082161304191668, Predicción: [0.08375739], Epsilon usado: 625.0551925273976, Error: [1.42224261]
#   - Valor ajustado: -0.8767232896893292, Predicción: [0.09783465], Epsilon usado: 790.6043210907702, Error: [1.40816535]
#   - Valor ajustado: -0.9155509728096106, Predicción: [0.08047872], Epsilon usado: 1000.0, Error: [1.42552128]
# Mejor X: 2.2762363790775377 Mejor Epsilon para index 1: 0.8685113737513529, Mejor Error: [0.00120381], Mejor Predicción: [1.50720381]
# mejora 3.1909925581733996  R pre 4.203856179095862 R pos 1.0128636209224622
#
# Valor original sin ruido (index 2): 2.096
# Valor ruidoso original (index 2): 6.20817595645841
# Y_test original (index 2): 1.875
# Y Predict original (index 2): 1.5841694985320065
# Y Predict optimo (index 2): 1.648045726823452
#  Error prediccion (index 2): 0.22695427317654793
#   - Valor ajustado: 6.20817595645841, Predicción: [3.42230718], Epsilon usado: 0.0, Error: [1.54730718]
#   - Valor ajustado: -219.04363830207612, Predicción: [-97.26498151], Epsilon usado: 0.01, Error: [99.13998151]
#   - Valor ajustado: 719.3296753126508, Predicción: [322.18675537], Epsilon usado: 0.012648552168552958, Error: [320.31175537]
#   - Valor ajustado: 88.70006172429153, Predicción: [40.2960804], Epsilon usado: 0.015998587196060583, Error: [38.4210804]
#   - Valor ajustado: 1099.0641937472044, Predicción: [491.92762609], Epsilon usado: 0.020235896477251575, Error: [490.05262609]
#   - Valor ajustado: -1606.1109574254642, Predicción: [-717.28239647], Epsilon usado: 0.025595479226995357, Error: [719.15739647]
#   - Valor ajustado: 6.559331862011156, Predicción: [3.57927345], Epsilon usado: 0.032374575428176434, Error: [1.70427345]
#   - Valor ajustado: -1562.6028279148168, Predicción: [-697.83431517], Epsilon usado: 0.040949150623804255, Error: [699.70931517]
#   - Valor ajustado: 123.46705723648131, Predicción: [55.83688537], Epsilon usado: 0.05179474679231213, Error: [53.96188537]
#   - Valor ajustado: -151.12279779468327, Predicción: [-66.90444791], Epsilon usado: 0.0655128556859551, Error: [68.77944791]
#   - Valor ajustado: 27.52662123979559, Predicción: [12.95162645], Epsilon usado: 0.08286427728546843, Error: [11.07662645]
#   - Valor ajustado: -425.4803647894748, Predicción: [-189.54194871], Epsilon usado: 0.10481131341546858, Error: [191.41694871]
#   - Valor ajustado: 58.3032505552666, Predicción: [26.70874255], Epsilon usado: 0.13257113655901095, Error: [24.83374255]
#   - Valor ajustado: 96.85940522222839, Predicción: [43.94329708], Epsilon usado: 0.16768329368110083, Error: [42.06829708]
#   - Valor ajustado: -111.95877135809701, Predicción: [-49.39817543], Epsilon usado: 0.21209508879201905, Error: [51.27317543]
#   - Valor ajustado: -3.24413988687839, Predicción: [-0.80286658], Epsilon usado: 0.2682695795279726, Error: [2.67786658]
#   - Valor ajustado: -29.426135202373857, Predicción: [-12.50618683], Epsilon usado: 0.33932217718953295, Error: [14.38118683]
#   - Valor ajustado: 50.852524819337475, Predicción: [23.37827716], Epsilon usado: 0.42919342601287785, Error: [21.50327716]
#   - Valor ajustado: 30.829434886371125, Predicción: [14.42798016], Epsilon usado: 0.5428675439323859, Error: [12.55298016]
#   - Valor ajustado: 17.010017345802446, Predicción: [8.25071722], Epsilon usado: 0.6866488450043002, Error: [6.37571722]
#   - Valor ajustado: -15.00375848012874, Predicción: [-6.05940187], Epsilon usado: 0.8685113737513529, Error: [7.93440187]
#   - Valor ajustado: 11.68296952527952, Predicción: [5.86953329], Epsilon usado: 1.0985411419875584, Error: [3.99453329]
#   - Valor ajustado: -12.227256418537417, Predicción: [-4.81830881], Epsilon usado: 1.3894954943731375, Error: [6.69330881]
#   - Valor ajustado: 1.9090378122332279, Predicción: [1.50059763], Epsilon usado: 1.757510624854793, Error: [0.37440237]
#   - Valor ajustado: -2.9553014150721015, Predicción: [-0.67375613], Epsilon usado: 2.2229964825261956, Error: [2.54875613]
#   - Valor ajustado: 5.29869254201323, Predicción: [3.01576919], Epsilon usado: 2.8117686979742307, Error: [1.14076919]
#   - Valor ajustado: 9.882887671402331, Predicción: [5.06489887], Epsilon usado: 3.5564803062231287, Error: [3.18989887]
#   - Valor ajustado: 2.318804633803711, Predicción: [1.6837629], Epsilon usado: 4.498432668969444, Error: [0.1912371]
#   - Valor ajustado: 20.038308069167464, Predicción: [9.60435952], Epsilon usado: 5.689866029018299, Error: [7.72935952]
#   - Valor ajustado: 2.88294565937396, Predicción: [1.93593326], Epsilon usado: 7.196856730011521, Error: [0.06093326]
#   - Valor ajustado: 6.231531716741095, Predicción: [3.43274718], Epsilon usado: 9.102981779915218, Error: [1.55774718]
#   - Valor ajustado: 1.3890332575272097, Predicción: [1.26815622], Epsilon usado: 11.513953993264481, Error: [0.60684378]
#   - Valor ajustado: 7.78020235621428, Predicción: [4.12500108], Epsilon usado: 14.563484775012444, Error: [2.25000108]
#   - Valor ajustado: 6.143993976783156, Predicción: [3.39361791], Epsilon usado: 18.420699693267164, Error: [1.51861791]
#   - Valor ajustado: 6.1181558696756, Predicción: [3.38206831], Epsilon usado: 23.29951810515372, Error: [1.50706831]
#   - Valor ajustado: 5.979121503309974, Predicción: [3.31992012], Epsilon usado: 29.4705170255181, Error: [1.44492012]
#   - Valor ajustado: 6.098416630142488, Predicción: [3.37324489], Epsilon usado: 37.27593720314942, Error: [1.49824489]
#   - Valor ajustado: 6.676878984068268, Predicción: [3.63181687], Epsilon usado: 47.14866363457394, Error: [1.75681687]
#   - Valor ajustado: 5.454514482467397, Predicción: [3.08542141], Epsilon usado: 59.63623316594643, Error: [1.21042141]
#   - Valor ajustado: 5.958158586491434, Predicción: [3.31054972], Epsilon usado: 75.43120063354623, Error: [1.43554972]
#   - Valor ajustado: 6.050053145627762, Predicción: [3.35162647], Epsilon usado: 95.40954763499944, Error: [1.47662647]
#   - Valor ajustado: 6.10529742743347, Predicción: [3.3763206], Epsilon usado: 120.67926406393289, Error: [1.5013206]
#   - Valor ajustado: 6.4774388793286155, Predicción: [3.54266738], Epsilon usado: 152.64179671752333, Error: [1.66766738]
#   - Valor ajustado: 6.450385279294212, Predicción: [3.53057445], Epsilon usado: 193.06977288832496, Error: [1.65557445]
#   - Valor ajustado: 5.998495254809812, Predicción: [3.32858016], Epsilon usado: 244.205309454865, Error: [1.45358016]
#   - Valor ajustado: 6.135583317278147, Predicción: [3.38985836], Epsilon usado: 308.8843596477485, Error: [1.51485836]
#   - Valor ajustado: 6.223356944401564, Predicción: [3.42909306], Epsilon usado: 390.6939937054621, Error: [1.55409306]
#   - Valor ajustado: 6.155599095263798, Predicción: [3.39880539], Epsilon usado: 494.17133613238383, Error: [1.52380539]
#   - Valor ajustado: 6.197864362412552, Predicción: [3.41769791], Epsilon usado: 625.0551925273976, Error: [1.54269791]
#   - Valor ajustado: 6.2287889667773335, Predicción: [3.43152117], Epsilon usado: 790.6043210907702, Error: [1.55652117]
#   - Valor ajustado: 6.192102810755873, Predicción: [3.4151225], Epsilon usado: 1000.0, Error: [1.5401225]
# Mejor X: 2.88294565937396 Mejor Epsilon para index 2: 7.196856730011521, Mejor Error: [0.06093326], Mejor Predicción: [1.93593326]
# mejora 3.32523029708445  R pre 4.11217595645841 R pos 0.7869456593739601
#
# Valor original sin ruido (index 3): 4.875
# Valor ruidoso original (index 3): 4.657674483460132
# Y_test original (index 3): 2.495
# Y Predict original (index 3): 2.78859376285354
# Y Predict optimo (index 3): 2.4896313775602277
#  Error prediccion (index 3): 0.00536862243977243
#   - Valor ajustado: 4.657674483460132, Predicción: [2.69144952], Epsilon usado: 0.0, Error: [0.19644952]
#   - Valor ajustado: -2176.840528494359, Predicción: [-972.43561022], Epsilon usado: 0.01, Error: [974.93061022]
#   - Valor ajustado: 182.72818560968483, Predicción: [82.28875274], Epsilon usado: 0.012648552168552958, Error: [79.79375274]
#   - Valor ajustado: -160.3784221924294, Predicción: [-71.0794862], Epsilon usado: 0.015998587196060583, Error: [73.5744862]
#   - Valor ajustado: 4025.6602226622995, Predicción: [1800.07472797], Epsilon usado: 0.020235896477251575, Error: [1797.57972797]
#   - Valor ajustado: -364.5269285733034, Predicción: [-162.33362178], Epsilon usado: 0.025595479226995357, Error: [164.82862178]
#   - Valor ajustado: 294.945794328584, Predicción: [132.44988819], Epsilon usado: 0.032374575428176434, Error: [129.95488819]
#   - Valor ajustado: 142.13952150855593, Predicción: [64.14566895], Epsilon usado: 0.040949150623804255, Error: [61.65066895]
#   - Valor ajustado: 157.3987932446546, Predicción: [70.96654497], Epsilon usado: 0.05179474679231213, Error: [68.47154497]
#   - Valor ajustado: 1353.637593514767, Predicción: [605.68384268], Epsilon usado: 0.0655128556859551, Error: [603.18884268]
#   - Valor ajustado: -241.38614144521387, Predicción: [-107.28983878], Epsilon usado: 0.08286427728546843, Error: [109.78483878]
#   - Valor ajustado: 274.3416117836529, Predicción: [123.2398435], Epsilon usado: 0.10481131341546858, Error: [120.7448435]
#   - Valor ajustado: 57.21997785643873, Predicción: [26.18673559], Epsilon usado: 0.13257113655901095, Error: [23.69173559]
#   - Valor ajustado: 115.81748499883979, Predicción: [52.37975045], Epsilon usado: 0.16768329368110083, Error: [49.88475045]
#   - Valor ajustado: 148.29575790031168, Predicción: [66.89749918], Epsilon usado: 0.21209508879201905, Error: [64.40249918]
#   - Valor ajustado: -156.9314553996628, Predicción: [-69.53869621], Epsilon usado: 0.2682695795279726, Error: [72.03369621]
#   - Valor ajustado: 103.54798015594008, Predicción: [46.89529662], Epsilon usado: 0.33932217718953295, Error: [44.40029662]
#   - Valor ajustado: 44.54000645775695, Predicción: [20.5188037], Epsilon usado: 0.42919342601287785, Error: [18.0238037]
#   - Valor ajustado: 1.7782988589426245, Predicción: [1.4043721], Epsilon usado: 0.5428675439323859, Error: [1.0906279]
#   - Valor ajustado: 14.09438908323424, Predicción: [6.90964954], Epsilon usado: 0.6866488450043002, Error: [4.41464954]
#   - Valor ajustado: -12.448526601633507, Predicción: [-4.95500169], Epsilon usado: 0.8685113737513529, Error: [7.45000169]
#   - Valor ajustado: -26.23776091876164, Predicción: [-11.11877276], Epsilon usado: 1.0985411419875584, Error: [13.61377276]
#   - Valor ajustado: 13.504345627246202, Predicción: [6.64590083], Epsilon usado: 1.3894954943731375, Error: [4.15090083]
#   - Valor ajustado: -13.503614727003395, Predicción: [-5.4266248], Epsilon usado: 1.757510624854793, Error: [7.9216248]
#   - Valor ajustado: 5.973285380959118, Predicción: [3.279526], Epsilon usado: 2.2229964825261956, Error: [0.784526]
#   - Valor ajustado: 9.411218925204384, Predicción: [4.81627814], Epsilon usado: 2.8117686979742307, Error: [2.32127814]
#   - Valor ajustado: 1.9614137147078088, Predicción: [1.48622422], Epsilon usado: 3.5564803062231287, Error: [1.00877578]
#   - Valor ajustado: 3.3034273907927023, Predicción: [2.08610271], Epsilon usado: 4.498432668969444, Error: [0.40889729]
#   - Valor ajustado: 7.1665149068497955, Predicción: [3.81289816], Epsilon usado: 5.689866029018299, Error: [1.31789816]
#   - Valor ajustado: -3.356305911707678, Predicción: [-0.89079003], Epsilon usado: 7.196856730011521, Error: [3.38579003]
#   - Valor ajustado: 5.273541338535736, Predicción: [2.96674126], Epsilon usado: 9.102981779915218, Error: [0.47174126]
#   - Valor ajustado: 1.6168863695161644, Predicción: [1.33222091], Epsilon usado: 11.513953993264481, Error: [1.16277909]
#   - Valor ajustado: 2.8980579004467444, Predicción: [1.90490303], Epsilon usado: 14.563484775012444, Error: [0.59009697]
#   - Valor ajustado: 2.4810165649576352, Predicción: [1.71848606], Epsilon usado: 18.420699693267164, Error: [0.77651394]
#   - Valor ajustado: 4.416140645074412, Predicción: [2.58348419], Epsilon usado: 23.29951810515372, Error: [0.08848419]
#   - Valor ajustado: 3.8076702669597493, Predicción: [2.31149866], Epsilon usado: 29.4705170255181, Error: [0.18350134]
#   - Valor ajustado: 4.02762730648546, Predicción: [2.40981919], Epsilon usado: 37.27593720314942, Error: [0.08518081]
#   - Valor ajustado: 4.632004581795778, Predicción: [2.6799751], Epsilon usado: 47.14866363457394, Error: [0.1849751]
#   - Valor ajustado: 4.75979090158804, Predicción: [2.73709544], Epsilon usado: 59.63623316594643, Error: [0.24209544]
#   - Valor ajustado: 4.381246713031446, Predicción: [2.56788664], Epsilon usado: 75.43120063354623, Error: [0.07288664]
#   - Valor ajustado: 4.3799545043908426, Predicción: [2.56730902], Epsilon usado: 95.40954763499944, Error: [0.07230902]
#   - Valor ajustado: 4.606829388400352, Predicción: [2.66872182], Epsilon usado: 120.67926406393289, Error: [0.17372182]
#   - Valor ajustado: 4.593943061380446, Predicción: [2.66296165], Epsilon usado: 152.64179671752333, Error: [0.16796165]
#   - Valor ajustado: 4.850214603248317, Predicción: [2.77751472], Epsilon usado: 193.06977288832496, Error: [0.28251472]
#   - Valor ajustado: 4.669319921675513, Predicción: [2.69665502], Epsilon usado: 244.205309454865, Error: [0.20165502]
#   - Valor ajustado: 4.666384064085822, Predicción: [2.69534269], Epsilon usado: 308.8843596477485, Error: [0.20034269]
#   - Valor ajustado: 4.658254595295774, Predicción: [2.69170883], Epsilon usado: 390.6939937054621, Error: [0.19670883]
#   - Valor ajustado: 4.750597200407856, Predicción: [2.73298586], Epsilon usado: 494.17133613238383, Error: [0.23798586]
#   - Valor ajustado: 4.606319990593535, Predicción: [2.66849412], Epsilon usado: 625.0551925273976, Error: [0.17349412]
#   - Valor ajustado: 4.6785597749285515, Predicción: [2.70078522], Epsilon usado: 790.6043210907702, Error: [0.20578522]
#   - Valor ajustado: 4.682218800834421, Predicción: [2.7024208], Epsilon usado: 1000.0, Error: [0.2074208]
# Mejor X: 4.3799545043908426 Mejor Epsilon para index 3: 95.40954763499944, Mejor Error: [0.07230902], Mejor Predicción: [2.56730902]
# mejora -0.277719979069289  R pre 0.21732551653986842 R pos 0.49504549560915745
#
# Valor original sin ruido (index 4): 4.4167
# Valor ruidoso original (index 4): 2.8293307294113728
# Y_test original (index 4): 1.58
# Y Predict original (index 4): 2.2321085699258942
# Y Predict optimo (index 4): 1.6686510910702481
#  Error prediccion (index 4): 0.08865109107024804
#   - Valor ajustado: 2.8293307294113728, Predicción: [1.52255642], Epsilon usado: 0.0, Error: [0.05744358]
#   - Valor ajustado: -5680.7154490579505, Predicción: [-2539.01508988], Epsilon usado: 0.01, Error: [2540.59508988]
#   - Valor ajustado: 473.05229972850015, Predicción: [211.71165516], Epsilon usado: 0.012648552168552958, Error: [210.13165516]
#   - Valor ajustado: 748.2754481664908, Predicción: [334.73606982], Epsilon usado: 0.015998587196060583, Error: [333.15606982]
#   - Valor ajustado: 1148.3251564902978, Predicción: [513.55780587], Epsilon usado: 0.020235896477251575, Error: [511.97780587]
#   - Valor ajustado: 393.00457007463825, Predicción: [175.93041677], Epsilon usado: 0.025595479226995357, Error: [174.35041677]
#   - Valor ajustado: 184.5595009773721, Predicción: [82.75572285], Epsilon usado: 0.032374575428176434, Error: [81.17572285]
#   - Valor ajustado: 283.1541455523366, Predicción: [126.82740979], Epsilon usado: 0.040949150623804255, Error: [125.24740979]
#   - Valor ajustado: -10.901879267703103, Predicción: [-4.61527785], Epsilon usado: 0.05179474679231213, Error: [6.19527785]
#   - Valor ajustado: 125.23388679839653, Predicción: [56.23724503], Epsilon usado: 0.0655128556859551, Error: [54.65724503]
#   - Valor ajustado: -108.04451932476205, Predicción: [-48.03792053], Epsilon usado: 0.08286427728546843, Error: [49.61792053]
#   - Valor ajustado: -20.205046564736065, Predicción: [-8.77378238], Epsilon usado: 0.10481131341546858, Error: [10.35378238]
#   - Valor ajustado: -6.551788178168971, Predicción: [-2.67079239], Epsilon usado: 0.13257113655901095, Error: [4.25079239]
#   - Valor ajustado: 46.10184083834096, Predicción: [20.86531614], Epsilon usado: 0.16768329368110083, Error: [19.28531614]
#   - Valor ajustado: 48.166655580864074, Predicción: [21.78828583], Epsilon usado: 0.21209508879201905, Error: [20.20828583]
#   - Valor ajustado: -119.53086641191953, Predicción: [-53.17230379], Epsilon usado: 0.2682695795279726, Error: [54.75230379]
#   - Valor ajustado: 13.82965543433434, Predicción: [6.43968827], Epsilon usado: 0.33932217718953295, Error: [4.85968827]
#   - Valor ajustado: -52.32892111243442, Predicción: [-23.13311547], Epsilon usado: 0.42919342601287785, Error: [24.71311547]
#   - Valor ajustado: 38.81665516701484, Predicción: [17.60884695], Epsilon usado: 0.5428675439323859, Error: [16.02884695]
#   - Valor ajustado: 24.04192420157937, Predicción: [11.00456007], Epsilon usado: 0.6866488450043002, Error: [9.42456007]
#   - Valor ajustado: -3.9113218773127825, Predicción: [-1.49050714], Epsilon usado: 0.8685113737513529, Error: [3.07050714]
#   - Valor ajustado: 16.419794528417547, Predicción: [7.59747731], Epsilon usado: 1.0985411419875584, Error: [6.01747731]
#   - Valor ajustado: 1.8831394073733179, Predicción: [1.09961005], Epsilon usado: 1.3894954943731375, Error: [0.48038995]
#   - Valor ajustado: 2.2488239844934945, Predicción: [1.26307061], Epsilon usado: 1.757510624854793, Error: [0.31692939]
#   - Valor ajustado: 1.2067621407880316, Predicción: [0.79727023], Epsilon usado: 2.2229964825261956, Error: [0.78272977]
#   - Valor ajustado: 12.98322084717091, Predicción: [6.06133303], Epsilon usado: 2.8117686979742307, Error: [4.48133303]
#   - Valor ajustado: 2.1874398112542517, Predicción: [1.23563196], Epsilon usado: 3.5564803062231287, Error: [0.34436804]
#   - Valor ajustado: -10.274267814720949, Predicción: [-4.33473628], Epsilon usado: 4.498432668969444, Error: [5.91473628]
#   - Valor ajustado: 0.7585566869279323, Predicción: [0.59692293], Epsilon usado: 5.689866029018299, Error: [0.98307707]
#   - Valor ajustado: -0.6851696440116091, Predicción: [-0.04842099], Epsilon usado: 7.196856730011521, Error: [1.62842099]
#   - Valor ajustado: 2.999112164325729, Predicción: [1.59844852], Epsilon usado: 9.102981779915218, Error: [0.01844852]
#   - Valor ajustado: 2.2605547518871907, Predicción: [1.26831425], Epsilon usado: 11.513953993264481, Error: [0.31168575]
#   - Valor ajustado: 3.400788225153251, Predicción: [1.77799723], Epsilon usado: 14.563484775012444, Error: [0.19799723]
#   - Valor ajustado: 2.3588557987206986, Predicción: [1.3122547], Epsilon usado: 18.420699693267164, Error: [0.2677453]
#   - Valor ajustado: 2.671698322030115, Predicción: [1.45209493], Epsilon usado: 23.29951810515372, Error: [0.12790507]
#   - Valor ajustado: 3.0600836020145477, Predicción: [1.62570268], Epsilon usado: 29.4705170255181, Error: [0.04570268]
#   - Valor ajustado: 3.252341689962313, Predicción: [1.71164181], Epsilon usado: 37.27593720314942, Error: [0.13164181]
#   - Valor ajustado: 3.3305126443964803, Predicción: [1.74658413], Epsilon usado: 47.14866363457394, Error: [0.16658413]
#   - Valor ajustado: 3.0317814058213717, Predicción: [1.61305163], Epsilon usado: 59.63623316594643, Error: [0.03305163]
#   - Valor ajustado: 2.47465855881448, Predicción: [1.36401839], Epsilon usado: 75.43120063354623, Error: [0.21598161]
#   - Valor ajustado: 2.813863968761982, Predicción: [1.5156428], Epsilon usado: 95.40954763499944, Error: [0.0643572]
#   - Valor ajustado: 2.8269374563158713, Predicción: [1.52148663], Epsilon usado: 120.67926406393289, Error: [0.05851337]
#   - Valor ajustado: 2.8179865162797797, Predicción: [1.51748558], Epsilon usado: 152.64179671752333, Error: [0.06251442]
#   - Valor ajustado: 2.81525100553481, Predicción: [1.51626281], Epsilon usado: 193.06977288832496, Error: [0.06373719]
#   - Valor ajustado: 2.693026728749965, Predicción: [1.4616287], Epsilon usado: 244.205309454865, Error: [0.1183713]
#   - Valor ajustado: 2.781245585167419, Predicción: [1.50106242], Epsilon usado: 308.8843596477485, Error: [0.07893758]
#   - Valor ajustado: 2.7053463350101787, Predicción: [1.46713555], Epsilon usado: 390.6939937054621, Error: [0.11286445]
#   - Valor ajustado: 2.8795313050445404, Predicción: [1.54499602], Epsilon usado: 494.17133613238383, Error: [0.03500398]
#   - Valor ajustado: 2.8994619561908332, Predicción: [1.553905], Epsilon usado: 625.0551925273976, Error: [0.026095]
#   - Valor ajustado: 2.8261478418824058, Predicción: [1.52113368], Epsilon usado: 790.6043210907702, Error: [0.05886632]
#   - Valor ajustado: 2.8217842418800716, Predicción: [1.51918315], Epsilon usado: 1000.0, Error: [0.06081685]
# Mejor X: 2.999112164325729 Mejor Epsilon para index 4: 9.102981779915218, Mejor Error: [0.01844852], Mejor Predicción: [1.59844852]
# mejora 0.16978143491435604  R pre 1.5873692705886269 R pos 1.4175878356742708
#
# Valor original sin ruido (index 5): 3.9107
# Valor ruidoso original (index 5): 4.578252094226395
# Y_test original (index 5): 1.907
# Y Predict original (index 5): 1.8972884509020083
# Y Predict optimo (index 5): 1.817581866751376
#  Error prediccion (index 5): 0.08941813324862413
#   - Valor ajustado: 4.578252094226395, Predicción: [2.19568343], Epsilon usado: 0.0, Error: [0.28868343]
#   - Valor ajustado: -2830.772990133426, Predicción: [-1265.20289448], Epsilon usado: 0.01, Error: [1267.10989448]
#   - Valor ajustado: -985.7492500649586, Predicción: [-440.47951293], Epsilon usado: 0.012648552168552958, Error: [442.38651293]
#   - Valor ajustado: 2014.293640094673, Predicción: [900.53603252], Epsilon usado: 0.015998587196060583, Error: [898.62903252]
#   - Valor ajustado: -851.4648296221336, Predicción: [-380.45453931], Epsilon usado: 0.020235896477251575, Error: [382.36153931]
#   - Valor ajustado: 1875.8240611729962, Predicción: [838.64029813], Epsilon usado: 0.025595479226995357, Error: [836.73329813]
#   - Valor ajustado: 14.025422430370616, Predicción: [6.41855715], Epsilon usado: 0.032374575428176434, Error: [4.51155715]
#   - Valor ajustado: -620.9749222890049, Predicción: [-277.42582935], Epsilon usado: 0.040949150623804255, Error: [279.33282935]
#   - Valor ajustado: -302.132592618458, Predicción: [-134.9036934], Epsilon usado: 0.05179474679231213, Error: [136.8106934]
#   - Valor ajustado: 21.683394617742806, Predicción: [9.84166146], Epsilon usado: 0.0655128556859551, Error: [7.93466146]
#   - Valor ajustado: 585.4357198475992, Predicción: [261.83826938], Epsilon usado: 0.08286427728546843, Error: [259.93126938]
#   - Valor ajustado: 76.17993474735884, Predicción: [34.20154902], Epsilon usado: 0.10481131341546858, Error: [32.29454902]
#   - Valor ajustado: -44.737159911731275, Predicción: [-19.84824612], Epsilon usado: 0.13257113655901095, Error: [21.75524612]
#   - Valor ajustado: 45.011602236875476, Predicción: [20.26934207], Epsilon usado: 0.16768329368110083, Error: [18.36234207]
#   - Valor ajustado: 14.005964491262047, Predicción: [6.40985948], Epsilon usado: 0.21209508879201905, Error: [4.50285948]
#   - Valor ajustado: -26.245102618446673, Predicción: [-11.58231887], Epsilon usado: 0.2682695795279726, Error: [13.48931887]
#   - Valor ajustado: -19.35152915111886, Predicción: [-8.50089986], Epsilon usado: 0.33932217718953295, Error: [10.40789986]
#   - Valor ajustado: 32.54531785009456, Predicción: [14.69692802], Epsilon usado: 0.42919342601287785, Error: [12.78992802]
#   - Valor ajustado: 42.02620452314917, Predicción: [18.9348729], Epsilon usado: 0.5428675439323859, Error: [17.0278729]
#   - Valor ajustado: 18.18284042020001, Predicción: [8.27691797], Epsilon usado: 0.6866488450043002, Error: [6.36991797]
#   - Valor ajustado: 6.301185594962892, Predicción: [2.96583262], Epsilon usado: 0.8685113737513529, Error: [1.05883262]
#   - Valor ajustado: 31.131439272515394, Predicción: [14.064926], Epsilon usado: 1.0985411419875584, Error: [12.157926]
#   - Valor ajustado: -8.366186206232499, Predicción: [-3.59046484], Epsilon usado: 1.3894954943731375, Error: [5.49746484]
#   - Valor ajustado: 2.748741154531654, Predicción: [1.37789425], Epsilon usado: 1.757510624854793, Error: [0.52910575]
#   - Valor ajustado: 10.725857975140363, Predicción: [4.94365583], Epsilon usado: 2.2229964825261956, Error: [3.03665583]
#   - Valor ajustado: 4.270990633347233, Predicción: [2.05833793], Epsilon usado: 2.8117686979742307, Error: [0.15133793]
#   - Valor ajustado: -0.14538895004026564, Predicción: [0.08422159], Epsilon usado: 3.5564803062231287, Error: [1.82277841]
#   - Valor ajustado: 1.5549968639704042, Predicción: [0.844292], Epsilon usado: 4.498432668969444, Error: [1.062708]
#   - Valor ajustado: 4.671746725504128, Predicción: [2.23747542], Epsilon usado: 5.689866029018299, Error: [0.33047542]
#   - Valor ajustado: 6.674720907098397, Predicción: [3.13280246], Epsilon usado: 7.196856730011521, Error: [1.22580246]
#   - Valor ajustado: 7.151135649456528, Predicción: [3.34575927], Epsilon usado: 9.102981779915218, Error: [1.43875927]
#   - Valor ajustado: 4.146029873986859, Predicción: [2.00248062], Epsilon usado: 11.513953993264481, Error: [0.09548062]
#   - Valor ajustado: 4.589962485032116, Predicción: [2.20091796], Epsilon usado: 14.563484775012444, Error: [0.29391796]
#   - Valor ajustado: 4.613144855512136, Predicción: [2.21128045], Epsilon usado: 18.420699693267164, Error: [0.30428045]
#   - Valor ajustado: 5.1801570865749635, Predicción: [2.46473423], Epsilon usado: 23.29951810515372, Error: [0.55773423]
#   - Valor ajustado: 4.976393482653715, Predicción: [2.37365215], Epsilon usado: 29.4705170255181, Error: [0.46665215]
#   - Valor ajustado: 4.703996740679726, Predicción: [2.25189114], Epsilon usado: 37.27593720314942, Error: [0.34489114]
#   - Valor ajustado: 3.329716391525305, Predicción: [1.63758948], Epsilon usado: 47.14866363457394, Error: [0.26941052]
#   - Valor ajustado: 4.67484269680185, Predicción: [2.23885931], Epsilon usado: 59.63623316594643, Error: [0.33185931]
#   - Valor ajustado: 4.8596872845664345, Predicción: [2.32148462], Epsilon usado: 75.43120063354623, Error: [0.41448462]
#   - Valor ajustado: 4.7854568161201545, Predicción: [2.28830369], Epsilon usado: 95.40954763499944, Error: [0.38130369]
#   - Valor ajustado: 4.74092180673469, Predicción: [2.26839659], Epsilon usado: 120.67926406393289, Error: [0.36139659]
#   - Valor ajustado: 4.784162097232413, Predicción: [2.28772495], Epsilon usado: 152.64179671752333, Error: [0.38072495]
#   - Valor ajustado: 4.627239338093788, Predicción: [2.21758067], Epsilon usado: 193.06977288832496, Error: [0.31058067]
#   - Valor ajustado: 4.589776445407901, Predicción: [2.2008348], Epsilon usado: 244.205309454865, Error: [0.2938348]
#   - Valor ajustado: 4.503410485926247, Predicción: [2.16222932], Epsilon usado: 308.8843596477485, Error: [0.25522932]
#   - Valor ajustado: 4.669247982036419, Predicción: [2.23635848], Epsilon usado: 390.6939937054621, Error: [0.32935848]
#   - Valor ajustado: 4.586909129574692, Predicción: [2.19955311], Epsilon usado: 494.17133613238383, Error: [0.29255311]
#   - Valor ajustado: 4.569063767529058, Predicción: [2.19157626], Epsilon usado: 625.0551925273976, Error: [0.28457626]
#   - Valor ajustado: 4.621367915171233, Predicción: [2.21495615], Epsilon usado: 790.6043210907702, Error: [0.30795615]
#   - Valor ajustado: 4.620185126362134, Predicción: [2.21442744], Epsilon usado: 1000.0, Error: [0.30742744]
# Mejor X: 4.146029873986859 Mejor Epsilon para index 5: 11.513953993264481, Mejor Error: [0.09548062], Mejor Predicción: [2.00248062]
# mejora 0.4322222202395354  R pre 0.6675520942263948 R pos 0.23532987398685945
#
# Valor original sin ruido (index 6): 5.1769
# Valor ruidoso original (index 6): 4.726892995092447
# Y_test original (index 6): 1.33
# Y Predict original (index 6): 2.145171810293133
# Y Predict optimo (index 6): 2.0149325675136085
#  Error prediccion (index 6): 0.6849325675136084
#   - Valor ajustado: 4.726892995092447, Predicción: [1.94401922], Epsilon usado: 0.0, Error: [0.61401922]
#   - Valor ajustado: -662.6188903078507, Predicción: [-296.35873923], Epsilon usado: 0.01, Error: [297.68873923]
#   - Valor ajustado: -3936.908663145613, Predicción: [-1759.96230973], Epsilon usado: 0.012648552168552958, Error: [1761.29230973]
#   - Valor ajustado: 408.6991240792773, Predicción: [182.5191182], Epsilon usado: 0.015998587196060583, Error: [181.1891182]
#   - Valor ajustado: -2144.3242904811204, Predicción: [-958.67926202], Epsilon usado: 0.020235896477251575, Error: [960.00926202]
#   - Valor ajustado: -87.73866286579444, Predicción: [-39.38797247], Epsilon usado: 0.025595479226995357, Error: [40.71797247]
#   - Valor ajustado: 1777.5601453382124, Predicción: [794.39834002], Epsilon usado: 0.032374575428176434, Error: [793.06834002]
#   - Valor ajustado: -1282.8689509647493, Predicción: [-573.60976658], Epsilon usado: 0.040949150623804255, Error: [574.93976658]
#   - Valor ajustado: 1145.505984473098, Predicción: [511.87089414], Epsilon usado: 0.05179474679231213, Error: [510.54089414]
#   - Valor ajustado: -283.71413195318996, Predicción: [-126.98877026], Epsilon usado: 0.0655128556859551, Error: [128.31877026]
#   - Valor ajustado: -24.285539089550277, Predicción: [-11.02450285], Epsilon usado: 0.08286427728546843, Error: [12.35450285]
#   - Valor ajustado: 220.95460317121024, Predicción: [98.5975443], Epsilon usado: 0.10481131341546858, Error: [97.2675443]
#   - Valor ajustado: 52.57535147597813, Predicción: [23.33222232], Epsilon usado: 0.13257113655901095, Error: [22.00222232]
#   - Valor ajustado: -41.88386871863269, Predicción: [-18.89093492], Epsilon usado: 0.16768329368110083, Error: [20.22093492]
#   - Valor ajustado: 88.47944431957521, Predicción: [39.38130843], Epsilon usado: 0.21209508879201905, Error: [38.05130843]
#   - Valor ajustado: -24.527962423193657, Predicción: [-11.13286579], Epsilon usado: 0.2682695795279726, Error: [12.46286579]
#   - Valor ajustado: 3.7631618349231264, Predicción: [1.51323256], Epsilon usado: 0.33932217718953295, Error: [0.18323256]
#   - Valor ajustado: 30.975327292217706, Predicción: [13.67703762], Epsilon usado: 0.42919342601287785, Error: [12.34703762]
#   - Valor ajustado: -15.774152965187456, Predicción: [-7.21992354], Epsilon usado: 0.5428675439323859, Error: [8.54992354]
#   - Valor ajustado: 18.15204001187653, Predicción: [7.94504371], Epsilon usado: 0.6866488450043002, Error: [6.61504371]
#   - Valor ajustado: 4.9200273527852865, Predicción: [2.03035005], Epsilon usado: 0.8685113737513529, Error: [0.70035005]
#   - Valor ajustado: 10.15180081718367, Predicción: [4.36894646], Epsilon usado: 1.0985411419875584, Error: [3.03894646]
#   - Valor ajustado: 4.818248167448731, Predicción: [1.98485487], Epsilon usado: 1.3894954943731375, Error: [0.65485487]
#   - Valor ajustado: 0.9050503537168639, Predicción: [0.23566018], Epsilon usado: 1.757510624854793, Error: [1.09433982]
#   - Valor ajustado: 3.990737702590904, Predicción: [1.6149587], Epsilon usado: 2.2229964825261956, Error: [0.2849587]
#   - Valor ajustado: -2.929506629849624, Predicción: [-1.47838215], Epsilon usado: 2.8117686979742307, Error: [2.80838215]
#   - Valor ajustado: 17.763063851151507, Predicción: [7.77117184], Epsilon usado: 3.5564803062231287, Error: [6.44117184]
#   - Valor ajustado: -6.622815229881519, Predicción: [-3.12928663], Epsilon usado: 4.498432668969444, Error: [4.45928663]
#   - Valor ajustado: 3.3349052091862665, Predicción: [1.32180237], Epsilon usado: 5.689866029018299, Error: [0.00819763]
#   - Valor ajustado: 5.505569286689314, Predicción: [2.29208658], Epsilon usado: 7.196856730011521, Error: [0.96208658]
#   - Valor ajustado: 5.3543537999573605, Predicción: [2.22449344], Epsilon usado: 9.102981779915218, Error: [0.89449344]
#   - Valor ajustado: 5.886654128573123, Predicción: [2.46243105], Epsilon usado: 11.513953993264481, Error: [1.13243105]
#   - Valor ajustado: 6.129324771333213, Predicción: [2.57090453], Epsilon usado: 14.563484775012444, Error: [1.24090453]
#   - Valor ajustado: 4.938749398526076, Predicción: [2.03871878], Epsilon usado: 18.420699693267164, Error: [0.70871878]
#   - Valor ajustado: 5.085566983211653, Predicción: [2.10434606], Epsilon usado: 23.29951810515372, Error: [0.77434606]
#   - Valor ajustado: 6.232463510613111, Predicción: [2.61700742], Epsilon usado: 29.4705170255181, Error: [1.28700742]
#   - Valor ajustado: 4.5421521020386235, Predicción: [1.86144027], Epsilon usado: 37.27593720314942, Error: [0.53144027]
#   - Valor ajustado: 4.707092939034908, Predicción: [1.93516862], Epsilon usado: 47.14866363457394, Error: [0.60516862]
#   - Valor ajustado: 4.818025105379667, Predicción: [1.98475517], Epsilon usado: 59.63623316594643, Error: [0.65475517]
#   - Valor ajustado: 4.668448176281306, Predicción: [1.91789446], Epsilon usado: 75.43120063354623, Error: [0.58789446]
#   - Valor ajustado: 4.965785216358683, Predicción: [2.05080376], Epsilon usado: 95.40954763499944, Error: [0.72080376]
#   - Valor ajustado: 4.701045355233964, Predicción: [1.93246536], Epsilon usado: 120.67926406393289, Error: [0.60246536]
#   - Valor ajustado: 4.749936614246105, Predicción: [1.95431969], Epsilon usado: 152.64179671752333, Error: [0.62431969]
#   - Valor ajustado: 5.17821300991409, Predicción: [2.14575872], Epsilon usado: 193.06977288832496, Error: [0.81575872]
#   - Valor ajustado: 4.826008869798304, Predicción: [1.9883239], Epsilon usado: 244.205309454865, Error: [0.6583239]
#   - Valor ajustado: 4.727659110500323, Predicción: [1.94436168], Epsilon usado: 308.8843596477485, Error: [0.61436168]
#   - Valor ajustado: 4.747512474217167, Predicción: [1.95323611], Epsilon usado: 390.6939937054621, Error: [0.62323611]
#   - Valor ajustado: 4.674944542411144, Predicción: [1.92079833], Epsilon usado: 494.17133613238383, Error: [0.59079833]
#   - Valor ajustado: 4.76763542943831, Predicción: [1.96223104], Epsilon usado: 625.0551925273976, Error: [0.63223104]
#   - Valor ajustado: 4.7314331146374, Predicción: [1.94604865], Epsilon usado: 790.6043210907702, Error: [0.61604865]
#   - Valor ajustado: 4.761423495333293, Predicción: [1.95945431], Epsilon usado: 1000.0, Error: [0.62945431]
# Mejor X: 3.3349052091862665 Mejor Epsilon para index 6: 5.689866029018299, Mejor Error: [0.00819763], Mejor Predicción: [1.32180237]
# mejora -1.3919877859061804  R pre 0.45000700490755285 R pos 1.8419947908137333
#
# Valor original sin ruido (index 7): 4.25
# Valor ruidoso original (index 7): 3.113037860868677
# Y_test original (index 7): 1.463
# Y Predict original (index 7): 1.6251492267597905
# Y Predict optimo (index 7): 1.6624367776443305
#  Error prediccion (index 7): 0.19943677764433043
#   - Valor ajustado: 3.113037860868677, Predicción: [1.11692852], Epsilon usado: 0.0, Error: [0.34607148]
#   - Valor ajustado: 359.3810079404377, Predicción: [160.36828049], Epsilon usado: 0.01, Error: [158.90528049]
# ...
#   - Valor ajustado: 2.6600751432422425, Predicción: [2.01572566], Epsilon usado: 37.27593720314942, Error: [0.49672566]
#   - Valor ajustado: 2.537173628723094, Predicción: [1.96078883], Epsilon usado: 47.14866363457394, Error: [0.44178883]
#   - Valor ajustado: 2.791911101356176, Predicción: [2.07465617], Epsilon usado: 59.63623316594643, Error: [0.55565617]
#   - Valor ajustado: 2.3298291423700954, Predicción: [1.8681061], Epsilon usado: 75.43120063354623, Error: [0.3491061]
#   - Valor ajustado: 2.347515581612426, Predicción: [1.87601191], Epsilon usado: 95.40954763499944, Error: [0.35701191]
#   - Valor ajustado: 2.4043142596376548, Predicción: [1.90140085], Epsilon usado: 120.67926406393289, Error: [0.38240085]
#   - Valor ajustado: 2.174180886598693, Predicción: [1.79853151], Epsilon usado: 152.64179671752333, Error: [0.27953151]
#   - Valor ajustado: 2.405503054515531, Predicción: [1.90193224], Epsilon usado: 193.06977288832496, Error: [0.38293224]
#   - Valor ajustado: 2.4589949372710134, Predicción: [1.92584305], Epsilon usado: 244.205309454865, Error: [0.40684305]
#   - Valor ajustado: 2.569766819840298, Predicción: [1.97535795], Epsilon usado: 308.8843596477485, Error: [0.45635795]
#   - Valor ajustado: 2.348417174425732, Predicción: [1.87641492], Epsilon usado: 390.6939937054621, Error: [0.35741492]
#   - Valor ajustado: 2.4116472875276473, Predicción: [1.90467871], Epsilon usado: 494.17133613238383, Error: [0.38567871]
#   - Valor ajustado: 2.435104085949802, Predicción: [1.91516387], Epsilon usado: 625.0551925273976, Error: [0.39616387]
#   - Valor ajustado: 2.4289535146852432, Predicción: [1.91241457], Epsilon usado: 790.6043210907702, Error: [0.39341457]
#   - Valor ajustado: 2.3748333614434647, Predicción: [1.88822293], Epsilon usado: 1000.0, Error: [0.36922293]
# Mejor X: 1.6142901385199018 Mejor Epsilon para index 47: 29.4705170255181, Mejor Error: [0.02926103], Mejor Predicción: [1.54826103]
# mejora -0.45286216653053657  R pre 0.17454769494956146 R pos 0.627409861480098
#
# Valor original sin ruido (index 48): 2.0395
# Valor ruidoso original (index 48): 2.7027408780056903
# Y_test original (index 48): 0.679
# Y Predict original (index 48): 0.2320293317048534
# Y Predict optimo (index 48): 0.2016536746730606
#  Error prediccion (index 48): 0.47734632532693944
#   - Valor ajustado: 2.7027408780056903, Predicción: [0.5284972], Epsilon usado: 0.0, Error: [0.1505028]
#   - Valor ajustado: 557.03191324026, Predicción: [248.31296718], Epsilon usado: 0.01, Error: [247.63396718]
#   - Valor ajustado: 1162.393590715389, Predicción: [518.90890525], Epsilon usado: 0.012648552168552958, Error: [518.22990525]
#   - Valor ajustado: -1593.7227414734175, Predicción: [-713.07176365], Epsilon usado: 0.015998587196060583, Error: [713.75076365]
#   - Valor ajustado: 459.88247912524326, Predicción: [204.88728756], Epsilon usado: 0.020235896477251575, Error: [204.20828756]
#   - Valor ajustado: 424.4854387372723, Predicción: [189.0648533], Epsilon usado: 0.025595479226995357, Error: [188.3858533]
#   - Valor ajustado: 238.3489778064215, Predicción: [105.86208026], Epsilon usado: 0.032374575428176434, Error: [105.18308026]
#   - Valor ajustado: 557.7298037261193, Predicción: [248.62492338], Epsilon usado: 0.040949150623804255, Error: [247.94592338]
#   - Valor ajustado: -496.4602804966557, Predicción: [-222.59676996], Epsilon usado: 0.05179474679231213, Error: [223.27576996]
#   - Valor ajustado: -361.00287598038864, Predicción: [-162.04747389], Epsilon usado: 0.0655128556859551, Error: [162.72647389]
#   - Valor ajustado: 604.6005080339279, Predicción: [269.57607155], Epsilon usado: 0.08286427728546843, Error: [268.89707155]
#   - Valor ajustado: -493.9229707926623, Predicción: [-221.46259559], Epsilon usado: 0.10481131341546858, Error: [222.14159559]
#   - Valor ajustado: -115.79660635594381, Predicción: [-52.44056777], Epsilon usado: 0.13257113655901095, Error: [53.11956777]
#   - Valor ajustado: -51.27832187388773, Predicción: [-23.6009726], Epsilon usado: 0.16768329368110083, Error: [24.2799726]
#   - Valor ajustado: 93.72884154178972, Predicción: [41.21705417], Epsilon usado: 0.21209508879201905, Error: [40.53805417]
#   - Valor ajustado: 62.582898915228746, Predicción: [27.29485546], Epsilon usado: 0.2682695795279726, Error: [26.61585546]
#   - Valor ajustado: -27.711540624547833, Predicción: [-13.06664986], Epsilon usado: 0.33932217718953295, Error: [13.74564986]
#   - Valor ajustado: 54.6104923628127, Predicción: [23.73119937], Epsilon usado: 0.42919342601287785, Error: [23.05219937]
#   - Valor ajustado: 19.200947130410235, Predicción: [7.90317545], Epsilon usado: 0.5428675439323859, Error: [7.22417545]
#   - Valor ajustado: -4.814933095931993, Predicción: [-2.83189398], Epsilon usado: 0.6866488450043002, Error: [3.51089398]
#   - Valor ajustado: 7.479370843016312, Predicción: [2.66364502], Epsilon usado: 0.8685113737513529, Error: [1.98464502]
#   - Valor ajustado: 10.349255473237955, Predicción: [3.94647998], Epsilon usado: 1.0985411419875584, Error: [3.26747998]
#   - Valor ajustado: -28.00061101769183, Predicción: [-13.19586398], Epsilon usado: 1.3894954943731375, Error: [13.87486398]
#   - Valor ajustado: 2.255700750727683, Predicción: [0.32867081], Epsilon usado: 1.757510624854793, Error: [0.35032919]
#   - Valor ajustado: 0.5646419776583507, Predicción: [-0.42723042], Epsilon usado: 2.2229964825261956, Error: [1.10623042]
#   - Valor ajustado: 3.5931418772153343, Predicción: [0.92650537], Epsilon usado: 2.8117686979742307, Error: [0.24750537]
#   - Valor ajustado: -6.716029523668844, Predicción: [-3.68168178], Epsilon usado: 3.5564803062231287, Error: [4.36068178]
#   - Valor ajustado: 0.686669057501518, Predicción: [-0.37268446], Epsilon usado: 4.498432668969444, Error: [1.05168446]
#   - Valor ajustado: -2.6157986323905233, Predicción: [-1.84888353], Epsilon usado: 5.689866029018299, Error: [2.52788353]
#   - Valor ajustado: 0.16024149789865083, Predicción: [-0.60799695], Epsilon usado: 7.196856730011521, Error: [1.28699695]
#   - Valor ajustado: 1.7784274477899267, Predicción: [0.11533022], Epsilon usado: 9.102981779915218, Error: [0.56366978]
#   - Valor ajustado: 2.367275071493961, Predicción: [0.37854439], Epsilon usado: 11.513953993264481, Error: [0.30045561]
#   - Valor ajustado: 2.9736644852471374, Predicción: [0.64959973], Epsilon usado: 14.563484775012444, Error: [0.02940027]
#   - Valor ajustado: 3.180772954920931, Predicción: [0.74217696], Epsilon usado: 18.420699693267164, Error: [0.06317696]
#   - Valor ajustado: 1.0193124233666628, Predicción: [-0.22399328], Epsilon usado: 23.29951810515372, Error: [0.90299328]
#   - Valor ajustado: 0.5567598663806099, Predicción: [-0.43075372], Epsilon usado: 29.4705170255181, Error: [1.10975372]
#   - Valor ajustado: 3.062070631961705, Predicción: [0.68911717], Epsilon usado: 37.27593720314942, Error: [0.01011717]
#   - Valor ajustado: 2.811663096881117, Predicción: [0.5771853], Epsilon usado: 47.14866363457394, Error: [0.1018147]
#   - Valor ajustado: 2.395501550758235, Predicción: [0.39116159], Epsilon usado: 59.63623316594643, Error: [0.28783841]
#   - Valor ajustado: 3.1517624948178176, Predicción: [0.72920932], Epsilon usado: 75.43120063354623, Error: [0.05020932]
#   - Valor ajustado: 2.7735014106572353, Predicción: [0.56012708], Epsilon usado: 95.40954763499944, Error: [0.11887292]
#   - Valor ajustado: 2.5850503733429506, Predicción: [0.47588969], Epsilon usado: 120.67926406393289, Error: [0.20311031]
#   - Valor ajustado: 2.7040564453442726, Predicción: [0.52908526], Epsilon usado: 152.64179671752333, Error: [0.14991474]
#   - Valor ajustado: 2.7374224487708343, Predicción: [0.54399982], Epsilon usado: 193.06977288832496, Error: [0.13500018]
#   - Valor ajustado: 2.3977803748335966, Predicción: [0.39218023], Epsilon usado: 244.205309454865, Error: [0.28681977]
#   - Valor ajustado: 2.7138418534157163, Predicción: [0.53345933], Epsilon usado: 308.8843596477485, Error: [0.14554067]
#   - Valor ajustado: 2.540142771898707, Predicción: [0.45581605], Epsilon usado: 390.6939937054621, Error: [0.22318395]
#   - Valor ajustado: 2.732252868466974, Predicción: [0.54168903], Epsilon usado: 494.17133613238383, Error: [0.13731097]
#   - Valor ajustado: 2.6890943391287183, Predicción: [0.52239722], Epsilon usado: 625.0551925273976, Error: [0.15660278]
#   - Valor ajustado: 2.7083230771304767, Predicción: [0.53099244], Epsilon usado: 790.6043210907702, Error: [0.14800756]
#   - Valor ajustado: 2.7293560732777387, Predicción: [0.54039416], Epsilon usado: 1000.0, Error: [0.13860584]
# Mejor X: 3.062070631961705 Mejor Epsilon para index 48: 37.27593720314942, Mejor Error: [0.01011717], Mejor Predicción: [0.68911717]
# mejora -0.35932975395601474  R pre 0.6632408780056904 R pos 1.0225706319617052
#
# Valor original sin ruido (index 49): 4.7891
# Valor ruidoso original (index 49): 4.8985255406711605
# Y_test original (index 49): 3.346
# Y Predict original (index 49): 3.2407508148708315
# Y Predict optimo (index 49): 2.3819257668319294
#  Error prediccion (index 49): 0.9640742331680707
#   - Valor ajustado: 4.8985255406711605, Predicción: [3.2896639], Epsilon usado: 0.0, Error: [0.0563361]
#   - Valor ajustado: -411.6235293049127, Predicción: [-182.89519113], Epsilon usado: 0.01, Error: [186.24119113]
#   - Valor ajustado: -510.7636877881369, Predicción: [-227.21072213], Epsilon usado: 0.012648552168552958, Error: [230.55672213]
#   - Valor ajustado: -19.141493810197723, Predicción: [-7.45619569], Epsilon usado: 0.015998587196060583, Error: [10.80219569]
#   - Valor ajustado: -18.286435865705833, Predicción: [-7.07398582], Epsilon usado: 0.020235896477251575, Error: [10.41998582]
#   - Valor ajustado: -1337.8694774891196, Predicción: [-596.92601032], Epsilon usado: 0.025595479226995357, Error: [600.27201032]
#   - Valor ajustado: 223.45290299715543, Predicción: [100.98320643], Epsilon usado: 0.032374575428176434, Error: [97.63720643]
#   - Valor ajustado: 165.53389915760675, Predicción: [75.09348173], Epsilon usado: 0.040949150623804255, Error: [71.74748173]
#   - Valor ajustado: 381.47826497588716, Predicción: [171.62035222], Epsilon usado: 0.05179474679231213, Error: [168.27435222]
#   - Valor ajustado: -122.7837062539942, Predicción: [-53.78413937], Epsilon usado: 0.0655128556859551, Error: [57.13013937]
#   - Valor ajustado: 14.936844971780218, Predicción: [7.77678055], Epsilon usado: 0.08286427728546843, Error: [4.43078055]
#   - Valor ajustado: -294.05673421461137, Predicción: [-130.34297583], Epsilon usado: 0.10481131341546858, Error: [133.68897583]
#   - Valor ajustado: 32.75840189229172, Predicción: [15.74299495], Epsilon usado: 0.13257113655901095, Error: [12.39699495]
#   - Valor ajustado: -4.690213267723408, Predicción: [-0.99649076], Epsilon usado: 0.16768329368110083, Error: [4.34249076]
#   - Valor ajustado: -8.121582034042152, Predicción: [-2.53030845], Epsilon usado: 0.21209508879201905, Error: [5.87630845]
#   - Valor ajustado: 284.8627214146553, Predicción: [128.43332103], Epsilon usado: 0.2682695795279726, Error: [125.08732103]
#   - Valor ajustado: 48.631591696913766, Predicción: [22.83829161], Epsilon usado: 0.33932217718953295, Error: [19.49229161]
#   - Valor ajustado: -108.29740112034628, Predicción: [-47.30877849], Epsilon usado: 0.42919342601287785, Error: [50.65477849]
#   - Valor ajustado: -13.637655821616546, Predicción: [-4.99598676], Epsilon usado: 0.5428675439323859, Error: [8.34198676]
#   - Valor ajustado: -23.787357480614794, Predicción: [-9.53289114], Epsilon usado: 0.6866488450043002, Error: [12.87889114]
#   - Valor ajustado: -47.04998034092051, Predicción: [-19.93125543], Epsilon usado: 0.8685113737513529, Error: [23.27725543]
#   - Valor ajustado: 4.679671350125551, Predicción: [3.19183634], Epsilon usado: 1.0985411419875584, Error: [0.15416366]
#   - Valor ajustado: 25.19501916266539, Predicción: [12.36217201], Epsilon usado: 1.3894954943731375, Error: [9.01617201]
#   - Valor ajustado: 12.669510512201164, Predicción: [6.76328479], Epsilon usado: 1.757510624854793, Error: [3.41728479]
#   - Valor ajustado: 17.718123299118478, Predicción: [9.0200086], Epsilon usado: 2.2229964825261956, Error: [5.6740086]
#   - Valor ajustado: 6.897531519693269, Predicción: [4.18321716], Epsilon usado: 2.8117686979742307, Error: [0.83721716]
#   - Valor ajustado: 4.343216176656822, Predicción: [3.04144128], Epsilon usado: 3.5564803062231287, Error: [0.30455872]
#   - Valor ajustado: 4.199065718293517, Predicción: [2.9770062], Epsilon usado: 4.498432668969444, Error: [0.3689938]
#   - Valor ajustado: 3.380538613600913, Predicción: [2.61112558], Epsilon usado: 5.689866029018299, Error: [0.73487442]
#   - Valor ajustado: 15.930689564354314, Predicción: [8.22102788], Epsilon usado: 7.196856730011521, Error: [4.87502788]
#   - Valor ajustado: 4.539973436831895, Predicción: [3.12939154], Epsilon usado: 9.102981779915218, Error: [0.21660846]
#   - Valor ajustado: 0.19907348322184681, Predicción: [1.18901451], Epsilon usado: 11.513953993264481, Error: [2.15698549]
#   - Valor ajustado: 4.271142021289623, Predicción: [3.00922422], Epsilon usado: 14.563484775012444, Error: [0.33677578]
#   - Valor ajustado: 5.904797564684924, Predicción: [3.73946628], Epsilon usado: 18.420699693267164, Error: [0.39346628]
#   - Valor ajustado: 5.1572435026917764, Predicción: [3.40531052], Epsilon usado: 23.29951810515372, Error: [0.05931052]
#   - Valor ajustado: 5.632640278108935, Predicción: [3.6178123], Epsilon usado: 29.4705170255181, Error: [0.2718123]
#   - Valor ajustado: 5.543435573902746, Predicción: [3.5779379], Epsilon usado: 37.27593720314942, Error: [0.2319379]
#   - Valor ajustado: 4.942802788511685, Predicción: [3.30945578], Epsilon usado: 47.14866363457394, Error: [0.03654422]
#   - Valor ajustado: 4.583019821685239, Predicción: [3.14863322], Epsilon usado: 59.63623316594643, Error: [0.19736678]
#   - Valor ajustado: 4.439945833187137, Predicción: [3.08467932], Epsilon usado: 75.43120063354623, Error: [0.26132068]
#   - Valor ajustado: 4.9561363249851516, Predicción: [3.31541585], Epsilon usado: 95.40954763499944, Error: [0.03058415]
#   - Valor ajustado: 4.944817178675994, Predicción: [3.31035621], Epsilon usado: 120.67926406393289, Error: [0.03564379]
#   - Valor ajustado: 4.7234838537666635, Predicción: [3.21142048], Epsilon usado: 152.64179671752333, Error: [0.13457952]
#   - Valor ajustado: 4.841693749440738, Predicción: [3.26426016], Epsilon usado: 193.06977288832496, Error: [0.08173984]
#   - Valor ajustado: 4.907377324416787, Predicción: [3.29362064], Epsilon usado: 244.205309454865, Error: [0.05237936]
#   - Valor ajustado: 4.902283457608629, Predicción: [3.29134368], Epsilon usado: 308.8843596477485, Error: [0.05465632]
#   - Valor ajustado: 4.8292663970422645, Predicción: [3.25870515], Epsilon usado: 390.6939937054621, Error: [0.08729485]
#   - Valor ajustado: 4.892713995067636, Predicción: [3.28706615], Epsilon usado: 494.17133613238383, Error: [0.05893385]
#   - Valor ajustado: 4.913725256060516, Predicción: [3.29645815], Epsilon usado: 625.0551925273976, Error: [0.04954185]
#   - Valor ajustado: 4.876786254149489, Predicción: [3.27994646], Epsilon usado: 790.6043210907702, Error: [0.06605354]
#   - Valor ajustado: 4.902280354357585, Predicción: [3.2913423], Epsilon usado: 1000.0, Error: [0.0546577]
# Mejor X: 4.9561363249851516 Mejor Epsilon para index 49: 95.40954763499944, Mejor Error: [0.03058415], Mejor Predicción: [3.31541585]
# mejora -0.057610784313991026  R pre 0.10942554067116017 R pos 0.1670363249851512
#
# error en la entrega:
# MAE: 1.3138027078018373
# RMSE: 1.775937893039519
# R2: -0.11281662182362528
#
# error attack:
# MAE: 0.9890178430518207
# RMSE: 1.2683340401840344
# R2: 0.4324091925441875
#
# Estadísticas detalladas de mejora:
# Mejora Media: 1.2071374540344524
# Varianza de la Mejora: 1.036203534454672
# Número de puntos que mejoran: 26
# Mejora Máxima: 4.169171354503474
# Mejora Mínima: 0.013211692593256164
#
# Estadísticas detalladas de empeoramiento:
# Empeoramiento Medio: 0.6310971069747885
# Varianza del Empeoramiento: 0.2002485345900805
# Número de puntos que empeoran: 24
# Empeoramiento Máximo: 1.65257637446227
# Empeoramiento Mínimo: 0.035032684537073866
